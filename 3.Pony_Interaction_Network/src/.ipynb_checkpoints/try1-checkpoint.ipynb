# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib

# %%
df = pd.read_csv("../../../hw3/submission_template/data/pony_data/clean_dialog.csv")
df = df.loc[:,['title', 'pony']].apply(lambda x: x.astype(str).str.lower())
df
# Out:
#                                title                           pony
# 0        friendship is magic, part 1                       narrator
# 1        friendship is magic, part 1                       narrator
# 2        friendship is magic, part 1  narrator and twilight sparkle
# 3        friendship is magic, part 1               twilight sparkle
# 4        friendship is magic, part 1                   twinkleshine
# ...                              ...                            ...
# 36854  my little pony best gift ever                         others
# 36855  my little pony best gift ever                          alice
# 36856  my little pony best gift ever                         others
# 36857  my little pony best gift ever                         others
# 36858  my little pony best gift ever                         others
#
# [36859 rows x 2 columns]

# %%
def check_word(name, forbidden):
    if set(str.split(name, " ")) & set(forbidden):
        return True
    else:
        return False

# %%
counts = df['pony'].value_counts()
df_count = pd.DataFrame()
df_count['name']= counts.index
df_count['counts'] = list(counts)

df_count = df_count[df_count['name'].apply(lambda x: not check_word(x, forbidden))]
#counts
#df_count
top_101 = list(df_count[0:101]['name'])
top_101
# Out:
# ['twilight sparkle',
#  'rainbow dash',
#  'pinkie pie',
#  'applejack',
#  'rarity',
#  'spike',
#  'fluttershy',
#  'apple bloom',
#  'starlight glimmer',
#  'sweetie belle',
#  'scootaloo',
#  'discord',
#  'trixie',
#  'princess celestia',
#  'granny smith',
#  'big mcintosh',
#  'princess cadance',
#  'maud pie',
#  'princess luna',
#  'sunburst',
#  'shining armor',
#  'thorax',
#  'diamond tiara',
#  'flim',
#  'smolder',
#  'spitfire',
#  'flam',
#  'zecora',
#  'cheerilee',
#  'gallus',
#  'cutie mark crusaders',
#  'sandbar',
#  'ocellus',
#  'cozy glow',
#  'silverstream',
#  'yona',
#  'prince rutherford',
#  'garble',
#  'gilda',
#  'zephyr breeze',
#  'cranky doodle donkey',
#  'rockhoof',
#  'quibble pants',
#  'young applejack',
#  'daring do',
#  'queen chrysalis',
#  'lightning dust',
#  'star swirl the bearded',
#  'mayor mare',
#  'sugar belle',
#  'ember',
#  'iron will',
#  'mrs. cake',
#  'tempest shadow',
#  'sassy saddles',
#  'snips',
#  'lord tirek',
#  'rumble',
#  'silver spoon',
#  'snails',
#  'sludge',
#  'cheese sandwich',
#  'babs seed',
#  'soarin',
#  'pipsqueak',
#  'gabby',
#  'filthy rich',
#  'photo finish',
#  'bulk biceps',
#  'fancy pants',
#  'goldie delicious',
#  'moon dancer',
#  'mudbriar',
#  'gladmane',
#  'capper',
#  'chancellor neighsay',
#  'bow hothoof',
#  'stellar flare',
#  'ms. peachbottom',
#  'mr. cake',
#  'princess ember',
#  'vapor trail',
#  'sky stinger',
#  'windy whistles',
#  'braeburn',
#  'hoity toity',
#  'pharynx',
#  'rover',
#  'sweetie drops',
#  'the storm king',
#  'derpy',
#  'dr. caballeron',
#  'double diamond',
#  'trouble shoes',
#  'firelight',
#  'nightmare moon',
#  'matilda',
#  'young big mcintosh',
#  'princess skystar',
#  'neighsay',
#  'young rainbow dash']

# %%
G = nx.Graph()
forbidden = ['others', 'ponies', 'and', 'all']
pony_prev = df['pony'][0]
title_prev = df['title'][0]

for i in range(1,len(df)):
    title = df['title'][i]
    pony = df['pony'][i]
    #print(pony)
    #print(title)
    if pony == pony_prev:
        pony_prev = pony
        title_prev = title
        continue
    if set(forbidden) & set(str.split(pony, " ")) or pony not in top_101:
        print(f'skip {pony}')
        pony_prev = None
        title_prev = title
        continue
    if title != title_prev:
        print('New episode started')
        pony_prev = pony
        title_prev = title
        continue
    if pony_prev != None:
        if G.has_edge(pony_prev, pony):
            G[pony_prev][pony]['weight'] = G[pony_prev][pony]['weight'] + 1
        else:
            G.add_edge(pony_prev, pony, weight=1)
    
    pony_prev = pony
    title_prev = title
# Out:
# skip narrator and twilight sparkle
# skip twinkleshine
# skip twinkleshine
# skip ponies
# New episode started
# skip everypony
# skip everypony
# skip everypony
# skip others
# skip others
# skip others
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip shadowbolt leader
# skip everypony
# skip twilight sparkle and rainbow dash
# New episode started
# skip applejack and twilight sparkle
# skip rarity and pinkie pie
# skip savoir fare
# skip savoir fare
# skip savoir fare
# skip ponies
# skip drizzle
# skip others
# skip daisy
# skip shoeshine
# skip ponies in unison
# skip ponies in unison
# skip others
# New episode started
# skip daisyjo
# skip daisyjo
# skip daisyjo
# skip nurse redheart
# skip nurse redheart
# skip mule
# skip daisy
# skip rose
# skip lily valley
# skip daisy
# skip lily valley
# skip rose
# skip daisy
# skip others
# skip others
# skip ponies
# skip ponies
# New episode started
# skip rainbow dash and gilda
# skip gilda and rainbow dash
# skip merry may
# skip pony
# skip others
# skip others
# skip others
# New episode started
# skip audience
# skip audience
# skip snips and snails
# skip audience
# skip golden harvest
# skip snips and snails
# skip snips and snails
# skip snips and snails
# skip unidentified cow
# skip others
# skip snips and snails
# skip snips and snails
# skip others
# New episode started
# skip ponies
# skip others
# skip ponies
# skip razer
# skip razer
# skip others
# skip others
# New episode started
# skip applejack and rarity
# skip applejack and rarity
# skip applejack and rarity
# skip everyone but twilight
# skip others
# skip others
# skip daisy
# skip rose
# skip lily valley
# skip daisy
# skip others
# skip others
# skip lotus blossom
# skip golden harvest
# skip gardening pony
# skip daisy
# skip choir
# skip choir
# skip rainbow dash and pinkie pie
# skip choir
# skip fluttershy and rarity
# skip choir
# skip others
# skip choir
# skip choir
# skip choir
# skip spike and applejack
# skip rainbowshine
# New episode started
# skip twist
# skip twist
# skip twist
# skip twist
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip ace point
# skip twist
# skip twist
# skip twist
# skip twist
# skip others
# skip others
# skip diamond tiara and silver spoon
# skip others
# skip others
# skip others
# skip twist
# skip others
# New episode started
# skip applejack and rainbow dash
# skip applejack and rainbow dash
# skip applejack and rainbow dash
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip others
# skip all sans rarity
# skip others
# skip all sans rarity
# skip others
# skip all except rarity
# skip all except rarity
# New episode started
# skip twilight
# New episode started
# skip others
# skip hoops
# skip others
# skip others
# skip hoops
# skip others
# skip others
# skip hoops
# skip others
# skip hoops
# skip others
# skip group
# skip steam roller
# skip others
# skip others
# skip others
# skip hoops
# skip others
# skip rainbowshine
# skip foggy fleece
# skip madden
# skip madden
# skip madden
# skip lucy packard
# skip lucy packard
# skip lucy packard
# skip dr. hooves
# skip lucy packard
# skip lucy packard
# skip meadow song
# skip lucy packard
# skip lucy packard
# skip madden
# skip hoops
# skip misty fly
# skip others
# skip hoops
# skip others
# skip hoops
# skip others
# skip others
# New episode started
# skip apple bloom and scootaloo
# skip apple bloom and scootaloo
# skip apple bloom and scootaloo
# skip apple bloom and scootaloo
# skip apple bloom and sweetie belle
# skip others
# skip others
# New episode started
# skip apple bloom and scootaloo
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip fido
# skip diamond dogs
# skip spot
# skip fido
# skip spot
# skip fido
# skip spot
# skip spot
# skip fido
# skip diamond dogs
# skip all
# skip sir spike
# skip sir spike
# skip lady rarity
# skip sir spike
# skip sir spike
# skip spot
# skip fido
# skip spot
# skip fido
# skip spot
# skip fido
# skip fido
# skip fido
# skip fido
# skip spot
# skip spot
# skip spot
# skip fido and spot
# skip spot
# skip fido
# skip spot
# skip mook dogs
# skip spot
# skip fido
# skip spot
# skip fido
# skip spot
# skip background voice
# skip lyrica lilac
# skip royal ribbon
# skip shoeshine
# skip gala appleby
# skip golden harvest
# skip lemon hearts
# skip lyrica lilac
# skip lyrica lilac
# skip royal ribbon
# skip lyrica lilac
# skip fluttershy and rarity
# New episode started
# skip others
# skip little strongheart
# skip others
# skip noteworthy
# skip others
# skip ol' salt
# skip buffalo
# skip little strongheart
# skip little strongheart
# skip little strongheart
# skip little strongheart
# skip rainbow dash and pinkie pie
# skip chief thunderhooves
# skip little strongheart
# skip little strongheart
# skip little strongheart
# skip little strongheart
# skip others
# skip others
# skip others
# skip others
# skip others
# skip chief thunderhooves
# skip sheriff silverstar
# skip chief thunderhooves
# skip sheriff silverstar
# skip chief thunderhooves
# skip little strongheart
# skip sheriff silverstar
# skip goldengrape
# skip little strongheart
# skip chief thunderhooves
# skip chief thunderhooves
# skip chief thunderhooves
# skip chief thunderhooves
# skip sheriff silverstar
# skip sheriff silverstar
# skip chief thunderhooves
# skip chief thunderhooves
# skip chief thunderhooves
# New episode started
# skip guard 1
# skip guard 2
# skip guard 1
# skip guard 2
# skip guard
# New episode started
# skip apple bloom and sweetie belle
# skip apple bloom and sweetie belle
# skip apple bloom and sweetie belle
# skip count caesar
# skip aunt orange
# skip uncle orange
# skip aunt orange
# skip tall order
# skip aunt orange
# skip dane tee dove
# skip tall order
# skip pony
# skip others
# skip young hoops
# skip young hoops
# skip others
# skip young hoops
# skip young fluttershy
# skip young fluttershy
# skip others
# skip others
# skip others
# skip others
# skip young fluttershy
# skip rarity's teacher
# skip young rarity
# skip young rarity
# skip young rarity
# skip young rarity
# skip crystal clear
# skip crystal clear
# skip crystal clear
# skip young twilight sparkle
# skip young twilight sparkle
# skip young twilight sparkle
# skip young twilight sparkle
# skip young twilight sparkle
# skip young twilight sparkle
# skip young twilight sparkle
# skip young twilight sparkle
# skip cherry fizzy
# skip igneous rock pie
# skip cloudy quartz
# skip young pinkie pie
# skip young pinkie pie
# skip young pinkie pie
# skip young hoops
# skip mane six
# skip apple bloom and sweetie belle
# skip twilight sparkle and spike
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip davenport
# skip owlowiscious
# skip green dragon
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# skip owlowiscious
# New episode started
# skip others
# skip others
# skip slowing down
# skip breathing heavily
# skip pinkie pie voicing a bucket of turnips
# skip pinkie pie voicing a pile of rocks
# skip pinkie pie voicing a clump of lint
# skip pinkie pie voicing a bag of flour
# skip others
# skip rocky
# skip sir lintsalot
# skip madame le flour
# skip mr. turnip
# skip madame le flour
# skip sir lintsalot
# skip madame le flour
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip caramel
# skip lucky clover
# skip choir
# skip choir
# skip choir
# skip choir
# skip choir
# skip choir
# skip choir
# skip choir
# skip choir
# skip choir and fluttershy
# skip choir and applejack
# skip choir and rarity
# skip choir and rainbow dash
# skip all
# skip others
# skip prince blueblood
# skip prince blueblood
# skip all
# skip mr. greenhooves
# skip prince blueblood
# skip prince blueblood
# skip prince blueblood
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip lyrica lilac
# skip prince blueblood
# skip prince blueblood
# skip prince blueblood
# skip prince blueblood
# skip joe
# skip joe
# skip everypony
# skip all sans celestia
# New episode started
# skip twilight sparkle and rarity
# skip red apples
# skip others
# skip green apples
# skip red apples
# skip others
# skip green apples
# skip red apples
# skip others
# skip pond rainbow dash
# skip pond fluttershy
# skip pond pinkie pie
# skip pond rarity
# skip pond twilight sparkle
# skip others
# skip green apples
# skip butterflies
# skip butterflies
# skip butterflies
# skip flashback discord
# skip all
# skip all but rarity
# skip all
# skip others
# skip others
# skip others
# skip others
# skip others
# skip rarity and pinkie pie
# New episode started
# skip mrs cake
# skip mrs cake
# skip mrs cake
# skip mrs cake
# skip others
# skip others
# skip others
# skip orange swirl
# skip others
# skip fillies
# skip background ponies
# skip all
# skip sassaflash
# skip cherry berry
# skip noi
# skip foals
# New episode started
# skip hondo flanks
# skip hondo flanks
# skip cookie crumbles
# skip cookie crumbles
# skip hondo flanks
# skip applejack and apple bloom
# skip applejack and apple bloom
# skip sheep
# skip others
# skip others
# skip rarity and sweetie belle
# New episode started
# skip sea swirl
# skip scootaloo and sweetie belle
# skip twist
# skip diamond tiara and silver spoon
# skip scootaloo and sweetie belle
# skip others
# skip others
# skip lily valley
# skip rose
# skip daisy
# skip pony
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip fluttershy and rainbow dash
# skip fluttershy and rainbow dash
# skip fluttershy and rainbow dash
# skip others
# New episode started
# skip aura
# skip aura
# skip snips and snails
# skip pony 1
# skip pony 2
# skip crowd
# skip crowd
# skip pinkie pie and twilight sparkle
# skip others
# skip cherry berry
# skip pony
# skip daisy
# skip globe trotter
# skip others
# skip crafty crate
# skip jack hammer
# skip others
# skip others
# skip amethyst star
# skip amethyst star
# skip amethyst star
# skip amethyst star
# skip others
# skip liza doolots
# skip pony
# skip cherry berry
# skip other main cast
# New episode started
# skip bags valet
# skip bags valet
# skip bags valet
# skip jet set
# skip upper crust
# skip hayseed turnip truck
# skip hayseed turnip truck
# skip jet set and upper crust
# skip jet set
# skip hayseed turnip truck
# skip upper crust
# skip jet set
# skip jet set and upper crust
# skip hayseed turnip truck
# skip fleur de lis
# skip announcer
# skip announcer
# skip silver frames
# skip ponies
# skip golden gavel
# skip swan song
# skip silver frames
# skip golden gavel
# skip swan song
# skip silver frames
# skip golden gavel
# skip swan song
# skip others
# skip others
# skip others
# skip others
# skip bags valet
# skip bags valet
# skip bags valet
# skip rest of main cast
# skip rest of main cast
# skip upper crust
# skip upper crust
# skip jet set
# skip upper crust
# skip jet set
# skip upper crust
# skip upper crust
# skip jet set
# skip bags valet
# New episode started
# skip junebug
# skip junebug
# skip junebug
# skip dr. horse
# skip dr. horse
# skip dr. horse
# skip dr. horse
# skip dr. fauna
# skip dr. fauna
# skip applejack and twilight sparkle
# skip others
# New episode started
# skip main cast
# skip other main cast
# skip unicorns
# skip others
# skip others
# skip shoeshine
# skip applejack and fluttershy
# skip main cast
# skip choir
# New episode started
# skip others
# skip daisy
# skip apple family
# skip foals
# New episode started
# skip main cast
# skip main cast
# skip nurse redheart
# skip nurse redheart
# skip nurse redheart
# skip nurse redheart
# skip pumpkin cake
# skip pumpkin cake
# skip pumpkin cake
# skip pumpkin cake
# skip pound cake
# skip pound cake
# skip pumpkin cake
# New episode started
# skip conductor
# skip ponies
# skip parcel post
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip coach ponies
# skip others
# New episode started
# skip ponies
# skip caramel
# skip caramel
# skip flim and flam
# skip flim and flam
# skip flim and flam
# skip others
# skip flim and flam
# skip others
# skip flim and flam
# skip flim and flam
# skip crowd
# skip crowd
# skip flim and flam
# skip flim and flam
# skip others
# skip flim and flam
# skip flim and flam
# skip flim and flam
# skip flim and flam
# skip rest of main cast
# skip rest of main cast
# skip rest of main cast
# skip cherry berry
# skip comet tail
# skip crowd
# skip crowd
# skip flim and flam
# skip crowd
# skip caramel
# New episode started
# skip others
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip others
# skip fluttershy and twilight sparkle
# skip others
# skip nurse snowheart
# skip ahuizotl
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip doctor horse
# skip others
# skip nurse snowheart
# skip others
# skip others
# skip others
# skip doctor horse
# skip night watch
# skip ahuizotl
# New episode started
# skip others
# skip others
# skip others
# skip apple bloom and sweetie belle
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip sweetie belle and scootaloo
# skip apple bloom and scootaloo
# skip cheerilee and big mcintosh
# skip cheerilee and big mcintosh
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip daisyjo
# skip daisyjo
# skip rose
# skip mr. waddle
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip choir and pinkie pie
# skip choir and pinkie pie
# skip cranky doodle donkey and matilda
# New episode started
# skip lucy packard
# skip sand trap
# skip sand trap
# skip sand trap
# skip others
# skip others
# skip others
# skip gizmo
# skip gizmo
# skip gizmo
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip crafty crate
# skip lemon hearts
# skip crafty crate
# skip meadow song
# skip mr. greenhooves
# skip cherry berry
# skip cherry berry
# skip cherry berry
# skip cherry berry
# skip cherry berry
# skip cherry berry
# skip shoeshine
# skip royal riff
# skip others
# skip others
# skip others
# skip globe trotter
# skip globe trotter
# skip globe trotter
# skip pinkie pie and rarity
# New episode started
# skip future twilight sparkle
# skip future twilight sparkle
# skip future twilight sparkle
# skip future twilight sparkle
# skip future twilight sparkle
# skip future twilight sparkle
# skip future twilight sparkle
# skip future twilight sparkle
# skip guard
# skip past twilight sparkle
# skip past twilight sparkle
# skip past twilight sparkle
# skip past twilight sparkle
# skip past twilight sparkle
# skip past twilight sparkle
# skip main cast
# skip others
# skip others
# skip fume
# skip others
# skip others
# skip fume
# skip teenage dragons
# skip teenage dragons
# skip fume
# skip crackle
# skip others
# skip others
# skip teenage dragons
# skip others
# skip others
# skip fume
# skip others
# skip teenage dragons
# skip teenage dragons
# skip others
# skip others
# skip fume
# skip teenage dragons
# skip others
# skip others
# New episode started
# skip flitter
# skip mule
# skip film announcer
# skip pegasi
# skip pegasi
# skip pegasi
# skip cloud chaser
# skip flitter
# skip pegasi
# skip thunderlane
# skip pegasi
# skip foals
# skip others
# skip others
# skip fluttershy and rainbow dash
# skip flitter
# skip cloud chaser
# New episode started
# skip students
# skip students
# skip truffle
# skip others
# skip others
# skip others
# skip cotton cloudy
# skip truffle
# skip main cast
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip mr. cake and mrs. cake
# skip rest of main cast
# skip gustave le grand
# skip donut joe
# skip mulia mild
# skip gustave le grand
# skip donut joe
# skip donut joe
# skip mulia mild
# skip donut joe
# skip mulia mild
# skip donut joe
# skip gustave le grand
# skip gustave le grand
# skip donut joe
# skip mulia mild
# skip gustave le grand
# New episode started
# skip rest of main cast
# skip others
# skip others
# skip others
# skip others
# skip rest of main cast
# skip young twilight sparkle
# skip young cadance
# skip young twilight sparkle
# skip young cadance
# skip wild fire
# skip lucky clover
# skip wild fire
# skip lucky clover
# skip wild fire
# skip lucky clover
# skip lucky clover
# skip wild fire
# skip twinkleshine
# skip minuette
# skip lyra heartstrings
# skip rest of main cast
# skip others
# New episode started
# skip twilight sparkle and princess cadance
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip professor bill neigh
# skip twilight sparkle and spike
# skip all
# skip other ponies
# skip autumn gem
# skip autumn gem
# skip autumn gem
# skip fleur de verre
# skip fleur de verre
# skip elbow grease
# skip others
# skip elbow grease
# skip amethyst maresbury
# skip amethyst maresbury
# skip amethyst maresbury
# skip amethyst maresbury
# skip amethyst maresbury
# skip others
# skip all
# skip all
# skip elbow grease
# skip autumn gem
# skip fleur de verre
# skip others
# skip fleur de verre
# skip amethyst maresbury
# skip amethyst maresbury
# New episode started
# skip amethyst maresbury
# skip king sombra
# skip autumn gem
# skip autumn gem
# skip king sombra
# skip crystal pony
# skip crystal beau
# skip sapphire joy
# skip king sombra
# skip sapphire joy
# skip king sombra
# skip sapphire joy
# skip king sombra
# skip king sombra
# skip king sombra
# skip bright smile
# skip king sombra
# skip all sans twilight sparkle
# skip all sans twilight sparkle
# skip others
# skip others
# skip all sans twilight sparkle
# New episode started
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie and pinkie pie 2
# skip pinkie pie 2
# skip pinkie pie 3
# skip others
# skip pinkie pie duplicates
# skip pinkie pie duplicates
# skip pinkie pie duplicates
# skip pinkie pie duplicate
# skip pinkie pie duplicate 2
# skip pinkie pie duplicate 3
# skip pinkie pie duplicate 4
# skip pinkie pie duplicate 5
# skip pinkie pie duplicate 6
# skip pinkie pie duplicates
# skip pinkie pie duplicates
# skip pinkie pie duplicate
# skip pinkie pie duplicate
# skip pinkie pie duplicates
# skip pinkie pie duplicate
# skip pinkie pie duplicate
# skip pinkie pie duplicate
# skip pinkie pie duplicate 2
# skip pinkie pie duplicate 3
# skip pinkie pie duplicate
# skip pinkie pie duplicate
# skip others
# skip others
# New episode started
# skip apple bloom and scootaloo
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip apple bloom and scootaloo
# skip apple bloom and scootaloo
# skip others
# skip spectator
# skip shopkeeper
# skip shopkeeper
# skip others
# skip saddle arabian delegates
# New episode started
# skip the olden pony
# skip the olden pony
# skip the olden pony
# skip the olden pony
# skip the olden pony
# New episode started
# skip messenger pony
# skip all pegasi
# skip all pegasi
# skip cloudchaser
# skip meadow flower
# skip meadow flower
# skip rainbow dash and lightning dust
# skip cloudchaser
# skip meadow flower
# skip all pegasi
# skip others
# skip rest of main cast
# skip others
# New episode started
# skip young granny smith
# skip half baked apple
# skip apple split
# skip apple split
# skip apple split
# skip baby applejack
# skip young apple rose
# skip young granny smith
# skip apple bloom and babs seed
# skip auntie applesauce
# skip apple rose
# skip auntie applesauce
# skip auntie applesauce
# skip apple rose
# skip apple rose
# skip auntie applesauce
# skip apple rose
# skip apple rose
# skip apple rose
# skip apple dumpling
# skip apple leaves
# skip apple leaves
# skip apple bloom and babs seed
# skip apple bloom and babs seed
# skip apple bloom and babs seed
# skip ponies
# skip auntie applesauce
# skip others
# skip others
# skip apple family
# skip others
# skip apple family
# skip others
# skip apple family
# skip applejack and apple bloom
# skip apple family
# skip apple family
# skip apple family
# skip others
# skip others
# skip others
# New episode started
# skip applejack and granny smith
# skip fluttershy and rainbow dash
# New episode started
# skip rest of main cast
# skip twilight sparkle and spike
# skip main cast sans fluttershy
# skip main cast sans fluttershy and applejack
# New episode started
# skip conductor
# skip conductor
# skip conductor
# skip conductor
# skip conductor
# skip conductor
# New episode started
# skip conductor
# skip laurette
# skip main cast
# skip train conductor
# skip twilight and cadance
# skip golden hooves
# skip crystal ponies
# skip golden hooves
# skip main cast
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip conductor
# New episode started
# skip others
# skip davenport
# skip others
# skip others
# skip rarity and rainbow dash
# skip others
# skip pinkie pie and applejack
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip twilight and fluttershy
# skip twilight and fluttershy
# skip others
# skip others
# skip crowd
# skip others
# skip others
# skip others
# skip others
# skip main cast
# skip others
# skip choir
# skip others
# skip others
# skip main cast and crowd
# New episode started
# skip others
# skip train conductor
# skip messenger pony
# skip messenger pony
# skip others
# skip royal ribbon
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip main cast sans fluttershy
# skip royal guard
# skip cherry berry and comet tail
# New episode started
# skip rainbow dash and applejack
# skip parcel post
# skip parcel post
# skip all
# New episode started
# skip others
# skip a.k. yearling
# skip a.k. yearling
# skip a.k. yearling
# skip rainbow dash and twilight sparkle
# skip all except fluttershy
# skip ahuizotl
# skip ahuizotl
# skip ahuizotl
# skip ahuizotl
# skip ahuizotl
# skip ahuizotl
# skip ahuizotl
# skip messenger pony
# New episode started
# skip ms. harshwhinny
# skip aura
# skip snips and snails
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip apple bloom and sweetie belle
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip crusaders
# skip crusaders
# skip diamond tiara and silver spoon
# skip crusaders
# skip diamond tiara and silver spoon
# skip apple bloom and sweetie belle
# skip train conductor
# skip apple bloom and sweetie belle
# skip train conductor
# skip others
# skip others
# skip others
# skip crusaders
# skip ms. harshwhinny
# skip apple bloom and sweetie belle
# New episode started
# skip others
# skip main cast
# skip others
# skip henchpony
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip others
# skip all except fluttershy
# skip rest of main cast
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip tourist pony 1
# skip others
# skip others
# skip cherry fizzy
# skip businesspony
# skip others
# skip others
# skip main cast sans spike
# skip janine manewitz
# skip others
# skip prim hemline
# skip prim hemline
# skip prim hemline
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip janine manewitz
# skip suri polomare
# skip prim hemline
# skip suri polomare
# skip suri polomare
# skip coco pommel
# skip suri polomare
# skip suri polomare
# skip suri polomare
# skip prim hemline
# skip prim hemline
# skip suri polomare
# skip prim hemline
# skip prim hemline
# skip prim hemline
# skip prim hemline
# skip others
# skip others
# skip others
# skip others
# skip suri polomare
# skip coco pommel
# skip suri polomare
# skip hinny of the hills
# skip coco pommel
# skip coco pommel
# New episode started
# skip big mcintosh and granny smith
# skip apple family
# skip applejack and apple bloom
# skip others
# skip apples
# skip all
# skip others
# skip apple family
# skip all
# New episode started
# skip helia
# skip thunderlane
# skip mane moon
# skip orange swirl
# skip mane moon
# skip sprinkle medley
# skip orange swirl
# skip fleetfoot
# skip cloudsdale cheerleaders
# skip rainbowshine and sprinkle medley
# skip fleetfoot
# skip cloudsdale cheerleaders
# skip fleetfoot
# skip fleetfoot
# skip fleetfoot
# skip fleetfoot
# skip fleetfoot
# skip cloudsdale cheerleaders
# skip fleetfoot
# skip fleetfoot
# skip fleetfoot
# skip fleetfoot
# skip fleetfoot
# skip cloudsdale cheerleaders
# skip official
# skip main cast sans rainbow dash
# New episode started
# skip conductor
# skip others
# skip applejack and rarity
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip vendor pony
# skip vendor pony
# skip crowd
# skip others
# skip art vendor
# skip art vendor
# skip peachy pitt
# skip peachy pitt
# skip crowd
# skip crowd
# skip others
# skip others
# skip others
# skip goldengrape
# skip others
# skip colt
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip pinkie pie and cheese sandwich
# skip pinkie pie and cheese sandwich
# skip others
# skip rest of main cast
# New episode started
# skip ponies
# skip main cast sans rarity
# skip main cast sans rarity
# skip main cast sans rarity
# skip main cast sans rarity
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip trenderhoof
# skip applejack and rarity
# skip trenderhoof
# skip trenderhoof
# New episode started
# skip the pony tones
# skip the pony tones
# skip torch song
# skip torch song
# skip torch song
# skip others
# skip the pony tones
# skip others
# skip others
# skip others
# skip the pony tones
# skip others
# skip the pony tones
# skip others
# skip crowd
# skip nightjar
# skip zipporwhill
# skip nightjar
# skip zipporwhill
# skip nightjar and zipporwhill
# skip zipporwhill
# skip nightjar
# skip the pony tones
# skip others
# skip zipporwhill
# skip others
# skip the pony tones
# skip the pony tones
# skip others
# skip others
# skip others
# skip rest of main cast
# skip the pony tones
# skip the pony tones
# skip the pony tones
# skip the pony tones
# skip the pony tones
# New episode started
# skip foals
# skip diamond tiara and silver spoon
# skip foals
# skip classmate pony 2
# skip classmate pony 3
# skip foals
# skip foals
# skip foals
# New episode started
# skip rest of main cast
# skip rest of main cast
# skip rest of main cast
# skip rest of main cast
# skip seabreeze
# skip cloud chaser
# skip flitter
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip twirly
# skip breezie
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip breezie
# skip breezie
# skip twirly
# skip seabreeze
# skip flitter
# skip breezies
# skip seabreeze
# skip twirly
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip seabreeze
# skip breezies
# skip flitter
# skip cloud chaser
# skip breezette
# skip breezie
# skip seabreeze
# skip seabreeze
# New episode started
# skip scootaloo and sweetie belle
# skip chimera's tiger head
# skip chimera's tiger head
# skip chimera's goat head
# skip chimera's snake head
# skip chimera's tiger head
# skip chimera's goat head
# skip chimera's snake head
# skip chimera's tiger head
# skip chimera's goat head
# skip chimera's snake head
# skip chimera's tiger head
# skip chimera's goat head
# skip chimera's snake head
# skip chimera's tiger head
# skip chimera's snake head
# skip chimera's goat head
# skip chimera's tiger head
# skip chimera's goat head
# skip chimera's snake head
# skip chimera's tiger head and goat head
# skip chimera's goat head
# skip chimera's goat head
# skip others
# skip others
# skip rest of main cast
# skip others
# skip rest of main cast
# New episode started
# skip apple bloom and scootaloo
# skip lemon hearts
# skip noteworthy
# skip noteworthy
# skip noteworthy
# skip others
# skip eclair cr<e8>me
# skip others
# skip little pony 2
# skip little pony 2
# skip others
# skip little pony 2
# skip others
# skip little pony 2
# skip others
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip scootaloo and apple bloom
# skip sapphire shores
# skip sapphire shores
# skip security guard
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# skip sapphire shores
# New episode started
# skip others
# skip flim and flam
# skip flim and flam
# skip flim and flam
# skip silver shill
# skip crowd
# skip in background
# skip flim and flam
# skip silver shill
# skip silver shill
# skip silver shill
# skip others
# skip others
# skip apple bloom and granny smith
# skip silver shill
# skip silver shill
# skip silver shill
# skip others
# skip rainbowshine
# skip silver shill
# skip silver shill
# skip silver shill
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip big mcintosh and rainbow dash
# skip others
# skip others
# skip sassaflash
# skip others
# skip others
# New episode started
# skip crowd pony 1
# skip crowd pony 2
# skip others
# skip others
# skip others
# skip others
# skip others
# skip applejack and rarity
# skip cratus
# skip cratus
# skip cratus
# skip cratus
# skip stellar eclipse
# skip others
# skip others
# skip fluttershy and rainbow dash
# skip others
# skip others
# skip others
# skip fleur de verre
# skip stellar eclipse
# skip stellar eclipse
# skip stellar eclipse
# skip others
# skip others
# skip others
# skip others
# skip others
# skip minuette
# skip crowd pony 3
# skip others
# New episode started
# skip claude
# skip claude
# skip claude
# skip claude
# skip stallion
# New episode started
# skip crystal guard
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip apple bloom and sweetie belle
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip others
# skip bright smile
# skip elbow grease
# skip bright smile
# skip others
# skip security guard
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip ms. harshwhinny
# skip crystal pony in crowd
# skip others
# skip security guard 2
# skip all present characters bar spike
# skip ms. harshwhinny
# skip flash sentry
# skip duke of maretonia
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip rare find
# New episode started
# skip others
# skip all
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip night glider
# skip party favor
# skip party favor
# skip party favor
# skip others
# skip others
# skip citizens
# skip others
# skip citizens
# skip others
# skip citizens
# skip others
# skip citizens
# skip others
# skip others
# skip others
# skip others
# skip others
# skip party favor
# skip night glider
# skip night glider
# skip party favor
# skip night glider
# skip night glider
# New episode started
# skip others
# skip others
# skip party favor
# skip party favor
# skip party favor
# skip party favor
# skip party favor
# skip others
# skip others
# skip others
# skip party favor
# skip party favor
# skip party favor
# skip party favor
# skip night glider
# skip party favor
# skip night glider
# skip party favor
# skip night glider
# skip party favor
# skip night glider
# New episode started
# skip others
# skip all
# skip all
# skip all
# skip all
# skip main cast sans twilight
# skip aloe
# skip aloe
# skip rainbow dash and rarity
# skip rest of main cast sans twilight
# skip others
# skip all
# skip rest of main cast
# New episode started
# skip scootaloo and sweetie belle
# skip others
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip pest control pony
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip mysterious voice
# skip scootaloo and sweetie belle
# New episode started
# skip sunshower
# skip open skies
# skip sunshower
# skip clear skies
# skip sunshower
# skip clear skies
# skip sunshower
# skip open skies
# skip sunshower
# skip clear skies and open skies
# skip open skies
# skip clear skies
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip sunshower
# New episode started
# skip sheriff silverstar
# skip apple bloom and scootaloo
# skip sheriff silverstar
# skip sheriff silverstar
# skip townspony 1
# skip townspony 2
# skip sheriff silverstar
# skip townspony 3
# skip townspony 4
# skip sheriff silverstar
# skip sheriff silverstar
# skip apple bloom and scootaloo
# skip sheriff silverstar
# skip star spur
# skip senior deputy
# skip sheriff silverstar
# skip sheriff silverstar
# skip young trouble shoes
# skip young trouble shoes
# skip young trouble shoes
# skip sheriff silverstar
# skip sheriff silverstar
# skip sheriff silverstar
# skip sheriff silverstar
# skip crowd
# skip others
# skip others
# skip others
# skip sheriff silverstar
# skip judge
# skip sheriff silverstar
# skip sheriff silverstar
# New episode started
# skip scootaloo and sweetie belle
# skip tree hugger
# skip tree hugger
# skip parcel post
# skip parcel post
# skip announcer
# skip announcer
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# skip tree hugger
# New episode started
# skip grampa gruff
# skip grampa gruff
# skip grampa gruff
# skip grampa gruff
# skip grampa gruff
# skip grampa gruff
# skip grampa gruff
# skip storekeeper
# skip storekeeper
# skip storekeeper
# skip storekeeper
# skip storekeeper
# skip young hoops
# skip young gilda
# skip young gilda
# skip young gilda
# skip young gilda and young rainbow dash
# New episode started
# skip savoir fare
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip dr. hooves
# skip jeff letrotski
# skip dr. hooves
# skip jeff letrotski
# skip dr. hooves
# skip jeff letrotski
# skip dr. hooves
# skip jeff letrotski
# skip dr. hooves
# skip jeff letrotski
# skip dr. hooves
# skip dr. hooves
# skip octavia melody
# skip octavia melody
# skip octavia melody
# skip amethyst star
# skip amethyst star
# skip amethyst star
# skip lily valley
# skip daisy
# skip rose
# skip lily valley
# skip lily valley
# skip daisy
# skip rose
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip lyra heartstrings
# skip jeff letrotski
# skip dr. hooves
# skip dr. hooves
# skip lotus blossom
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip steven magnet
# skip octavia melody
# skip octavia melody
# skip octavia melody
# skip lyra heartstrings
# skip lyra heartstrings
# skip dr. hooves
# skip dr. hooves
# skip steven magnet
# skip steven magnet
# skip dr. hooves
# New episode started
# skip neigh sayer
# skip delegate 2
# skip horticultural pegasus
# skip horticultural pegasus
# skip horticultural pegasus
# skip public works pony
# skip public works pony
# skip public works pony
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip annoyed delegate
# skip annoyed delegate
# skip fluffy clouds
# skip fluffy clouds
# skip fluffy clouds
# skip others
# skip others
# skip others
# skip others
# skip public works pony
# skip public works pony
# skip public works pony
# skip horticultural pegasus
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip yaks
# skip conductor
# skip conductor
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip cherry jubilee
# skip yaks
# skip main cast sans pinkie
# skip yaks
# New episode started
# skip minuette
# skip minuette
# skip minuette
# skip twinkleshine
# skip twinkleshine
# skip minuette
# skip lemon hearts
# skip minuette
# skip minuette
# skip twinkleshine
# skip lemon hearts
# skip minuette
# skip young twilight sparkle
# skip young moon dancer
# skip young twilight sparkle
# skip young moon dancer
# skip lemon hearts
# skip twinkleshine
# skip lemon hearts
# skip minuette
# skip twinkleshine
# skip lemon hearts
# skip minuette
# skip minuette
# skip twinkleshine
# skip minuette
# skip ponies
# skip ponies
# skip minuette
# skip minuette
# skip minuette
# skip minuette
# skip minuette
# skip lemon hearts
# skip minuette
# skip twinkleshine
# skip minuette
# skip minuette
# skip minuette
# skip minuette
# skip minuette
# skip minuette
# skip minuette
# skip all
# New episode started
# skip rest of main cast
# skip others
# skip others
# skip ponies
# New episode started
# skip fashion plate
# skip fashion plate
# skip fashion plate
# skip fashion plate
# skip fashion plate
# skip fashion plate
# skip fashion plate
# skip fashion plate
# skip fashion plate and rarity
# skip fashion plate
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip pretzel
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip others
# skip others
# skip others
# skip wind rider
# skip wind rider
# skip wind rider
# skip wind rider
# skip misty fly
# skip stormy flare
# skip stormy flare
# skip stormy flare
# skip stormy flare
# skip misty fly
# skip wind rider
# skip blaze
# skip misty fly
# skip castle guard 1
# skip castle guard 1
# skip spearhead
# skip spearhead
# skip castle guard 1
# skip castle guard 1
# skip spearhead
# skip spearhead
# skip castle guard 1
# skip castle guard 1
# skip cinnamon chai
# skip cinnamon chai
# skip cinnamon chai
# skip cinnamon chai
# skip cinnamon chai
# skip cinnamon chai
# skip cinnamon chai
# skip blaze
# skip stormy flare
# skip wind rider
# skip wind rider
# skip wind rider
# skip wind rider
# skip wind rider
# skip wind rider
# skip blaze
# skip wind rider
# skip stormy flare
# New episode started
# skip rarity and applejack
# skip diamond cutter
# skip strawberry ice
# skip others
# skip others
# skip others
# skip others
# skip others
# skip stinky bottom
# skip stinky bottom
# skip coco pommel
# skip coco pommel
# skip coco pommel
# skip coco pommel
# skip coco pommel
# skip street pony
# skip coco pommel
# skip coco pommel
# skip coco pommel
# skip others
# skip others
# skip others
# skip others
# skip coco pommel
# skip coco pommel
# skip coco pommel
# skip coco pommel
# skip on stage
# skip raspberry beret
# skip coco pommel
# skip others
# skip raspberry beret
# skip coco pommel
# skip coco pommel
# skip on stage
# skip raspberry beret
# skip on stage
# skip others
# skip blueberry curls
# skip others
# skip blueberry curls
# skip others
# skip on stage
# skip on stage
# skip others
# skip raspberry beret
# skip others
# skip raspberry beret
# skip others
# skip raspberry beret
# skip others
# skip luckette
# skip others
# skip others
# skip raspberry beret
# skip others
# skip pearly stitch
# skip on stage
# skip coco pommel
# skip coco pommel
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip apple bloom and applejack
# skip booth barker
# skip booth barker
# skip others
# skip apple bloom and big mcintosh
# skip others
# skip apple bloom and big mcintosh
# skip apple bloom and big mcintosh as orchard blossom
# skip rainbow dash and scootaloo
# skip registration pony
# skip registration pony
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip foals
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip foals
# skip foals
# skip foals
# skip foals
# skip foals
# skip spoiled rich
# skip spoiled rich
# skip spoiled rich
# skip spoiled rich
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip spoiled rich
# skip spoiled rich
# skip spoiled rich
# skip spoiled rich
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip scootaloo and sweetie belle
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip pinkie pie and twilight sparkle
# skip pinkie pie and twilight sparkle
# skip featherweight
# skip featherweight
# skip featherweight
# skip others
# skip others
# skip others
# skip others
# skip rainbow dash and twilight sparkle
# skip main cast sans pinkie pie
# skip main cast sans pinkie pie
# skip princess cadance and shining armor
# New episode started
# skip porter pony
# skip apple family
# skip igneous rock
# skip cloudy quartz
# skip igneous rock
# skip limestone pie
# skip limestone pie
# skip marble pie
# skip limestone pie
# skip marble pie
# skip limestone pie
# skip marble pie
# skip marble pie
# skip cloudy quartz
# skip igneous rock
# skip igneous rock
# skip cloudy quartz
# skip igneous rock
# skip limestone pie
# skip igneous rock
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip applejack and pinkie pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip marble pie
# skip igneous rock
# New episode started
# skip foals
# skip foals
# skip all but rainbow dash
# skip rarity and spike
# New episode started
# skip rainbow dash and discord
# skip rainbow dash and discord
# skip main cast sans twilight sparkle
# New episode started
# skip ma hooffield
# skip ma hooffield
# skip ma hooffield
# skip ma hooffield
# skip others
# skip ma hooffield
# skip ma hooffield
# skip others
# skip others
# skip others
# skip others
# skip big daddy mccolt
# skip big daddy mccolt
# skip big daddy mccolt
# skip big daddy mccolt
# skip big daddy mccolt
# skip big daddy mccolt
# skip big daddy mccolt
# skip big daddy mccolt
# skip ma hooffield
# skip ma hooffield
# skip ma hooffield
# skip ma hooffield
# skip big daddy mccolt
# skip big daddy mccolt
# skip mccolts
# skip big daddy mccolt
# skip ma hooffield
# skip big daddy mccolt
# skip ma hooffield
# skip ma hooffield
# skip others
# skip ma hooffield
# skip others
# skip ma hooffield
# skip others
# skip ma hooffield
# skip others
# skip others
# skip others
# skip hooffields
# skip big daddy mccolt
# skip mccolts
# skip ma hooffield
# skip ma hooffield
# skip big daddy mccolt
# skip ma hooffield
# skip big daddy mccolt
# skip ma hooffield
# skip big daddy mccolt
# skip big daddy mccolt
# skip ma hooffield
# skip big daddy mccolt
# skip ma hooffield
# skip big daddy mccolt
# skip ma hooffield
# skip ma hooffield
# skip big daddy mccolt
# skip big daddy mccolt
# skip ma hooffield
# skip big daddy mccolt
# skip others
# skip ma hooffield
# skip others
# skip others
# skip young coloratura
# skip others
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip svengallop
# skip svengallop
# skip svengallop
# skip svengallop
# skip svengallop
# skip countess coloratura
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip svengallop
# skip countess coloratura
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip svengallop
# skip svengallop
# skip svengallop
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip svengallop
# skip svengallop
# skip svengallop
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip svengallop
# skip countess coloratura
# skip coloratura
# skip coloratura
# skip coloratura
# skip coloratura
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip coloratura
# skip coloratura and cutie mark crusaders
# skip others
# New episode started
# skip audience pony
# skip young hoops
# skip twilight sparkle and spike
# skip others
# skip young fluttershy
# skip others
# skip young hoops
# skip young fluttershy
# New episode started
# skip starlight glimmer and mane six
# skip others
# skip others
# skip others
# New episode started
# skip pinkie pie and rarity
# skip others
# skip others
# skip others
# skip crystal ponies
# skip others
# skip others
# skip foals
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip flurry heart
# skip spike and starlight glimmer
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip night light
# skip twilight velvet
# skip twilight velvet
# New episode started
# skip deputy copper
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip scootaloo and sweetie belle
# skip scootaloo and sweetie belle
# skip others
# skip others
# skip others
# skip hoofer steps
# skip hoofer steps
# skip hoofer steps
# skip hoofer steps
# skip tender taps
# skip tender taps
# skip tender taps
# skip shoeshine
# skip tender taps
# skip tender taps
# skip tender taps
# skip tender taps
# skip tender taps
# skip tender taps
# New episode started
# skip dragon lord torch
# skip dragons
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip maar
# skip others
# skip twilight sparkle and rarity
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# skip dragon lord torch
# New episode started
# skip cherry berry and goldengrape
# skip others
# New episode started
# skip rainbow dash and spitfire
# skip misty fly
# skip fleetfoot
# skip young hoops
# skip young hoops and young pegasi
# skip others
# skip misty fly
# skip surprise
# skip fleetfoot
# skip rest of main cast and cutie mark crusaders
# skip fleetfoot
# skip fleetfoot
# skip misty fly
# skip announcer
# skip fleetfoot
# skip fleetfoot
# skip misty fly
# skip surprise
# skip high winds
# skip ponies
# skip pegasi
# skip pegasi
# skip fluttershy and rainbow dash
# skip ponies
# skip ponies
# skip ponies
# skip stallions
# skip ponies
# skip ponies
# skip ponies
# skip ponies
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip professor flintheart
# skip young starlight glimmer
# skip professor flintheart
# skip young starlight glimmer
# skip professor flintheart
# skip young starlight glimmer
# skip professor flintheart
# skip young starlight glimmer
# skip professor flintheart
# skip professor flintheart
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip ponies
# skip ponies
# skip ponies
# New episode started
# skip buried lede
# skip buried lede
# skip mr. stripes
# skip mr. stripes
# skip mr. stripes
# skip plaid stripes
# skip others
# skip plaid stripes
# skip coco pommel
# skip rarity devil
# skip rarity angel
# skip rarity devil
# skip dancers
# skip blue bobbin
# skip blue bobbin
# skip plaid stripes
# skip plaid stripes
# skip plaid stripes
# skip plaid stripes
# skip mr. stripes
# skip others
# skip blue bobbin
# skip others
# skip plaid stripes
# skip others
# skip aloe
# skip aloe
# skip aloe
# skip others
# skip others
# skip caramel
# skip aloe
# skip aloe
# skip aloe
# skip buddy
# skip spoiled rich
# skip aloe
# skip aloe
# skip others
# skip others
# skip others
# skip others
# skip aloe
# skip others
# skip aloe
# skip aloe
# skip aloe
# skip mrs. shy
# skip mr. shy
# skip mrs. shy
# skip mr. shy
# skip mrs. shy
# skip mrs. shy
# skip mrs. shy
# skip mr. shy
# skip mrs. shy
# skip mrs. shy
# skip mr. shy
# skip mr. shy
# skip mr. shy
# skip mrs. shy
# skip mr. shy
# skip mrs. shy
# skip fluttershy and rainbow dash
# skip others
# skip others
# skip fluttershy and rainbow dash
# skip others
# skip fluttershy and rainbow dash
# skip mrs. shy
# skip mr. shy
# skip mr. shy
# skip mrs. shy
# New episode started
# skip saffron masala
# skip saffron masala
# skip saffron masala
# skip saffron masala
# skip saffron masala
# skip coriander cumin
# skip coriander cumin
# skip coriander cumin
# skip saffron masala
# skip coriander cumin
# skip saffron masala
# skip coriander cumin
# skip saffron masala
# skip coriander cumin
# skip coriander cumin
# skip coriander cumin
# skip pinkie pie and rarity
# skip saffron masala
# skip coriander cumin
# skip coriander cumin
# skip coriander cumin
# skip saffron masala
# skip coriander cumin
# skip saffron masala
# skip saffron masala
# skip others
# skip others
# skip pinkie pie and rarity
# skip others
# skip others
# skip pinkie pie and rarity
# skip pinkie pie and rarity
# skip others
# skip saffron masala
# skip others
# skip saffron masala
# skip others
# skip chargrill breadwinner
# skip orange slice
# skip chargrill breadwinner
# skip saffron masala
# skip coriander cumin
# skip saffron masala
# skip coriander cumin
# skip saffron masala
# skip pinkie pie and saffron masala
# skip coriander cumin
# skip zesty gourmand
# skip orange slice
# skip coriander cumin
# skip saffron masala
# skip pinkie pie and rarity
# skip zesty gourmand
# skip zesty gourmand
# skip zesty gourmand
# skip chargrill breadwinner
# skip zesty gourmand
# ...
# skip others
# skip others
# skip cattail
# skip cattail
# skip others
# New episode started
# skip pony of shadows
# skip pony of shadows
# skip pony of shadows
# skip pony of shadows
# skip pony of shadows
# skip somnambula
# skip mage meadowbrook
# skip flash magnus
# skip somnambula
# skip mistmane
# skip somnambula
# skip mage meadowbrook
# skip flash magnus
# skip flash magnus
# skip mage meadowbrook
# skip mage meadowbrook
# skip flash magnus
# skip mistmane
# skip mage meadowbrook
# skip somnambula
# skip mage meadowbrook
# skip somnambula
# skip mistmane
# skip mistmane
# skip pony of shadows
# skip pony of shadows
# skip pony of shadows
# skip stygian
# skip stygian
# skip stygian
# skip stygian
# skip mage meadowbrook
# skip mistmane
# skip grampa gruff
# skip seaspray
# skip choir
# skip others
# skip choir
# skip main cast sans twilight sparkle
# skip students
# skip students
# skip all sans twilight sparkle
# skip pony
# skip seaspray
# skip grampa gruff
# New episode started
# skip grampa gruff
# skip grampa gruff
# skip others
# skip others
# skip grampa gruff
# skip seaspray
# skip seaspray
# skip grampa gruff
# skip rest of students
# skip seaspray
# skip grampa gruff
# skip grampa gruff
# skip grampa gruff
# skip all
# skip yaks
# skip all
# skip students
# skip all
# skip others
# skip seaspray
# skip grampa gruff
# skip grampa gruff
# skip meadow song
# skip fluttershy's apparition
# skip rarity's apparition
# skip applejack's apparition
# skip rainbow dash's apparition
# skip twilight sparkle's apparition
# skip limestone pie
# skip marble pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip limestone pie
# skip marble pie
# skip limestone pie
# skip crowd
# skip background pony 1
# skip background pony 2
# skip background pony 3
# skip background pony 4
# New episode started
# skip pursey pink
# skip pursey pink
# skip pursey pink
# skip blue bobbin
# skip bracer britches
# skip bracer britches
# skip bracer britches
# skip luckette
# skip bracer britches
# skip bracer britches
# skip silver berry
# skip silver berry
# skip old money
# skip old money
# skip valley trend
# skip valley trend
# skip valley trend
# skip others
# skip others
# skip joan pommelway
# skip others
# skip valley trend
# skip bracer britches
# skip pony
# skip blueberry curls
# skip blueberry curls
# New episode started
# skip misty fly
# skip misty fly
# skip apple rose
# skip auntie applesauce
# skip apple rose
# skip apple rose
# skip apple rose
# skip auntie applesauce
# skip applejack vision
# skip auntie applesauce
# skip others
# skip auntie applesauce
# skip others
# skip auntie applesauce
# skip auntie applesauce
# skip apple rose
# skip others
# skip others
# skip applejack vision
# skip others
# skip crowd
# skip carnival barker
# skip carnival barker
# skip carnival barker
# skip carnival barker
# skip auntie applesauce
# skip applejack vision
# skip carnival barker
# skip auntie applesauce
# skip others
# skip applejack vision
# skip apple rose
# skip auntie applesauce
# skip jack pot
# skip big bucks
# skip jack pot
# skip auntie applesauce
# skip jack pot
# skip big bucks
# skip others
# skip big bucks
# skip jack pot
# skip jack pot
# skip auntie applesauce
# skip big bucks
# skip jack pot
# skip big bucks
# skip applejack vision
# skip big bucks
# skip jack pot
# skip auntie applesauce
# skip apple rose
# skip apple rose
# skip auntie applesauce
# skip auntie applesauce
# skip apple rose
# skip grannies
# skip auntie applesauce
# New episode started
# skip others
# skip others
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip sky beak
# skip twilight sparkle and cutie mark crusaders
# skip terramar
# skip sky beak
# skip terramar
# skip sky beak
# skip terramar
# skip sky beak
# skip sky beak
# skip sky beak
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip terramar
# skip ocean flow
# skip terramar
# skip ocean flow
# skip ocean flow
# skip terramar
# skip ocean flow
# skip terramar
# skip sky beak
# skip others
# skip others
# skip others
# skip others
# skip sweetie belle and scootaloo
# skip terramar
# skip scootaloo and sweetie belle
# skip ocean flow
# skip sky beak
# skip ocean flow
# skip sky beak
# skip terramar
# skip terramar
# skip sky beak
# skip ocean flow
# skip sky beak
# skip ocean flow
# skip sky beak
# skip ocean flow
# skip terramar
# New episode started
# skip twilight sparkle and spike
# skip on stage
# skip on stage
# skip raspberry beret
# skip on stage
# skip raspberry beret
# skip on stage
# skip raspberry beret
# skip on stage
# skip raspberry beret
# skip others
# skip on stage
# skip twilight sparkle and spike
# skip mail pony
# skip mail pony
# skip automated voice
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip automated voice
# skip others
# skip others
# skip automated voice
# skip others
# skip others
# skip automated voice
# skip automated voice
# skip automated voice
# skip automated voice
# skip automated voice
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip starlight glimmer and sunburst
# skip others
# skip others
# New episode started
# skip rest of young six
# skip applejack and rainbow dash
# skip applejack and rainbow dash
# skip rainbow dash and applejack
# New episode started
# skip sweetie belle and scootaloo
# skip apple bloom and scootaloo
# New episode started
# skip tourist pony
# skip tourist pony
# skip tourist pony
# skip tourist pony
# skip tourist pony
# New episode started
# skip students
# skip others
# skip student 2
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip photographer
# skip mean pinkie pie
# skip mean rarity
# skip mean applejack
# skip mean rainbow dash
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean pinkie pie
# skip mean twilight sparkle
# skip mean applejack
# skip mean fluttershy
# skip mean rainbow dash
# skip mean applejack
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean rainbow dash
# skip others
# skip mean pinkie pie
# skip mean applejack
# skip others
# skip mean applejack
# skip mean fluttershy
# skip mean rarity
# skip mean rarity
# skip mean rarity
# skip mean applejack
# skip mean applejack
# skip mean applejack
# skip mean applejack
# skip mean pinkie pie
# skip mean pinkie pie
# skip mean rainbow dash
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip mean rarity
# skip mean rarity
# skip mean applejack
# skip mean applejack
# skip mean applejack
# skip rarity and starlight glimmer
# skip all except twilight sparkle and fluttershy
# skip mean pinkie pie
# skip mean applejack
# skip mean rarity
# skip mean twilight sparkle
# skip mean rarity
# skip mean fluttershy
# skip mean twilight sparkle
# skip mean twilight sparkle
# skip discord 1
# skip discord 2
# skip discord 3
# skip all three discords
# skip discord's ghost
# skip discord's ghost
# skip discord's ghost
# skip discord's ghost
# skip discord's ghost
# skip discord's ghost
# New episode started
# skip others
# skip silverstream and smolder
# skip changelings
# skip yona and family
# skip all but yona
# New episode started
# skip student 1
# skip flim and flam
# skip ponies
# skip flim and flam
# skip others
# skip flim and flam
# skip flim and flam
# skip flim and flam
# skip others
# skip ponies
# skip all
# skip flim and flam
# skip audience pony
# skip student 1
# skip student 1
# skip destitute pony
# skip destitute pony
# skip flim and flam
# skip student 4
# New episode started
# skip bufogren
# skip bufogren
# skip bufogren
# skip bufogren
# skip bufogren
# skip bufogren
# New episode started
# skip daisy
# skip rest of the mane six
# skip rest of the mane six
# skip rest of the mane six
# skip yaks
# skip yaks
# skip yak waiter
# skip yigrid
# skip yigrid
# skip yigrid
# skip applejack and rarity
# skip fluttershy and rainbow dash
# New episode started
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip starlight glimmer and trixie
# skip trxie
# skip starlight glimmer and trixie
# skip hoo'far
# skip starlight glimmer and trixie
# skip starlight glimmer and trixie
# skip starlight glimmer and trixie
# skip starlight glimmer and trixie
# skip starlight glimmer and trixie
# skip starlight glimmer and trixie
# skip starlight glimmer and trixie
# skip mrs. trotsworth
# skip tall pony
# skip short pony
# skip round pony
# skip hoo'far
# skip starlight glimmer and trixie
# skip hoo'far
# skip others
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip others
# skip others
# skip others
# skip others
# skip others
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip hoo'far
# skip starlight glimmer and trixie
# skip hoo'far
# skip hoo'far
# skip others
# New episode started
# skip announcer
# skip announcer
# skip announcer and crowd
# skip fanpony
# skip announcer
# skip rolling thunder
# skip rolling thunder
# skip rolling thunder
# skip rolling thunder
# skip short fuse
# skip short fuse
# skip rolling thunder
# skip rolling thunder
# skip short fuse
# skip short fuse
# skip announcer
# New episode started
# skip professor fossil
# skip professor fossil
# skip professor fossil
# skip professor fossil
# skip professor fossil
# skip professor fossil
# skip flash magnus
# skip flash magnus
# skip flash magnus
# skip mistmane
# skip mistmane
# skip somnambula
# skip mage meabowbrook
# skip mage meabowbrook
# skip seaspray
# skip seaspray
# skip hippogriff sailor
# skip seaspray
# skip seaspray
# skip seaspray
# skip students
# New episode started
# skip illusion twilight sparkle
# skip illusion twilight sparkle
# skip illusion twilight sparkle
# skip illusion twilight sparkle
# skip illusion twilight sparkle
# skip stepford pony 1
# skip stepford pony 2
# skip stepford pony 1
# skip changeling 1
# skip changeling 2
# skip illusion rarity
# skip illusion rainbow dash
# skip illusion rainbow dash
# skip stepford pony 2
# skip stepford pony 1
# skip stepford pony 2
# skip stepford pony 1
# skip illusion rarity
# skip illusion rainbow dash
# skip illusion rarity
# skip illusion rainbow dash
# skip illusion rarity
# skip tree of harmony
# skip tree of harmony
# skip tree of harmony
# New episode started
# skip ticket taker pony
# skip ticket taker pony
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip others
# skip others
# skip others
# skip others
# skip my happy village lay in ruins relationships got worse spoiler alert
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip autumn blaze
# skip rain shine
# skip autumn blaze
# skip others
# skip others
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip others
# skip others
# skip others
# skip others
# skip others
# New episode started
# skip young six sans sandbar
# skip blows
# skip others
# skip others
# skip others
# skip others
# skip young six
# skip rachel platten
# skip others
# skip others
# skip others
# skip others
# skip others
# skip apple cobbler
# skip clear skies
# skip female pony 2
# skip others
# skip others
# skip mane five
# skip others
# skip rainbow dash and wonderbolts
# skip crowd
# skip others
# skip fluttershy and bird whistle
# skip applejack and apple family
# skip apple family
# skip rarity and spike
# skip others
# skip others
# skip all
# skip others
# skip all
# skip code red
# skip songbird serenade
# skip songbird serenade
# skip female pony
# skip songbird serenade
# skip vinny
# skip whinnyfield
# skip party favor
# skip grubber
# skip female pony
# skip grubber
# skip grubber
# skip grubber
# skip grubber
# skip grubber
# skip grubber
# skip grubber
# skip grubber
# skip grubber
# skip pig creature 1
# skip pig creature 2
# skip pig creature 1
# skip vendor 1
# skip vendor 2
# skip pushkin
# skip mori
# skip louise
# skip mane six
# skip vera
# skip deer creature
# skip pig creature 1
# skip pig creature 2
# skip louise
# skip creature 1
# skip deer creature
# skip mori
# skip mori
# skip others
# skip others
# skip others
# skip others
# skip scaly klugetowner
# skip others
# skip others
# skip others
# skip others
# skip others
# skip to needy
# skip others
# skip others
# skip ponies except twilight sparkle
# skip grubber
# skip mori
# skip mori
# skip grubber
# skip mori
# skip verko
# skip grubber
# skip verko
# skip grubber
# skip boyle
# skip boyle
# skip grubber
# skip boyle
# skip mullet
# skip lix spittle
# skip boyle
# skip lix spittle
# skip mullet
# skip mullet
# skip mullet
# skip captain celaeno
# skip mane six
# skip captain celaeno
# skip boyle
# skip captain celaeno
# skip captain celaeno
# skip lix spittle
# skip captain celaeno
# skip mullet
# skip others
# skip others
# skip ponies
# skip captain celaeno
# skip ponies
# skip captain celaeno
# skip captain celaeno
# skip ponies
# skip rainbow dash and captain celaeno
# skip all
# skip mullet
# skip lix spittle
# skip boyle
# skip captain celaeno
# skip all
# skip all
# skip captain celaeno
# skip all
# skip captain celaeno
# skip captain celaeno
# skip grubber
# skip captain celaeno
# skip captain celaeno
# skip captain celaeno
# skip captain celaeno
# skip grubber
# skip grubber
# skip grubber
# skip mane six and spike
# skip queen novo
# skip queen novo
# skip queen novo
# skip queen novo
# skip mane six
# skip queen novo
# skip queen novo
# skip queen novo
# skip queen novo
# skip mane six
# skip queen novo
# skip queen novo
# skip queen novo
# skip queen novo
# skip queen novo
# skip queen novo
# skip others
# skip pinkie pie and princess skystar
# skip others
# skip pinkie pie and princess skystar
# skip others
# skip all
# skip seaponies
# skip seaponies
# skip seaponies
# skip all
# skip all
# skip seaponies
# skip seaponies
# skip seaponies
# skip pinkie pie and princess skystar
# skip princess skystar and seaponies
# skip queen novo
# skip female seapony
# skip queen novo
# skip queen novo
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip rest of the mane six and spike
# skip rest of the mane six and spike
# skip captain celaeno
# skip boyle
# skip captain celaeno
# skip mullet
# skip songbird serenade
# skip grubber
# skip grubber
# skip grubber
# skip captain celaeno
# skip mullet
# skip storm creature
# skip captain celaeno
# skip captain celaeno
# skip everypony else
# skip storm creature
# skip storm creature
# skip mullet
# skip songbird serenade
# skip code red
# skip songbird serenade
# skip others
# skip songbird serenade
# skip songbird serenade
# skip others
# skip songbird serenade
# skip songbird serenade
# skip others
# skip others
# skip others
# skip others
# skip lukas graham
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip alice
# skip others
# skip others
# skip others
# skip ponies
# skip others
# skip ponies
# skip others
# skip ponies
# skip others
# skip others
# skip pinkie pie and applejack
# skip ponies
# skip ponies
# skip ponies
# skip wensley
# skip ponies
# skip others
# skip others
# skip others
# skip ponies
# skip parcel post
# skip others
# skip all
# skip others
# skip limestone pie
# skip limestone pie
# skip marble pie
# skip pony vendor 1
# skip pony vendor 2
# skip others
# skip holly the hearth's warmer doll
# skip butternut
# skip oak nut
# skip butternut
# skip oak nut
# skip butternut
# skip oak nut
# skip pistachio
# skip butternut
# skip oak nut
# skip pistachio
# skip butternut
# skip pistachio
# skip pistachio
# skip shining armor and princess cadance
# skip aurora
# skip aurora
# skip alice
# skip pinkie pie and alice
# skip bori
# skip aurora
# skip bori
# skip alice
# skip others
# skip bori and alice
# skip aurora
# skip bori
# skip alice
# skip bori
# skip aurora
# skip bori
# skip alice
# skip alice
# skip alice
# skip flim and flam
# skip holly the hearth's warmer doll
# skip flim and flam
# skip others
# skip flim and flam
# skip others
# skip flim and flam
# skip butternut
# skip pistachio
# skip pistachio
# skip pistachio
# skip flurry heart
# skip flurry heart
# skip alice
# skip holly the hearth's warmer doll
# skip others
# skip others
# skip others
# skip others
# skip others
# skip others
# skip all
# skip all
# skip all
# skip others
# skip alice
# skip others
# skip others
# skip others

# %%
pos=nx.spring_layout(G)
nx.draw(G,pos)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos,edge_labels=labels)
# Out:
# {('twilight sparkle',
#   'spike'): Text(-0.05893485490705729, 0.07797108995063323, '1514'),
#  ('twilight sparkle',
#   'applejack'): Text(-0.006056318489883146, 0.012489004141223932, '771'),
#  ('twilight sparkle',
#   'apple bloom'): Text(-0.019570384131419205, -0.07373930772161719, '102'),
#  ('twilight sparkle',
#   'rainbow dash'): Text(-0.02806444168540171, -0.01502205500986787, '895'),
#  ('twilight sparkle',
#   'rarity'): Text(-0.006471743531721506, 0.05610947478353978, '649'),
#  ('twilight sparkle',
#   'fluttershy'): Text(-0.022055185907726267, 0.021047622533288443, '677'),
#  ('twilight sparkle',
#   'pinkie pie'): Text(-0.010122998082665268, 0.05785265043207258, '918'),
#  ('twilight sparkle',
#   'mayor mare'): Text(-0.020560411146099102, 0.16607285318753168, '18'),
#  ('twilight sparkle',
#   'nightmare moon'): Text(-0.3292599164613077, -0.027609013756728425, '27'),
#  ('twilight sparkle',
#   'princess celestia'): Text(-0.09051342954264988, 0.07827930991805829, '260'),
#  ('twilight sparkle',
#   'mrs. cake'): Text(0.11005914098702885, 0.08781290874888308, '9'),
#  ('twilight sparkle',
#   'big mcintosh'): Text(0.03178662877460172, -0.04268307489108118, '11'),
#  ('twilight sparkle',
#   'snips'): Text(-0.2180109341953623, -0.14258623530935477, '4'),
#  ('twilight sparkle',
#   'snails'): Text(-0.2467293146537971, -0.11009735802104632, '4'),
#  ('twilight sparkle',
#   'trixie'): Text(-0.13854568163407097, 0.07405114397440507, '69'),
#  ('twilight sparkle',
#   'zecora'): Text(-0.09159359507136985, -0.029793466747641842, '57'),
#  ('twilight sparkle',
#   'scootaloo'): Text(-0.04808042785568748, -0.10376209703558152, '44'),
#  ('twilight sparkle',
#   'diamond tiara'): Text(-0.02597258086078631, -0.20618849855865, '9'),
#  ('twilight sparkle',
#   'hoity toity'): Text(0.2121060794209055, 0.2953952596987978, '2'),
#  ('twilight sparkle',
#   'cheerilee'): Text(0.005159377772431563, -0.13474500001447703, '13'),
#  ('twilight sparkle',
#   'sweetie belle'): Text(-0.0450766387129909, -0.06943663637150291, '65'),
#  ('twilight sparkle',
#   'cutie mark crusaders'): Text(-0.05934662356418574, -0.15900079389614574, '17'),
#  ('twilight sparkle',
#   'rover'): Text(0.1162192999032402, 0.31002664942818753, '1'),
#  ('twilight sparkle',
#   'photo finish'): Text(0.17195342991180362, 0.1531065687816594, '3'),
#  ('twilight sparkle',
#   'mr. cake'): Text(0.1570998923858523, 0.20705900547872863, '2'),
#  ('twilight sparkle',
#   'discord'): Text(-0.08670080538206845, 0.028245185719400066, '149'),
#  ('twilight sparkle',
#   'granny smith'): Text(0.10020813253128608, -0.07844111347125304, '2'),
#  ('twilight sparkle',
#   'pipsqueak'): Text(-0.17841093468986402, -0.18614366003919763, '12'),
#  ('twilight sparkle',
#   'princess luna'): Text(-0.1139900123546605, -0.0002661624910495104, '88'),
#  ('twilight sparkle',
#   'fancy pants'): Text(0.03187329883888063, 0.2971285781217459, '8'),
#  ('twilight sparkle',
#   'flam'): Text(0.17240424260799345, 0.025052907929911144, '15'),
#  ('twilight sparkle',
#   'flim'): Text(0.12991943777086942, 0.02586052821868385, '16'),
#  ('twilight sparkle',
#   'garble'): Text(0.017857545682145738, 0.2155412196199885, '10'),
#  ('twilight sparkle',
#   'bulk biceps'): Text(0.021172207240893415, -0.21074081725435423, '3'),
#  ('twilight sparkle',
#   'shining armor'): Text(-0.14302063626387534, 0.055455622922538576, '120'),
#  ('twilight sparkle',
#   'princess cadance'): Text(-0.10576779067678208, 0.11849906743398068, '143'),
#  ('twilight sparkle',
#   'queen chrysalis'): Text(-0.24740200210525773, 0.25555803053222476, '13'),
#  ('twilight sparkle',
#   'spitfire'): Text(-0.08713828019117634, -0.11881090981963495, '7'),
#  ('twilight sparkle',
#   'ms. peachbottom'): Text(-0.2518359253202545, -0.06353898971354643, '22'),
#  ('twilight sparkle',
#   'daring do'): Text(0.10701042749880832, -0.13598611116548903, '1'),
#  ('twilight sparkle',
#   'soarin'): Text(-0.13682820028239345, -0.1844489827621536, '3'),
#  ('twilight sparkle',
#   'cheese sandwich'): Text(0.1747074644488338, 0.08750240658273006, '3'),
#  ('twilight sparkle',
#   'matilda'): Text(-0.37968406631250456, 0.2832379800211009, '1'),
#  ('twilight sparkle',
#   'silver spoon'): Text(0.020113635389996165, -0.31975101143172957, '4'),
#  ('twilight sparkle',
#   'maud pie'): Text(0.011459828769311162, 0.10773999192039926, '16'),
#  ('twilight sparkle',
#   'lord tirek'): Text(-0.195583307646659, -0.060240961021869835, '23'),
#  ('twilight sparkle',
#   'double diamond'): Text(0.07982241124727826, 0.2673610907553894, '6'),
#  ('twilight sparkle',
#   'starlight glimmer'): Text(-0.0941938890166302, 0.11190643837856698, '432'),
#  ('twilight sparkle',
#   'sugar belle'): Text(0.13887028925216072, -0.03135222610833505, '7'),
#  ('twilight sparkle',
#   'prince rutherford'): Text(0.01605274677251938, 0.14906510017844515, '13'),
#  ('twilight sparkle',
#   'moon dancer'): Text(-0.1267468545154555, 0.26652661490711327, '54'),
#  ('twilight sparkle',
#   'sassy saddles'): Text(0.11436775973681779, 0.1339632166961306, '5'),
#  ('twilight sparkle',
#   'young rainbow dash'): Text(-0.3465817313129082, -0.08122760532419868, '17'),
#  ('twilight sparkle',
#   'sunburst'): Text(-0.1158303034841314, 0.19838929121054033, '40'),
#  ('twilight sparkle',
#   'princess ember'): Text(-0.018410446709524065, 0.33582267827109935, '2'),
#  ('twilight sparkle',
#   'zephyr breeze'): Text(0.057894994387201144, -0.0840298566770883, '4'),
#  ('twilight sparkle',
#   'thorax'): Text(-0.1800764750419935, 0.18626223142190962, '9'),
#  ('twilight sparkle',
#   'vapor trail'): Text(0.15014174063476257, -0.19089351667980659, '12'),
#  ('twilight sparkle',
#   'sky stinger'): Text(0.12049586316850716, -0.24895782102974384, '12'),
#  ('twilight sparkle',
#   'ember'): Text(-0.18800915385767117, 0.2613633176347907, '11'),
#  ('twilight sparkle',
#   'iron will'): Text(-0.0784592166564855, 0.1991148945179183, '25'),
#  ('twilight sparkle',
#   'star swirl the bearded'): Text(-0.01673151532218817, 0.20895112850693298, '37'),
#  ('twilight sparkle',
#   'rockhoof'): Text(-0.21506235112452823, 0.14040310316690296, '36'),
#  ('twilight sparkle',
#   'neighsay'): Text(-0.29222008084166756, 0.1939716466573399, '33'),
#  ('twilight sparkle',
#   'sandbar'): Text(-0.2749310974473905, 0.0100762007941825, '11'),
#  ('twilight sparkle',
#   'silverstream'): Text(-0.3258406324914049, 0.10316908589868733, '13'),
#  ('twilight sparkle',
#   'gallus'): Text(-0.32031565269178125, 0.05634786627051826, '16'),
#  ('twilight sparkle',
#   'smolder'): Text(-0.20592443173908626, 0.08741473582233862, '15'),
#  ('twilight sparkle',
#   'yona'): Text(-0.2781235199191349, 0.1235006895569602, '9'),
#  ('twilight sparkle',
#   'ocellus'): Text(-0.2870112850669469, 0.06627722635290528, '7'),
#  ('twilight sparkle',
#   'cozy glow'): Text(-0.21556359588419552, -0.012791114113404153, '17'),
#  ('twilight sparkle',
#   'chancellor neighsay'): Text(-0.3886715560950709, 0.02251520380998537, '10'),
#  ('twilight sparkle',
#   'lightning dust'): Text(-0.0881848546711955, -0.2001042660049554, '2'),
#  ('twilight sparkle',
#   'sludge'): Text(-0.06736138250256535, 0.2591604613256623, '11'),
#  ('twilight sparkle',
#   'tempest shadow'): Text(0.2402394259529785, 0.10489822733815024, '22'),
#  ('twilight sparkle',
#   'capper'): Text(0.23214927646215308, 0.15299821142016667, '8'),
#  ('twilight sparkle',
#   'princess skystar'): Text(0.2638339534630979, 0.2536932714849158, '9'),
#  ('twilight sparkle',
#   'the storm king'): Text(0.3760150151846175, 0.1707279869406993, '6'),
#  ('spike',
#   'applejack'): Text(-0.002152736876045211, 0.04253583502006542, '238'),
#  ('spike', 'rarity'): Text(-0.0025681619178835706, 0.08615630566238128, '326'),
#  ('spike',
#   'fluttershy'): Text(-0.018151604293888332, 0.05109445341212993, '134'),
#  ('spike',
#   'pinkie pie'): Text(-0.006219416468827333, 0.08789948131091407, '198'),
#  ('spike',
#   'rainbow dash'): Text(-0.024160860071563775, 0.01502477586897362, '179'),
#  ('spike',
#   'mayor mare'): Text(-0.016656829532261167, 0.19611968406637317, '8'),
#  ('spike', 'gilda'): Text(0.09120939637679155, 0.04407432331671996, '1'),
#  ('spike', 'snails'): Text(-0.2428257330399592, -0.08005052714220484, '7'),
#  ('spike', 'snips'): Text(-0.21410735258152436, -0.11253940443051327, '18'),
#  ('spike', 'trixie'): Text(-0.13464210002023302, 0.10409797485324657, '9'),
#  ('spike', 'zecora'): Text(-0.08769001345753191, 0.00025336413119964735, '26'),
#  ('spike',
#   'big mcintosh'): Text(0.035690210388439655, -0.012636244012239693, '56'),
#  ('spike',
#   'cutie mark crusaders'): Text(-0.055443041950347806, -0.12895396301730425, '2'),
#  ('spike',
#   'apple bloom'): Text(-0.01566680251758127, -0.0436924768427757, '36'),
#  ('spike', 'rover'): Text(0.12012288151707813, 0.340073480307029, '4'),
#  ('spike', 'photo finish'): Text(0.17585701152564154, 0.1831533996605009, '1'),
#  ('spike',
#   'sweetie belle'): Text(-0.04117305709915296, -0.03938980549266142, '18'),
#  ('spike', 'mr. cake'): Text(0.16100347399969023, 0.2371058363575701, '2'),
#  ('spike', 'mrs. cake'): Text(0.11396272260086678, 0.11785973962772456, '4'),
#  ('spike', 'cheerilee'): Text(0.009062959386269498, -0.10469816913563554, '6'),
#  ('spike',
#   'scootaloo'): Text(-0.044176846241849546, -0.07371526615674004, '23'),
#  ('spike', 'daring do'): Text(0.11091400911264625, -0.10593928028664756, '1'),
#  ('spike',
#   'princess celestia'): Text(-0.08660984792881193, 0.10832614079689978, '42'),
#  ('spike', 'garble'): Text(0.021761127295983673, 0.24558805049882998, '73'),
#  ('spike', 'rumble'): Text(-0.07940471771918353, -0.2830730116751115, '1'),
#  ('spike',
#   'shining armor'): Text(-0.1391170546500374, 0.08550245380138007, '27'),
#  ('spike',
#   'granny smith'): Text(0.104111714145124, -0.048394282592411554, '9'),
#  ('spike', 'discord'): Text(-0.08279722376823051, 0.058292016598241556, '166'),
#  ('spike', 'matilda'): Text(-0.3757804846986666, 0.31328481089994237, '1'),
#  ('spike',
#   'princess cadance'): Text(-0.10186420906294413, 0.14854589831282217, '47'),
#  ('spike',
#   'lord tirek'): Text(-0.19167972603282107, -0.030194130143028346, '4'),
#  ('spike', 'fancy pants'): Text(0.03577688045271857, 0.3271754090005874, '14'),
#  ('spike',
#   'moon dancer'): Text(-0.12284327290161756, 0.29657344578595474, '1'),
#  ('spike',
#   'princess luna'): Text(-0.11008643074082256, 0.02978066838779198, '7'),
#  ('spike', 'derpy'): Text(-0.10692348248636864, 0.38422442664746875, '2'),
#  ('spike',
#   'starlight glimmer'): Text(-0.09029030740279226, 0.14195326925740848, '194'),
#  ('spike',
#   'young rainbow dash'): Text(-0.34267814969907023, -0.05118077444535719, '2'),
#  ('spike',
#   'nightmare moon'): Text(-0.32535633484746973, 0.0024378171221130646, '4'),
#  ('spike', 'sunburst'): Text(-0.11192672187029346, 0.2284361220893818, '15'),
#  ('spike',
#   'princess ember'): Text(-0.01450686509568613, 0.3658695091499408, '34'),
#  ('spike',
#   'zephyr breeze'): Text(0.06179857600103908, -0.05398302579824681, '1'),
#  ('spike', 'thorax'): Text(-0.17617289342815556, 0.2163090623007511, '51'),
#  ('spike', 'ember'): Text(-0.18410557224383323, 0.2914101485136322, '32'),
#  ('spike',
#   'sweetie drops'): Text(0.35307762023603484, 0.02095301130778523, '1'),
#  ('spike', 'neighsay'): Text(-0.2883164992278296, 0.22401847753618137, '2'),
#  ('spike', 'gallus'): Text(-0.3164120710779433, 0.08639469714935974, '3'),
#  ('spike',
#   'sugar belle'): Text(0.14277387086599863, -0.001305395229493564, '3'),
#  ('spike', 'smolder'): Text(-0.20202085012524834, 0.1174615667011801, '56'),
#  ('spike', 'silverstream'): Text(-0.3219370508775669, 0.1332159167775288, '2'),
#  ('spike',
#   'cranky doodle donkey'): Text(-0.15798220616971564, 0.18211216090801102, '1'),
#  ('spike', 'sandbar'): Text(-0.27102751583355256, 0.04012303167302399, '1'),
#  ('spike', 'rockhoof'): Text(-0.2111587695106903, 0.17044993404574446, '5'),
#  ('spike', 'yona'): Text(-0.274219938305297, 0.1535475204358017, '3'),
#  ('spike', 'ocellus'): Text(-0.2831077034531089, 0.09632405723174678, '2'),
#  ('spike', 'sludge'): Text(-0.0634578008887274, 0.28920729220450375, '44'),
#  ('spike', 'cozy glow'): Text(-0.21166001427035758, 0.017255716765437336, '2'),
#  ('spike',
#   'chancellor neighsay'): Text(-0.38476797448123295, 0.052562034688826864, '1'),
#  ('spike',
#   'tempest shadow'): Text(0.24414300756681645, 0.13494505821699174, '3'),
#  ('spike', 'capper'): Text(0.23605285807599102, 0.18304504229900817, '4'),
#  ('spike',
#   'princess skystar'): Text(0.2677375350769359, 0.2837401023637573, '1'),
#  ('applejack',
#   'granny smith'): Text(0.15699025056229815, -0.11387636840182085, '139'),
#  ('applejack',
#   'pinkie pie'): Text(0.04665911994834682, 0.022417395501504775, '569'),
#  ('applejack',
#   'rainbow dash'): Text(0.02871767634561037, -0.05045730994043567, '666'),
#  ('applejack',
#   'nightmare moon'): Text(-0.2724777984302956, -0.06304426868729623, '1'),
#  ('applejack',
#   'mayor mare'): Text(0.03622170688491298, 0.1306375982569639, '13'),
#  ('applejack',
#   'rarity'): Text(0.05031037449929057, 0.02067421985297198, '730'),
#  ('applejack',
#   'fluttershy'): Text(0.034726932123285814, -0.01438763239727936, '389'),
#  ('applejack',
#   'princess celestia'): Text(-0.033731311511637795, 0.042844054987490485, '16'),
#  ('applejack',
#   'big mcintosh'): Text(0.0885687468056138, -0.07811832982164899, '92'),
#  ('applejack', 'mr. cake'): Text(0.2138820104168644, 0.17162375054816081, '2'),
#  ('applejack',
#   'mrs. cake'): Text(0.16684125901804092, 0.05237765381831527, '6'),
#  ('applejack', 'gilda'): Text(0.1440879327939657, -0.02140776249268933, '1'),
#  ('applejack',
#   'trixie'): Text(-0.08176356360305888, 0.03861588904383727, '10'),
#  ('applejack',
#   'apple bloom'): Text(0.037211733899592876, -0.10917456265218499, '428'),
#  ('applejack',
#   'zecora'): Text(-0.03481147704035777, -0.06522872167820964, '14'),
#  ('applejack',
#   'diamond tiara'): Text(0.030809537170225772, -0.2416237534892178, '2'),
#  ('applejack',
#   'hoity toity'): Text(0.2688881974519176, 0.25996000476823, '13'),
#  ('applejack',
#   'sweetie belle'): Text(0.011705479318021185, -0.10487189130207071, '51'),
#  ('applejack',
#   'scootaloo'): Text(0.0087016901753246, -0.13919735196614932, '46'),
#  ('applejack',
#   'cutie mark crusaders'): Text(-0.0025645055331736596, -0.19443604882671353, '8'),
#  ('applejack', 'snips'): Text(-0.16122881616435022, -0.17802149023992256, '1'),
#  ('applejack',
#   'braeburn'): Text(0.26773634672789254, -0.10013507172462525, '36'),
#  ('applejack',
#   'young applejack'): Text(0.39137162548102056, -0.22502112303203814, '2'),
#  ('applejack', 'soarin'): Text(-0.08004608225138138, -0.2198842376927214, '4'),
#  ('applejack',
#   'spitfire'): Text(-0.030356162160164263, -0.15424616475020275, '2'),
#  ('applejack',
#   'discord'): Text(-0.02991868735105637, -0.007190069211167737, '41'),
#  ('applejack',
#   'princess luna'): Text(-0.05720789432364841, -0.03570141742161732, '14'),
#  ('applejack',
#   'pipsqueak'): Text(-0.12162881665885195, -0.22157891496976545, '1'),
#  ('applejack', 'flim'): Text(0.1867015558018815, -0.009574726711883953, '36'),
#  ('applejack', 'flam'): Text(0.22918636063900552, -0.010382347000656659, '19'),
#  ('applejack',
#   'shining armor'): Text(-0.08623851823286326, 0.020020367991970774, '8'),
#  ('applejack',
#   'princess cadance'): Text(-0.04898567264576999, 0.08306381250341288, '8'),
#  ('applejack',
#   'queen chrysalis'): Text(-0.19061988407424565, 0.22012277560165697, '2'),
#  ('applejack',
#   'babs seed'): Text(0.07099713312718525, -0.2951743912325606, '9'),
#  ('applejack',
#   'lightning dust'): Text(-0.03140273664018342, -0.2355395209355232, '2'),
#  ('applejack',
#   'ms. peachbottom'): Text(-0.19505380728924243, -0.09897424464411424, '4'),
#  ('applejack',
#   'goldie delicious'): Text(0.26562202650847155, -0.16860323964042304, '16'),
#  ('applejack',
#   'bulk biceps'): Text(0.07795432527190549, -0.24617607218492205, '1'),
#  ('applejack',
#   'maud pie'): Text(0.06824194680032325, 0.07230473698983146, '13'),
#  ('applejack',
#   'lord tirek'): Text(-0.1388011896156469, -0.09567621595243764, '4'),
#  ('applejack',
#   'double diamond'): Text(0.13660452927829037, 0.23192583582482157, '3'),
#  ('applejack',
#   'starlight glimmer'): Text(-0.03741177098561811, 0.07647118344799918, '58'),
#  ('applejack',
#   'sugar belle'): Text(0.1956524072831728, -0.06678748103890286, '5'),
#  ('applejack',
#   'trouble shoes'): Text(-0.11187878648069877, -0.3814241690028011, '2'),
#  ('applejack',
#   'prince rutherford'): Text(0.07283486480353146, 0.11362984524787736, '3'),
#  ('applejack',
#   'sassy saddles'): Text(0.17114987776782986, 0.0985279617655628, '3'),
#  ('applejack',
#   'cheerilee'): Text(0.061941495803443644, -0.17018025494504482, '3'),
#  ('applejack',
#   'snails'): Text(-0.18994719662278503, -0.14553261295161413, '6'),
#  ('applejack',
#   'gladmane'): Text(0.3379183006397526, -0.040970239840872426, '16'),
#  ('applejack',
#   'filthy rich'): Text(0.37124148743560814, -0.2728678039514145, '3'),
#  ('applejack',
#   'photo finish'): Text(0.2287355479428157, 0.11767131385109161, '10'),
#  ('applejack',
#   'rockhoof'): Text(-0.15828023309351616, 0.10496784823633516, '12'),
#  ('applejack',
#   'sunburst'): Text(-0.05904818545311931, 0.16295403627997251, '3'),
#  ('applejack',
#   'star swirl the bearded'): Text(0.04005060270882391, 0.17351587357636516, '2'),
#  ('applejack', 'yona'): Text(-0.22134140188812285, 0.0880654346263924, '7'),
#  ('applejack',
#   'smolder'): Text(-0.14914231370807418, 0.05197948089177082, '9'),
#  ('applejack', 'gallus'): Text(-0.2635335346607691, 0.020912611339950454, '7'),
#  ('applejack', 'ocellus'): Text(-0.2302291670359348, 0.03084197142233748, '3'),
#  ('applejack',
#   'silverstream'): Text(-0.26905851446039275, 0.06773383096811952, '5'),
#  ('applejack',
#   'sandbar'): Text(-0.21814897941637842, -0.025359054136385305, '3'),
#  ('applejack', 'sludge'): Text(-0.01057926447155326, 0.22372520639509447, '3'),
#  ('applejack',
#   'cozy glow'): Text(-0.15878147785318344, -0.048226369043971956, '1'),
#  ('applejack', 'capper'): Text(0.2889313944931652, 0.11756295648959889, '5'),
#  ('applejack',
#   'princess skystar'): Text(0.32061607149411, 0.218258016554348, '3'),
#  ('applejack',
#   'the storm king'): Text(0.4327971332156296, 0.13529273201013148, '1'),
#  ('applejack',
#   'tempest shadow'): Text(0.2970215439839906, 0.06946297240758244, '1'),
#  ('granny smith',
#   'rainbow dash'): Text(0.1349821273667796, -0.14138742755291264, '32'),
#  ('granny smith',
#   'gilda'): Text(0.2503523838151349, -0.11233788010516631, '1'),
#  ('granny smith',
#   'apple bloom'): Text(0.14347618492076208, -0.20010468026466197, '112'),
#  ('granny smith',
#   'pipsqueak'): Text(-0.015364365637682731, -0.31250903258224244, '1'),
#  ('granny smith',
#   'sweetie belle'): Text(0.1179699303391904, -0.1958020089145477, '11'),
#  ('granny smith',
#   'big mcintosh'): Text(0.19483319782678302, -0.16904844743412595, '21'),
#  ('granny smith',
#   'filthy rich'): Text(0.47750593845677736, -0.3637979215638915, '13'),
#  ('granny smith',
#   'diamond tiara'): Text(0.137073988191395, -0.33255387110169476, '4'),
#  ('granny smith',
#   'silver spoon'): Text(0.18316020444217745, -0.4461163839747744, '2'),
#  ('granny smith',
#   'scootaloo'): Text(0.11496614119649382, -0.2301274695786263, '7'),
#  ('granny smith',
#   'cheerilee'): Text(0.16820594682461287, -0.2611103725575218, '5'),
#  ('granny smith',
#   'flam'): Text(0.33545081166017476, -0.10131246461313363, '8'),
#  ('granny smith',
#   'flim'): Text(0.29296600682305074, -0.10050484432436092, '10'),
#  ('granny smith',
#   'mayor mare'): Text(0.14248615790608218, 0.03970748064448691, '1'),
#  ('granny smith', 'rarity'): Text(0.1565748255204598, -0.070255897759505, '2'),
#  ('granny smith',
#   'babs seed'): Text(0.17726158414835447, -0.3861045088450376, '1'),
#  ('granny smith',
#   'pinkie pie'): Text(0.15292357096951603, -0.0685127221109722, '17'),
#  ('granny smith',
#   'goldie delicious'): Text(0.37188647752964077, -0.2595333572529, '7'),
#  ('granny smith',
#   'maud pie'): Text(0.17450639782149246, -0.018625380622645515, '2'),
#  ('granny smith',
#   'fluttershy'): Text(0.14099138314445503, -0.10531775000975634, '11'),
#  ('granny smith',
#   'young applejack'): Text(0.4976360765021898, -0.31595124064451513, '44'),
#  ('granny smith',
#   'young big mcintosh'): Text(0.6316273507917337, -0.3981595556321123, '6'),
#  ('granny smith',
#   'starlight glimmer'): Text(0.0688526800355511, -0.014458934164477799, '4'),
#  ('granny smith',
#   'trixie'): Text(0.024500887418110337, -0.05231422856863971, '9'),
#  ('granny smith',
#   'bulk biceps'): Text(0.1842187762930747, -0.33710618979739904, '2'),
#  ('apple bloom',
#   'rainbow dash'): Text(0.015203610704074312, -0.13668562180327679, '35'),
#  ('apple bloom',
#   'zecora'): Text(-0.04832554268189383, -0.15145703354105078, '27'),
#  ('apple bloom',
#   'diamond tiara'): Text(0.017295471528689713, -0.3278520653520589, '56'),
#  ('apple bloom',
#   'cheerilee'): Text(0.048427430161907585, -0.25640856680788593, '50'),
#  ('apple bloom',
#   'silver spoon'): Text(0.06338168777947219, -0.4414145782251385, '17'),
#  ('apple bloom',
#   'sweetie drops'): Text(0.39244209101167293, -0.13075738636446518, '2'),
#  ('apple bloom',
#   'pinkie pie'): Text(0.03314505430681076, -0.06381091636133635, '45'),
#  ('apple bloom',
#   'scootaloo'): Text(-0.004812375466211457, -0.22542566382899043, '487'),
#  ('apple bloom',
#   'sweetie belle'): Text(-0.001808586323514872, -0.19110020316491183, '467'),
#  ('apple bloom',
#   'big mcintosh'): Text(0.07505468116407775, -0.1643466416844901, '127'),
#  ('apple bloom',
#   'fluttershy'): Text(0.021212866481749755, -0.10061594426012048, '23'),
#  ('apple bloom',
#   'cutie mark crusaders'): Text(-0.01607857117470972, -0.28066436068955464, '26'),
#  ('apple bloom',
#   'mayor mare'): Text(0.022707641243376923, 0.04440928639412277, '8'),
#  ('apple bloom',
#   'rarity'): Text(0.03679630885775452, -0.06555409200986914, '18'),
#  ('apple bloom', 'flam'): Text(0.21567229499746945, -0.09661065886349778, '3'),
#  ('apple bloom', 'flim'): Text(0.17318749016034543, -0.09580303857472507, '7'),
#  ('apple bloom',
#   'snips'): Text(-0.1747428818058863, -0.26424980210276366, '1'),
#  ('apple bloom',
#   'babs seed'): Text(0.057483067485649186, -0.38140270309540175, '42'),
#  ('apple bloom',
#   'goldie delicious'): Text(0.25210796086693554, -0.25483155150326414, '6'),
#  ('apple bloom',
#   'princess luna'): Text(-0.07072195996518446, -0.12192972928445843, '15'),
#  ('apple bloom',
#   'braeburn'): Text(0.25422228108635647, -0.18636338358746637, '1'),
#  ('apple bloom',
#   'trouble shoes'): Text(-0.12539285212223483, -0.4676524808656422, '19'),
#  ('apple bloom',
#   'pipsqueak'): Text(-0.135142882300388, -0.3078072268326066, '13'),
#  ('apple bloom',
#   'maud pie'): Text(0.054727881158787184, -0.013923574873009659, '6'),
#  ('apple bloom',
#   'mrs. cake'): Text(0.15332719337650486, -0.03385065804452585, '7'),
#  ('apple bloom',
#   'bulk biceps'): Text(0.06444025963036944, -0.3324043840477632, '2'),
#  ('apple bloom',
#   'gabby'): Text(0.0059578645392736555, -0.4428097312278334, '17'),
#  ('apple bloom',
#   'bow hothoof'): Text(-0.08370510514421499, -0.48044950625542543, '3'),
#  ('apple bloom',
#   'windy whistles'): Text(-0.16588747975207171, -0.4296353746354988, '1'),
#  ('apple bloom',
#   'sugar belle'): Text(0.18213834164163673, -0.15301579290174397, '4'),
#  ('apple bloom',
#   'starlight glimmer'): Text(-0.05092583662715417, -0.009757128414841942, '4'),
#  ('apple bloom',
#   'rockhoof'): Text(-0.17179429873505223, 0.018739536373494042, '1'),
#  ('apple bloom',
#   'rumble'): Text(-0.040040246943545445, -0.4347834093473619, '12'),
#  ('apple bloom',
#   'discord'): Text(-0.04343275299259243, -0.09341838107400885, '3'),
#  ('apple bloom',
#   'cozy glow'): Text(-0.1722955434947195, -0.13445468090681306, '14'),
#  ('apple bloom',
#   'chancellor neighsay'): Text(-0.34540350370559486, -0.09914836298342355, '1'),
#  ('apple bloom',
#   'sandbar'): Text(-0.2316630450579145, -0.11158736599922642, '6'),
#  ('apple bloom',
#   'smolder'): Text(-0.16265637934961025, -0.0342488309710703, '1'),
#  ('rainbow dash',
#   'nightmare moon'): Text(-0.29448592162581416, -0.09055532783838803, '4'),
#  ('rainbow dash',
#   'fluttershy'): Text(0.01271880892776725, -0.04189869154837116, '530'),
#  ('rainbow dash',
#   'rarity'): Text(0.02830225130377201, -0.006836839298119825, '506'),
#  ('rainbow dash',
#   'pinkie pie'): Text(0.02465099675282825, -0.005093663649587028, '696'),
#  ('rainbow dash',
#   'sweetie drops'): Text(0.3839480334576904, -0.07204013365271586, '1'),
#  ('rainbow dash',
#   'gilda'): Text(0.12207980959844714, -0.048918821643781134, '56'),
#  ('rainbow dash',
#   'trixie'): Text(-0.10377168679857744, 0.011104829892745464, '18'),
#  ('rainbow dash',
#   'zecora'): Text(-0.05681960023587634, -0.09273978082930145, '5'),
#  ('rainbow dash',
#   'princess celestia'): Text(-0.05573943470715636, 0.015332995836398682, '17'),
#  ('rainbow dash',
#   'mayor mare'): Text(0.014213583689394415, 0.10312653910587208, '6'),
#  ('rainbow dash',
#   'diamond tiara'): Text(0.008801413974707207, -0.2691348126403096, '3'),
#  ('rainbow dash',
#   'silver spoon'): Text(0.05488763022548968, -0.3826973255133892, '2'),
#  ('rainbow dash',
#   'spitfire'): Text(-0.05236428535568283, -0.18175722390129456, '136'),
#  ('rainbow dash',
#   'braeburn'): Text(0.24572822353237397, -0.12764613087571705, '6'),
#  ('rainbow dash',
#   'scootaloo'): Text(-0.013306433020193964, -0.16670841111724113, '221'),
#  ('rainbow dash',
#   'young rainbow dash'): Text(-0.31180773647741467, -0.14417391940585828, '4'),
#  ('rainbow dash',
#   'cutie mark crusaders'): Text(-0.024572628728692224, -0.22194710797780534, '11'),
#  ('rainbow dash',
#   'soarin'): Text(-0.10205420544689994, -0.2473952968438132, '43'),
#  ('rainbow dash',
#   'discord'): Text(-0.051926810546574935, -0.03470112836225954, '95'),
#  ('rainbow dash',
#   'snips'): Text(-0.1832369393598688, -0.20553254939101437, '3'),
#  ('rainbow dash',
#   'mr. cake'): Text(0.19187388722134582, 0.144112691397069, '3'),
#  ('rainbow dash',
#   'derpy'): Text(-0.07605306926471306, 0.29123128168696766, '6'),
#  ('rainbow dash',
#   'flam'): Text(0.20717823744348696, -0.03789340615174846, '2'),
#  ('rainbow dash',
#   'flim'): Text(0.16469343260636293, -0.037085785862975756, '3'),
#  ('rainbow dash',
#   'daring do'): Text(0.14178442233430183, -0.19893242524714866, '52'),
#  ('rainbow dash',
#   'bulk biceps'): Text(0.05594620207638693, -0.27368713133601386, '14'),
#  ('rainbow dash',
#   'rumble'): Text(-0.04853430449752795, -0.3760661566356126, '1'),
#  ('rainbow dash',
#   'mrs. cake'): Text(0.14483313582252236, 0.02486659466722347, '3'),
#  ('rainbow dash',
#   'sweetie belle'): Text(-0.01030264387749738, -0.1323829504531625, '21'),
#  ('rainbow dash',
#   'princess luna'): Text(-0.07921601751916697, -0.06321247657270912, '12'),
#  ('rainbow dash',
#   'shining armor'): Text(-0.10824664142838182, -0.0074906911591210296, '12'),
#  ('rainbow dash',
#   'lightning dust'): Text(-0.053410859835701985, -0.26305058008661497, '60'),
#  ('rainbow dash',
#   'princess cadance'): Text(-0.07099379584128855, 0.05555275335232108, '9'),
#  ('rainbow dash',
#   'ms. peachbottom'): Text(-0.217061930484761, -0.12648530379520603, '12'),
#  ('rainbow dash',
#   'dr. caballeron'): Text(0.2022770481747892, -0.375849689809338, '15'),
#  ('rainbow dash',
#   'cheese sandwich'): Text(0.20948145928432732, 0.024556092501070458, '13'),
#  ('rainbow dash',
#   'maud pie'): Text(0.04623382360480468, 0.04479367783873966, '13'),
#  ('rainbow dash',
#   'lord tirek'): Text(-0.16080931281116548, -0.12318727510352945, '4'),
#  ('rainbow dash',
#   'double diamond'): Text(0.11459640608277179, 0.20441477667372976, '7'),
#  ('rainbow dash',
#   'starlight glimmer'): Text(-0.059419894181136676, 0.048960124296907374, '72'),
#  ('rainbow dash',
#   'sugar belle'): Text(0.17364428408765423, -0.09429854018999466, '5'),
#  ('rainbow dash',
#   'matilda'): Text(-0.344910071477011, 0.22029166593944127, '1'),
#  ('rainbow dash',
#   'filthy rich'): Text(0.3492333642400896, -0.30037886310250633, '3'),
#  ('rainbow dash',
#   'sassy saddles'): Text(0.1491417545723113, 0.071016902614471, '3'),
#  ('rainbow dash',
#   'big mcintosh'): Text(0.06656062361009524, -0.1056293889727408, '6'),
#  ('rainbow dash',
#   'sunburst'): Text(-0.08105630864863787, 0.1354429771288807, '1'),
#  ('rainbow dash',
#   'zephyr breeze'): Text(0.09266898922269466, -0.14697617075874791, '32'),
#  ('rainbow dash',
#   'quibble pants'): Text(0.11901903698880006, -0.2502723472820849, '72'),
#  ('rainbow dash',
#   'cheerilee'): Text(0.03993337260792508, -0.19769131409613663, '4'),
#  ('rainbow dash',
#   'snails'): Text(-0.2119553198183036, -0.17304367210270594, '5'),
#  ('rainbow dash',
#   'sky stinger'): Text(0.15526985800400067, -0.31190413511140347, '17'),
#  ('rainbow dash',
#   'vapor trail'): Text(0.18491573547025608, -0.25383983076146616, '24'),
#  ('rainbow dash',
#   'bow hothoof'): Text(-0.0921991626981975, -0.4217322535436761, '7'),
#  ('rainbow dash',
#   'windy whistles'): Text(-0.1743815373060542, -0.37091812192374946, '10'),
#  ('rainbow dash',
#   'garble'): Text(0.052631540517639255, 0.15259490553832888, '12'),
#  ('rainbow dash',
#   'star swirl the bearded'): Text(0.018042479513305346, 0.14600481442527335, '6'),
#  ('rainbow dash',
#   'sandbar'): Text(-0.240157102611897, -0.05287011328747711, '10'),
#  ('rainbow dash',
#   'gallus'): Text(-0.2855416578562877, -0.006598447811141349, '5'),
#  ('rainbow dash',
#   'goldie delicious'): Text(0.24361390331295302, -0.19611429879151485, '12'),
#  ('rainbow dash',
#   'silverstream'): Text(-0.29106663765591134, 0.04022277181702772, '5'),
#  ('rainbow dash',
#   'ocellus'): Text(-0.25223729023145336, 0.003330912271245677, '13'),
#  ('rainbow dash', 'yona'): Text(-0.2433495250836414, 0.06055437547530059, '7'),
#  ('rainbow dash',
#   'smolder'): Text(-0.17115043690359275, 0.024468421740679015, '8'),
#  ('rainbow dash',
#   'rockhoof'): Text(-0.18028835628903472, 0.07745678908524337, '1'),
#  ('rainbow dash',
#   'cozy glow'): Text(-0.180789601048702, -0.07573742819506377, '1'),
#  ('rainbow dash',
#   'tempest shadow'): Text(0.275013420788472, 0.041951913256490635, '3'),
#  ('rainbow dash',
#   'capper'): Text(0.2669232712976466, 0.09005189733850708, '7'),
#  ('rarity', 'mayor mare'): Text(0.03580628184307462, 0.17425806889927975, '5'),
#  ('rarity',
#   'pinkie pie'): Text(0.046243694906508453, 0.06603786614382062, '483'),
#  ('rarity',
#   'fluttershy'): Text(0.03431150708144745, 0.029232838245036488, '492'),
#  ('rarity', 'gilda'): Text(0.14367250775212734, 0.022212708149626517, '1'),
#  ('rarity', 'trixie'): Text(-0.08217898864489724, 0.08223635968615312, '8'),
#  ('rarity', 'zecora'): Text(-0.03522690208219613, -0.021608251035893797, '44'),
#  ('rarity', 'hoity toity'): Text(0.2684727724100792, 0.30358047541054584, '8'),
#  ('rarity',
#   'princess celestia'): Text(-0.03414673655347615, 0.08646452562980633, '19'),
#  ('rarity',
#   'sweetie belle'): Text(0.011290054276182826, -0.06125142065975486, '288'),
#  ('rarity',
#   'cutie mark crusaders'): Text(-0.0029799305750120193, -0.15081557818439767, '7'),
#  ('rarity', 'rover'): Text(0.17258599289241391, 0.31821186513993555, '34'),
#  ('rarity',
#   'photo finish'): Text(0.22832012290097733, 0.16129178449340748, '26'),
#  ('rarity',
#   'sweetie drops'): Text(0.4055407316113706, -0.0009086038593082157, '6'),
#  ('rarity',
#   'scootaloo'): Text(0.00828626513348624, -0.09557688132383348, '16'),
#  ('rarity', 'discord'): Text(-0.03033411239289473, 0.03643040143114811, '19'),
#  ('rarity',
#   'fancy pants'): Text(0.08823999182805435, 0.30531379383349394, '26'),
#  ('rarity', 'mr. cake'): Text(0.21346658537502602, 0.21524422119047665, '1'),
#  ('rarity',
#   'iron will'): Text(-0.022092523667311775, 0.20730011022966632, '4'),
#  ('rarity', 'garble'): Text(0.07422423867131946, 0.22372643533173653, '3'),
#  ('rarity',
#   'princess cadance'): Text(-0.04940109768760835, 0.12668428314572872, '20'),
#  ('rarity',
#   'shining armor'): Text(-0.08665394327470162, 0.06364083863428663, '11'),
#  ('rarity',
#   'lightning dust'): Text(-0.031818161682021784, -0.19191905029320733, '1'),
#  ('rarity',
#   'ms. peachbottom'): Text(-0.1954692323310808, -0.05535377400179839, '1'),
#  ('rarity',
#   'bulk biceps'): Text(0.07753890023006714, -0.2025556015426062, '2'),
#  ('rarity',
#   'big mcintosh'): Text(0.08815332176377544, -0.03449785917933314, '10'),
#  ('rarity', 'maud pie'): Text(0.06782652175848489, 0.11592520763214731, '54'),
#  ('rarity', 'cheerilee'): Text(0.06152607076160528, -0.12655978430272896, '5'),
#  ('rarity',
#   'princess luna'): Text(-0.05762331936548677, 0.007919053220698535, '10'),
#  ('rarity',
#   'sugar belle'): Text(0.19523698224133443, -0.023167010396587008, '2'),
#  ('rarity',
#   'starlight glimmer'): Text(-0.037827196027456475, 0.12009165409031503, '72'),
#  ('rarity',
#   'double diamond'): Text(0.136189104236452, 0.2755463064671374, '1'),
#  ('rarity',
#   'prince rutherford'): Text(0.0724194397616931, 0.15725031589019323, '1'),
#  ('rarity',
#   'sassy saddles'): Text(0.1707344527259915, 0.14214843240787867, '83'),
#  ('rarity', 'spitfire'): Text(-0.030771587202002623, -0.1106256941078869, '1'),
#  ('rarity', 'soarin'): Text(-0.08046150729321974, -0.17626376705040553, '3'),
#  ('rarity',
#   'princess ember'): Text(0.03795624627964966, 0.34400789398284737, '5'),
#  ('rarity',
#   'zephyr breeze'): Text(0.11426168737637486, -0.07584464096534026, '10'),
#  ('rarity', 'filthy rich'): Text(0.3708260623937698, -0.2292473333090987, '3'),
#  ('rarity',
#   'star swirl the bearded'): Text(0.03963517766698555, 0.217136344218681, '6'),
#  ('rarity', 'sunburst'): Text(-0.05946361049495767, 0.20657450692228835, '1'),
#  ('rarity', 'rockhoof'): Text(-0.15869565813535452, 0.148588318878651, '6'),
#  ('rarity', 'sandbar'): Text(-0.2185644044582168, 0.018261416505930543, '2'),
#  ('rarity', 'gallus'): Text(-0.2639489597026075, 0.0645330819822663, '2'),
#  ('rarity',
#   'queen chrysalis'): Text(-0.19103530911608402, 0.26374324624397283, '1'),
#  ('rarity',
#   'cozy glow'): Text(-0.1591969028950218, -0.004605898401656108, '6'),
#  ('rarity', 'smolder'): Text(-0.14955773874991254, 0.09559995153408667, '3'),
#  ('rarity', 'flam'): Text(0.22877093559716716, 0.03323812364165919, '9'),
#  ('rarity',
#   'chancellor neighsay'): Text(-0.3323048631058972, 0.030700419521733417, '3'),
#  ('rarity', 'flim'): Text(0.18628613076004313, 0.034045743930431895, '5'),
#  ('rarity', 'sludge'): Text(-0.01099468951339162, 0.2673456770374103, '4'),
#  ('rarity',
#   'lord tirek'): Text(-0.13921661465748528, -0.05205574531012179, '1'),
#  ('rarity', 'capper'): Text(0.2885159694513268, 0.16118342713191475, '9'),
#  ('rarity',
#   'tempest shadow'): Text(0.2966061189421522, 0.11308344304989829, '3'),
#  ('rarity',
#   'princess skystar'): Text(0.32020064645227164, 0.26187848719666385, '2'),
#  ('rarity', 'derpy'): Text(-0.05446037111103286, 0.3623628114803753, '16'),
#  ('fluttershy',
#   'mayor mare'): Text(0.020222839467069858, 0.1391962166490284, '2'),
#  ('fluttershy',
#   'pinkie pie'): Text(0.030660252530503692, 0.030976013893569285, '340'),
#  ('fluttershy',
#   'gilda'): Text(0.12808906537612258, -0.012849144100624817, '7'),
#  ('fluttershy',
#   'big mcintosh'): Text(0.07256987938777068, -0.06955971142958448, '4'),
#  ('fluttershy',
#   'cutie mark crusaders'): Text(-0.01856337295101678, -0.18587743043464902, '15'),
#  ('fluttershy',
#   'sweetie belle'): Text(-0.004293388099821936, -0.0963132729100062, '31'),
#  ('fluttershy',
#   'scootaloo'): Text(-0.007297177242518521, -0.13063873357408481, '29'),
#  ('fluttershy',
#   'photo finish'): Text(0.21273668052497258, 0.12622993224315612, '16'),
#  ('fluttershy',
#   'braeburn'): Text(0.2517374793100494, -0.09157645333256074, '3'),
#  ('fluttershy',
#   'princess celestia'): Text(-0.049730178929480916, 0.051402673379554994, '32'),
#  ('fluttershy',
#   'young rainbow dash'): Text(-0.30579848069973925, -0.10810424186270197, '1'),
#  ('fluttershy',
#   'discord'): Text(-0.04591755476889949, 0.0013685491808967756, '180'),
#  ('fluttershy',
#   'princess luna'): Text(-0.07320676174149153, -0.027142799029552803, '21'),
#  ('fluttershy',
#   'iron will'): Text(-0.037675966043316536, 0.172238257979415, '26'),
#  ('fluttershy',
#   'shining armor'): Text(-0.10223738565070638, 0.028578986384035283, '4'),
#  ('fluttershy',
#   'snips'): Text(-0.17722768358219335, -0.16946287184785805, '1'),
#  ('fluttershy',
#   'ms. peachbottom'): Text(-0.21105267470708555, -0.09041562625204973, '5'),
#  ('fluttershy',
#   'dr. caballeron'): Text(0.20828630395246464, -0.33978001226618165, '1'),
#  ('fluttershy',
#   'daring do'): Text(0.14779367811197727, -0.16286274770399234, '2'),
#  ('fluttershy',
#   'bulk biceps'): Text(0.061955457854062375, -0.23761745379285754, '10'),
#  ('fluttershy',
#   'spitfire'): Text(-0.046355029578007384, -0.14568754635813824, '1'),
#  ('fluttershy',
#   'soarin'): Text(-0.0960449496692245, -0.21132561930065688, '1'),
#  ('fluttershy',
#   'cheese sandwich'): Text(0.21549071506200276, 0.06062577004422677, '2'),
#  ('fluttershy',
#   'zecora'): Text(-0.050810344458200894, -0.056670103286145135, '27'),
#  ('fluttershy',
#   'mr. cake'): Text(0.19788314299902127, 0.18018236894022532, '5'),
#  ('fluttershy',
#   'mrs. cake'): Text(0.1508423916001978, 0.06093627221037978, '2'),
#  ('fluttershy',
#   'maud pie'): Text(0.05224307938248012, 0.08086335538189597, '6'),
#  ('fluttershy',
#   'lord tirek'): Text(-0.15480005703349003, -0.08711759756037313, '4'),
#  ('fluttershy',
#   'double diamond'): Text(0.12060566186044723, 0.24048445421688608, '2'),
#  ('fluttershy',
#   'sugar belle'): Text(0.17965353986532967, -0.058228862646838346, '2'),
#  ('fluttershy',
#   'starlight glimmer'): Text(-0.05341063840346123, 0.08502980184006369, '41'),
#  ('fluttershy',
#   'prince rutherford'): Text(0.05683599738568834, 0.12218846363994187, '2'),
#  ('fluttershy',
#   'queen chrysalis'): Text(-0.20661875149208878, 0.22868139399372148, '1'),
#  ('fluttershy',
#   'zephyr breeze'): Text(0.0986782450003701, -0.1109064932155916, '62'),
#  ('fluttershy',
#   'snails'): Text(-0.20594606404062815, -0.13697399455954962, '5'),
#  ('fluttershy',
#   'gladmane'): Text(0.3219194332219095, -0.03241162144880791, '11'),
#  ('fluttershy', 'flam'): Text(0.2131874932211624, -0.0018237286085921469, '9'),
#  ('fluttershy',
#   'flim'): Text(0.17070268838403838, -0.0010161083198194404, '19'),
#  ('fluttershy',
#   'sunburst'): Text(-0.07504705287096243, 0.17151265467203702, '1'),
#  ('fluttershy',
#   'star swirl the bearded'): Text(0.02405173529098079, 0.18207449196842967, '2'),
#  ('fluttershy',
#   'silverstream'): Text(-0.2850573818782359, 0.07629244936018403, '5'),
#  ('fluttershy',
#   'sandbar'): Text(-0.23414784683422155, -0.01680043574432079, '1'),
#  ('fluttershy',
#   'ocellus'): Text(-0.24622803445377792, 0.03940058981440199, '2'),
#  ('fluttershy',
#   'smolder'): Text(-0.1651411811259173, 0.06053809928383533, '1'),
#  ('fluttershy', 'yona'): Text(-0.23734026930596597, 0.0966240530184569, '1'),
#  ('fluttershy',
#   'sludge'): Text(-0.02657813188939638, 0.23228382478715898, '1'),
#  ('fluttershy',
#   'cozy glow'): Text(-0.17478034527102657, -0.039667750651907446, '1'),
#  ('fluttershy', 'capper'): Text(0.272932527075322, 0.1261215748816634, '1'),
#  ('fluttershy',
#   'tempest shadow'): Text(0.28102267656614743, 0.07802159079964695, '1'),
#  ('fluttershy',
#   'princess cadance'): Text(-0.06498454006361311, 0.09162243089547739, '1'),
#  ('pinkie pie',
#   'mayor mare'): Text(0.03215502729213086, 0.17600124454781252, '13'),
#  ('pinkie pie',
#   'princess celestia'): Text(-0.03779799110441992, 0.08820770127833913, '14'),
#  ('pinkie pie',
#   'princess luna'): Text(-0.06127457391643053, 0.009662228869231331, '19'),
#  ('pinkie pie',
#   'sweetie drops'): Text(0.4018894770604268, 0.0008345717892245808, '1'),
#  ('pinkie pie',
#   'mrs. cake'): Text(0.1627745794252588, 0.09774130010916392, '35'),
#  ('pinkie pie',
#   'mr. cake'): Text(0.20981533082408227, 0.21698739683900947, '29'),
#  ('pinkie pie',
#   'gilda'): Text(0.14002125320118358, 0.023955883798159314, '79'),
#  ('pinkie pie', 'zecora'): Text(-0.0388781566331399, -0.019865075387361, '18'),
#  ('pinkie pie',
#   'photo finish'): Text(0.22466886835003358, 0.16303496014194024, '1'),
#  ('pinkie pie',
#   'braeburn'): Text(0.2636696671351104, -0.05477142543377661, '1'),
#  ('pinkie pie',
#   'scootaloo'): Text(0.004635010582542478, -0.09383370567530068, '18'),
#  ('pinkie pie',
#   'sweetie belle'): Text(0.007638799725239063, -0.059508245011222066, '6'),
#  ('pinkie pie',
#   'spitfire'): Text(-0.03442284175294638, -0.10888251845935411, '9'),
#  ('pinkie pie',
#   'discord'): Text(-0.033985366943838496, 0.03817357707968091, '44'),
#  ('pinkie pie',
#   'pipsqueak'): Text(-0.12569549625163406, -0.1762152686789168, '4'),
#  ('pinkie pie', 'derpy'): Text(-0.05811162566197661, 0.3641059871289081, '2'),
#  ('pinkie pie', 'flim'): Text(0.18263487620909938, 0.03578891957896469, '1'),
#  ('pinkie pie',
#   'cheerilee'): Text(0.057874816210661525, -0.12481660865419618, '8'),
#  ('pinkie pie',
#   'matilda'): Text(-0.3269686278742746, 0.29316637138138174, '4'),
#  ('pinkie pie',
#   'cranky doodle donkey'): Text(-0.1091703493453236, 0.1619937213894504, '106'),
#  ('pinkie pie',
#   'iron will'): Text(-0.025743778218255537, 0.20904328587819915, '18'),
#  ('pinkie pie',
#   'big mcintosh'): Text(0.08450206721283168, -0.03275468353080034, '7'),
#  ('pinkie pie',
#   'princess cadance'): Text(-0.053052352238552106, 0.12842745879426154, '10'),
#  ('pinkie pie',
#   'shining armor'): Text(-0.09030519782564538, 0.06538401428281942, '8'),
#  ('pinkie pie', 'trixie'): Text(-0.085830243195841, 0.08397953533468591, '2'),
#  ('pinkie pie',
#   'ms. peachbottom'): Text(-0.19912048688202455, -0.05361059835326559, '3'),
#  ('pinkie pie',
#   'goldie delicious'): Text(0.26155534691568944, -0.12323959334957439, '5'),
#  ('pinkie pie',
#   'bulk biceps'): Text(0.07388764567912337, -0.2008124258940734, '3'),
#  ('pinkie pie',
#   'cheese sandwich'): Text(0.22742290288706377, 0.0974307979430109, '50'),
#  ('pinkie pie',
#   'diamond tiara'): Text(0.02674285757744365, -0.19626010719836917, '1'),
#  ('pinkie pie',
#   'maud pie'): Text(0.06417526720754112, 0.1176683832806801, '192'),
#  ('pinkie pie',
#   'double diamond'): Text(0.13253784968550822, 0.2772894821156702, '1'),
#  ('pinkie pie',
#   'starlight glimmer'): Text(-0.04147845057840023, 0.12183482973884782, '101'),
#  ('pinkie pie',
#   'sugar belle'): Text(0.19158572769039067, -0.02142383474805421, '6'),
#  ('pinkie pie',
#   'prince rutherford'): Text(0.06876818521074934, 0.158993491538726, '114'),
#  ('pinkie pie',
#   'moon dancer'): Text(-0.07403141607722553, 0.2764550062673941, '1'),
#  ('pinkie pie',
#   'sunburst'): Text(-0.06311486504590143, 0.20831768257082117, '1'),
#  ('pinkie pie',
#   'snails'): Text(-0.19401387621556715, -0.10016896666076548, '7'),
#  ('pinkie pie',
#   'dr. caballeron'): Text(0.22021849177752564, -0.3029749843673975, '1'),
#  ('pinkie pie',
#   'daring do'): Text(0.15972586593703827, -0.1260577198052082, '15'),
#  ('pinkie pie',
#   'star swirl the bearded'): Text(0.03598392311604179, 0.21887951986721382, '3'),
#  ('pinkie pie',
#   'sandbar'): Text(-0.22221565900916054, 0.02000459215446334, '4'),
#  ('pinkie pie',
#   'mudbriar'): Text(0.1538877255758149, 0.21128167392020503, '61'),
#  ('pinkie pie',
#   'smolder'): Text(-0.1532089933008563, 0.09734312718261946, '1'),
#  ('pinkie pie',
#   'ocellus'): Text(-0.23429584662871691, 0.07620561771318612, '2'),
#  ('pinkie pie',
#   'cutie mark crusaders'): Text(-0.006631185125955782, -0.1490724025358649, '1'),
#  ('pinkie pie', 'yona'): Text(-0.22540808148090496, 0.13342908091724104, '1'),
#  ('pinkie pie',
#   'rockhoof'): Text(-0.16234691268629828, 0.1503314945271838, '3'),
#  ('pinkie pie',
#   'sludge'): Text(-0.014645944064335382, 0.2690888526859431, '4'),
#  ('pinkie pie',
#   'chancellor neighsay'): Text(-0.33595611765684097, 0.03244359517026621, '1'),
#  ('pinkie pie',
#   'lord tirek'): Text(-0.14286786920842903, -0.05031256966158899, '6'),
#  ('pinkie pie',
#   'tempest shadow'): Text(0.29295486439120844, 0.11482661869843108, '5'),
#  ('pinkie pie', 'capper'): Text(0.284864714900383, 0.16292660278044752, '6'),
#  ('pinkie pie',
#   'princess skystar'): Text(0.31654939190132786, 0.26362166284519667, '8'),
#  ('pinkie pie',
#   'the storm king'): Text(0.42873045362284745, 0.18065637830098014, '4'),
#  ('mayor mare',
#   'big mcintosh'): Text(0.07406465414939785, 0.07546551922465877, '3'),
#  ('mayor mare',
#   'sweetie drops'): Text(0.391452063996993, 0.1090547745446837, '1'),
#  ('mayor mare',
#   'zecora'): Text(-0.04931556969657373, 0.08835512736809811, '1'),
#  ('mayor mare', 'derpy'): Text(-0.06854903872541045, 0.47232618988436725, '4'),
#  ('mayor mare', 'flim'): Text(0.17219746314566553, 0.1440091223344238, '1'),
#  ('mayor mare', 'flam'): Text(0.21468226798278955, 0.1432015020456511, '1'),
#  ('mayor mare',
#   'cranky doodle donkey'): Text(-0.11960776240875744, 0.2702139241449095, '2'),
#  ('mayor mare',
#   'matilda'): Text(-0.33740604093770843, 0.40138657413684087, '2'),
#  ('mayor mare',
#   'mrs. cake'): Text(0.15233716636182495, 0.20596150286462303, '1'),
#  ('nightmare moon',
#   'pipsqueak'): Text(-0.44483241463027645, -0.2616769328677178, '1'),
#  ('nightmare moon',
#   'princess luna'): Text(-0.38041149229507293, -0.07579943531956967, '2'),
#  ('nightmare moon',
#   'princess celestia'): Text(-0.35693490948306233, 0.0027460370895381267, '2'),
#  ('nightmare moon',
#   'starlight glimmer'): Text(-0.36061536895704266, 0.03637316555004682, '1'),
#  ('princess celestia',
#   'princess luna'): Text(-0.14166500537641513, 0.03008888835521704, '71'),
#  ('princess celestia',
#   'mrs. cake'): Text(0.08238414796527418, 0.11816795959514963, '3'),
#  ('princess celestia',
#   'mr. cake'): Text(0.12942489936409765, 0.23741405632499518, '3'),
#  ('princess celestia',
#   'discord'): Text(-0.1143757984038231, 0.05860023656566662, '22'),
#  ('princess celestia',
#   'princess cadance'): Text(-0.1334427836985367, 0.14885411828024725, '12'),
#  ('princess celestia',
#   'queen chrysalis'): Text(-0.2750769951270124, 0.2859130813784913, '4'),
#  ('princess celestia',
#   'shining armor'): Text(-0.17069562928562998, 0.08581067376880513, '2'),
#  ('princess celestia',
#   'lord tirek'): Text(-0.22325830066841365, -0.029885910175603284, '3'),
#  ('princess celestia',
#   'sweetie drops'): Text(0.32149904560044223, 0.02126123127521029, '1'),
#  ('princess celestia',
#   'prince rutherford'): Text(-0.011622246249235267, 0.1794201510247117, '2'),
#  ('princess celestia',
#   'sunburst'): Text(-0.14350529650588603, 0.22874434205680688, '4'),
#  ('princess celestia',
#   'starlight glimmer'): Text(-0.12186888203838483, 0.14226148922483353, '37'),
#  ('princess celestia',
#   'star swirl the bearded'): Text(-0.044406508343942816, 0.23930617935319953, '2'),
#  ('princess celestia',
#   'thorax'): Text(-0.20775146806374817, 0.21661728226817617, '1'),
#  ('princess celestia',
#   'sandbar'): Text(-0.30260609046914516, 0.04043125164044905, '1'),
#  ('princess celestia',
#   'ember'): Text(-0.21568414687942583, 0.29171836848105726, '1'),
#  ('princess celestia',
#   'neighsay'): Text(-0.3198950738634222, 0.22432669750360645, '1'),
#  ('princess celestia',
#   'cozy glow'): Text(-0.24323858890595018, 0.017563936732862398, '1'),
#  ('princess celestia',
#   'tempest shadow'): Text(0.21256443293122385, 0.1352532781844168, '3'),
#  ('princess luna',
#   'pipsqueak'): Text(-0.2295625105236293, -0.2343340816020389, '8'),
#  ('princess luna',
#   'shining armor'): Text(-0.1941722120976406, 0.00726520135969733, '1'),
#  ('princess luna',
#   'scootaloo'): Text(-0.09923200368945274, -0.15195251859842276, '12'),
#  ('princess luna',
#   'discord'): Text(-0.1378523812158337, -0.01994523584344118, '1'),
#  ('princess luna',
#   'sweetie belle'): Text(-0.09622821454675616, -0.11762705793434415, '14'),
#  ('princess luna',
#   'princess cadance'): Text(-0.15691936651054733, 0.07030864587113944, '9'),
#  ('princess luna',
#   'lord tirek'): Text(-0.24673488348042427, -0.10843138258471108, '2'),
#  ('princess luna',
#   'big mcintosh'): Text(-0.019364947059163543, -0.09087349645392243, '1'),
#  ('princess luna',
#   'starlight glimmer'): Text(-0.14534546485039546, 0.06371601681572574, '57'),
#  ('princess luna',
#   'sunburst'): Text(-0.16698187931789665, 0.15019886964769907, '1'),
#  ('princess luna',
#   'star swirl the bearded'): Text(-0.06788309115595344, 0.16076070694409172, '1'),
#  ('princess luna',
#   'cozy glow'): Text(-0.2667151717179608, -0.060981535676245396, '1'),
#  ('princess luna',
#   'tempest shadow'): Text(0.18908785011921325, 0.056707805775309, '2'),
#  ('big mcintosh',
#   'flim'): Text(0.22454450306636636, -0.06474680574418906, '3'),
#  ('big mcintosh',
#   'sweetie belle'): Text(0.04954842658250605, -0.16004397033437584, '37'),
#  ('big mcintosh',
#   'cheerilee'): Text(0.09978444306792851, -0.22535233397734994, '29'),
#  ('big mcintosh',
#   'mrs. cake'): Text(0.2046842062825258, -0.002794425213989843, '2'),
#  ('big mcintosh',
#   'scootaloo'): Text(0.046544637439809466, -0.19436943099845444, '10'),
#  ('big mcintosh',
# ...
#  ('scootaloo',
#   'babs seed'): Text(0.02897302376138091, -0.4114254924093661, '10'),
#  ('scootaloo',
#   'pipsqueak'): Text(-0.16365292602465628, -0.33783001614657093, '4'),
#  ('scootaloo', 'braeburn'): Text(0.2257122373620882, -0.2163861729014307, '1'),
#  ('scootaloo',
#   'trouble shoes'): Text(-0.1539028958465031, -0.49767527017960655, '5'),
#  ('scootaloo',
#   'bulk biceps'): Text(0.03593021590610116, -0.3624271733617275, '5'),
#  ('scootaloo',
#   'spitfire'): Text(-0.0723802715259686, -0.2704972659270082, '11'),
#  ('scootaloo',
#   'young rainbow dash'): Text(-0.33182372264770044, -0.23291396143157195, '1'),
#  ('scootaloo',
#   'gabby'): Text(-0.022552179184994622, -0.4728325205417977, '29'),
#  ('scootaloo',
#   'bow hothoof'): Text(-0.11221514886848327, -0.5104722955693898, '22'),
#  ('scootaloo',
#   'windy whistles'): Text(-0.19439752347633998, -0.4596581639494631, '24'),
#  ('scootaloo',
#   'sugar belle'): Text(0.15362829791736846, -0.18303858221570832, '7'),
#  ('scootaloo',
#   'rumble'): Text(-0.06855029066781372, -0.4648061986613262, '19'),
#  ('scootaloo',
#   'cozy glow'): Text(-0.20080558721898778, -0.1644774702207774, '10'),
#  ('scootaloo',
#   'starlight glimmer'): Text(-0.07943588035142245, -0.03977991772880628, '1'),
#  ('scootaloo',
#   'lightning dust'): Text(-0.07342684600598776, -0.35179062211232864, '23'),
#  ('scootaloo',
#   'sandbar'): Text(-0.26017308878218276, -0.14161015531319077, '2'),
#  ('sweetie belle',
#   'cutie mark crusaders'): Text(-0.04158482575628141, -0.2763616893394404, '24'),
#  ('sweetie belle',
#   'babs seed'): Text(0.031976812904077494, -0.37710003174528745, '8'),
#  ('sweetie belle',
#   'pipsqueak'): Text(-0.1606491368819597, -0.3035045554824923, '15'),
#  ('sweetie belle',
#   'braeburn'): Text(0.2287160265047848, -0.1820607122373521, '1'),
#  ('sweetie belle',
#   'trouble shoes'): Text(-0.15089910670380652, -0.4633498095155279, '5'),
#  ('sweetie belle',
#   'bulk biceps'): Text(0.038934005048797744, -0.3281017126976489, '5'),
#  ('sweetie belle',
#   'gabby'): Text(-0.01954839004229804, -0.4385070598777191, '11'),
#  ('sweetie belle',
#   'bow hothoof'): Text(-0.10921135972578669, -0.4761468349053111, '1'),
#  ('sweetie belle',
#   'sugar belle'): Text(0.15663208706006504, -0.1487131215516297, '1'),
#  ('sweetie belle',
#   'rumble'): Text(-0.06554650152511714, -0.4304807379972476, '17'),
#  ('sweetie belle',
#   'discord'): Text(-0.06893900757416412, -0.08911570972389457, '3'),
#  ('sweetie belle',
#   'cozy glow'): Text(-0.1978017980762912, -0.1301520095566988, '15'),
#  ('sweetie belle',
#   'starlight glimmer'): Text(-0.07643209120872586, -0.0054544570647276636, '1'),
#  ('sweetie belle',
#   'yona'): Text(-0.2603617221112306, 0.006139794113665553, '1'),
#  ('hoity toity',
#   'photo finish'): Text(0.4468979458536043, 0.4005775694086655, '7'),
#  ('soarin', 'spitfire'): Text(-0.16112804395267458, -0.3511841516535803, '12'),
#  ('soarin',
#   'bulk biceps'): Text(-0.05281755652060482, -0.4431140590882996, '1'),
#  ('spitfire',
#   'lightning dust'): Text(-0.11248469834147662, -0.36683943489638204, '18'),
#  ('spitfire',
#   'sky stinger'): Text(0.09619601949822604, -0.41569298992117054, '2'),
#  ('spitfire',
#   'vapor trail'): Text(0.12584189696448145, -0.3576286855712333, '2'),
#  ('spitfire',
#   'bow hothoof'): Text(-0.15127300120397214, -0.5255211083534432, '2'),
#  ('spitfire',
#   'windy whistles'): Text(-0.23345537581182885, -0.47470697673351653, '2'),
#  ('cutie mark crusaders',
#   'babs seed'): Text(0.01770682805288265, -0.46666418926993025, '1'),
#  ('cutie mark crusaders',
#   'pipsqueak'): Text(-0.17491912173315455, -0.3930687130071351, '1'),
#  ('cutie mark crusaders',
#   'trouble shoes'): Text(-0.16516909155500137, -0.5529139670401707, '2'),
#  ('cutie mark crusaders',
#   'discord'): Text(-0.08320899242535897, -0.1786798672485374, '2'),
#  ('cutie mark crusaders',
#   'gabby'): Text(-0.03381837489349288, -0.528071217402362, '6'),
#  ('cutie mark crusaders',
#   'sugar belle'): Text(0.1423621022088702, -0.23827727907627252, '1'),
#  ('cutie mark crusaders',
#   'rumble'): Text(-0.07981648637631197, -0.5200448955218905, '4'),
#  ('cutie mark crusaders',
#   'cozy glow'): Text(-0.21207178292748605, -0.21971616708134162, '2'),
#  ('cutie mark crusaders',
#   'starlight glimmer'): Text(-0.0907020760599207, -0.09501861458937048, '1'),
#  ('young applejack',
#   'young big mcintosh'): Text(0.8660087257104561, -0.5093043102623296, '34'),
#  ('young applejack',
#   'filthy rich'): Text(0.7118873133754998, -0.4749426761941088, '30'),
#  ('young rainbow dash',
#   'starlight glimmer'): Text(-0.37793718380864316, -0.017245426017423432, '7'),
#  ('discord',
#   'princess cadance'): Text(-0.1296301595379553, 0.09881999408158902, '14'),
#  ('discord',
#   'lord tirek'): Text(-0.21944567650783223, -0.0799200343742615, '27'),
#  ('discord',
#   'shining armor'): Text(-0.16688300512504856, 0.03577654957014691, '1'),
#  ('discord', 'maud pie'): Text(-0.012402540091862063, 0.0880609185680076, '3'),
#  ('discord',
#   'starlight glimmer'): Text(-0.11805625787780341, 0.09222736502617532, '48'),
#  ('discord', 'thorax'): Text(-0.20393884390316674, 0.16658315806951793, '11'),
#  ('discord', 'sunburst'): Text(-0.1396926723453046, 0.17871021785814864, '1'),
#  ('discord',
#   'sugar belle'): Text(0.11500792039098748, -0.05103129946072672, '1'),
#  ('discord', 'yona'): Text(-0.30198588878030813, 0.10382161620456853, '1'),
#  ('discord',
#   'sandbar'): Text(-0.29879346630856374, -0.009602872558209168, '2'),
#  ('fancy pants',
#   'princess cadance'): Text(-0.011056055317006208, 0.36770338648393486, '1'),
#  ('filthy rich',
#   'young big mcintosh'): Text(0.8458785876650436, -0.557150991181706, '9'),
#  ('derpy', 'matilda'): Text(-0.4276726938918159, 0.5894913167179364, '3'),
#  ('flim', 'flam'): Text(0.3651621168997581, 0.00298917707680326, '141'),
#  ('flim', 'gladmane'): Text(0.4738940569005052, -0.027598715763412503, '11'),
#  ('flim',
#   'chancellor neighsay'): Text(-0.19591368180330626, 0.0004514729568774866, '1'),
#  ('flim',
#   'star swirl the bearded'): Text(0.17602635896957647, 0.1868873976538251, '5'),
#  ('flim',
#   'prince rutherford'): Text(0.20881062106428402, 0.1270013693253373, '1'),
#  ('flam', 'gladmane'): Text(0.5163788617376293, -0.028406336052185212, '15'),
#  ('flam',
#   'star swirl the bearded'): Text(0.2185111638067005, 0.18607977736505238, '5'),
#  ('daring do',
#   'dr. caballeron'): Text(0.3373519173589992, -0.49681374596495914, '12'),
#  ('daring do',
#   'quibble pants'): Text(0.2540939061730101, -0.37123640343770614, '18'),
#  ('matilda',
#   'cranky doodle donkey'): Text(-0.4787314175751629, 0.3873790509784787, '19'),
#  ('cranky doodle donkey',
#   'starlight glimmer'): Text(-0.19324124027928852, 0.2160475093359448, '1'),
#  ('iron will',
#   'shining armor'): Text(-0.1586414163994656, 0.20664625836866513, '2'),
#  ('iron will',
#   'princess cadance'): Text(-0.12138857081237234, 0.26968970288010724, '4'),
#  ('iron will',
#   'starlight glimmer'): Text(-0.10981466915222046, 0.26309707382469355, '1'),
#  ('iron will', 'yona'): Text(-0.2937443000547252, 0.27469132500308674, '5'),
#  ('garble',
#   'princess ember'): Text(0.0622855354935169, 0.5034396388192961, '7'),
#  ('garble',
#   'starlight glimmer'): Text(-0.013497906813589228, 0.27952339892676376, '7'),
#  ('bulk biceps',
#   'lightning dust'): Text(-0.00417421090940686, -0.45876934233110134, '2'),
#  ('shining armor',
#   'princess cadance'): Text(-0.18594999041976218, 0.12603043128472752, '63'),
#  ('shining armor',
#   'queen chrysalis'): Text(-0.32758420184823783, 0.26308939438297163, '4'),
#  ('shining armor',
#   'ms. peachbottom'): Text(-0.33201812506323464, -0.056007625862799594, '8'),
#  ('shining armor',
#   'lord tirek'): Text(-0.2757655073896391, -0.052709597171122995, '3'),
#  ('shining armor',
#   'starlight glimmer'): Text(-0.1743760887596103, 0.11943780222931383, '3'),
#  ('shining armor',
#   'sunburst'): Text(-0.1960125032271115, 0.20592065506128715, '2'),
#  ('shining armor',
#   'thorax'): Text(-0.2602586747849736, 0.19379359527265644, '1'),
#  ('princess cadance',
#   'queen chrysalis'): Text(-0.2903313562611446, 0.3261328388944137, '12'),
#  ('princess cadance',
#   'starlight glimmer'): Text(-0.13712324317251703, 0.18248124674075594, '6'),
#  ('princess cadance',
#   'sunburst'): Text(-0.15875965764001823, 0.26896409957272926, '3'),
#  ('princess cadance',
#   'thorax'): Text(-0.22300582919788037, 0.25683703978409855, '2'),
#  ('queen chrysalis',
#   'starlight glimmer'): Text(-0.2787574546009927, 0.319540209839, '11'),
#  ('queen chrysalis',
#   'thorax'): Text(-0.364640040626356, 0.3938960028823426, '5'),
#  ('dr. caballeron',
#   'quibble pants'): Text(0.31458653201349746, -0.5481536679998954, '18'),
#  ('maud pie',
#   'starlight glimmer'): Text(-0.019895623726423804, 0.1717221712271745, '44'),
#  ('maud pie', 'sunburst'): Text(-0.041532038193925, 0.25820502405914786, '16'),
#  ('maud pie', 'mudbriar'): Text(0.17547055242779133, 0.2611690154085317, '7'),
#  ('lord tirek',
#   'cozy glow'): Text(-0.3483084670099593, -0.12095633420706572, '2'),
#  ('lord tirek',
#   'sandbar'): Text(-0.40767596857315425, -0.09808901929947907, '2'),
#  ('double diamond',
#   'starlight glimmer'): Text(0.048466958751543304, 0.33134327006216463, '21'),
#  ('double diamond',
#   'sugar belle'): Text(0.2815311370203342, 0.18808460557526258, '4'),
#  ('starlight glimmer',
#   'sugar belle'): Text(0.10751483675642574, 0.03262995319844019, '5'),
#  ('starlight glimmer',
#   'sunburst'): Text(-0.14718575597986636, 0.2623714705173156, '178'),
#  ('starlight glimmer',
#   'thorax'): Text(-0.2114319275377285, 0.25024441072868486, '66'),
#  ('starlight glimmer',
#   'princess ember'): Text(-0.049765899205259034, 0.3998048575778746, '2'),
#  ('starlight glimmer',
#   'ember'): Text(-0.21936460635340616, 0.32534549694156595, '11'),
#  ('starlight glimmer',
#   'pharynx'): Text(-0.3549994285000657, 0.3649633619963735, '13'),
#  ('starlight glimmer',
#   'star swirl the bearded'): Text(-0.04808696781792314, 0.2729333078137082, '10'),
#  ('starlight glimmer',
#   'rockhoof'): Text(-0.24641780362026322, 0.2043852824736782, '2'),
#  ('starlight glimmer',
#   'gallus'): Text(-0.3516711051875162, 0.1203300455772935, '2'),
#  ('starlight glimmer',
#   'ocellus'): Text(-0.31836673756268186, 0.13025940565968053, '7'),
#  ('starlight glimmer',
#   'mudbriar'): Text(0.06981683464184997, 0.26533546186669943, '1'),
#  ('starlight glimmer',
#   'firelight'): Text(-0.23996209283811187, 0.45251349664733126, '29'),
#  ('starlight glimmer',
#   'stellar flare'): Text(-0.19907781831347132, 0.5048009053697219, '12'),
#  ('starlight glimmer',
#   'cozy glow'): Text(-0.2469190483799305, 0.05119106519337109, '11'),
#  ('starlight glimmer',
#   'yona'): Text(-0.3094789724148699, 0.18748286886373544, '5'),
#  ('starlight glimmer',
#   'sandbar'): Text(-0.3062865499431255, 0.07405838010095775, '2'),
#  ('starlight glimmer',
#   'silverstream'): Text(-0.35719608498713984, 0.16715126520546258, '3'),
#  ('prince rutherford',
#   'gallus'): Text(-0.24142446939836662, 0.1574887073771717, '1'),
#  ('prince rutherford',
#   'yona'): Text(-0.19923233662572032, 0.22464153066361364, '1'),
#  ('prince rutherford',
#   'neighsay'): Text(-0.21332889754825293, 0.29511248776399335, '2'),
#  ('prince rutherford',
#   'ember'): Text(-0.10911797056425657, 0.36250415874144415, '1'),
#  ('prince rutherford',
#   'thorax'): Text(-0.1011852917485789, 0.287403072528563, '2'),
#  ('prince rutherford',
#   'ocellus'): Text(-0.20812010177353227, 0.16741806745955873, '1'),
#  ('prince rutherford',
#   'smolder'): Text(-0.12703324844567165, 0.18855557692899205, '2'),
#  ('sunburst',
#   'star swirl the bearded'): Text(-0.06972338228542434, 0.35941616064568155, '4'),
#  ('sunburst', 'rockhoof'): Text(-0.2680542180877644, 0.29086813530565153, '1'),
#  ('sunburst',
#   'stellar flare'): Text(-0.22071423278097252, 0.5912837582016952, '26'),
#  ('sunburst',
#   'firelight'): Text(-0.26159850730561307, 0.5389963494793046, '6'),
#  ('thorax', 'ember'): Text(-0.30524719237876946, 0.39970128998490856, '35'),
#  ('thorax', 'pharynx'): Text(-0.440882014525429, 0.43931915503971614, '27'),
#  ('thorax',
#   'silverstream'): Text(-0.44307867101250314, 0.2415070582488052, '3'),
#  ('sky stinger',
#   'vapor trail'): Text(0.33347604032416495, -0.4877755967813422, '22'),
#  ('bow hothoof',
#   'windy whistles'): Text(-0.2732902531543435, -0.7146820063758981, '18'),
#  ('ember', 'smolder'): Text(-0.33109514907586224, 0.30085379438533755, '3'),
#  ('ember', 'neighsay'): Text(-0.4173907981784435, 0.40741070522033884, '3'),
#  ('rockhoof',
#   'star swirl the bearded'): Text(-0.1689554299258212, 0.3014299726020442, '3'),
#  ('rockhoof', 'smolder'): Text(-0.3581483463427193, 0.17989357991744986, '6'),
#  ('rockhoof', 'sandbar'): Text(-0.4271550120510235, 0.10255504488929373, '1'),
#  ('rockhoof', 'ocellus'): Text(-0.4392351996705799, 0.1587560704480165, '2'),
#  ('rockhoof', 'gallus'): Text(-0.47253956729541424, 0.1488267103656295, '2'),
#  ('rockhoof',
#   'silverstream'): Text(-0.4780645470950379, 0.19564792999379854, '3'),
#  ('rockhoof', 'yona'): Text(-0.4303474345227679, 0.21597953365207143, '16'),
#  ('star swirl the bearded',
#   'chancellor neighsay'): Text(-0.34256463489636385, 0.1835420732451266, '2'),
#  ('neighsay',
#   'silverstream'): Text(-0.5552222768121772, 0.24921647348423548, '1'),
#  ('neighsay', 'gallus'): Text(-0.5496972970125535, 0.2023952538560664, '1'),
#  ('neighsay', 'yona'): Text(-0.5075051642399072, 0.26954807714250834, '2'),
#  ('sandbar', 'smolder'): Text(-0.4180170926655815, 0.04956667754472938, '22'),
#  ('sandbar', 'gallus'): Text(-0.5324083136182765, 0.01849980799290902, '26'),
#  ('sandbar',
#   'ocellus'): Text(-0.49910394599344216, 0.028429168075296045, '20'),
#  ('sandbar',
#   'silverstream'): Text(-0.5379332934179002, 0.0653210276210781, '21'),
#  ('sandbar', 'yona'): Text(-0.49021618084563023, 0.08565263127935097, '19'),
#  ('sandbar',
#   'cozy glow'): Text(-0.4276562568106908, -0.05063917239101339, '11'),
#  ('sandbar',
#   'chancellor neighsay'): Text(-0.6007642170215661, -0.015332854467623865, '8'),
#  ('gallus', 'ocellus'): Text(-0.5444885012378329, 0.0747008335516318, '26'),
#  ('gallus',
#   'silverstream'): Text(-0.5833178486622909, 0.11159269309741385, '48'),
#  ('gallus', 'yona'): Text(-0.5356007360900209, 0.13192429675568673, '21'),
#  ('gallus', 'smolder'): Text(-0.4634016479099723, 0.09583834302106514, '24'),
#  ('gallus',
#   'cozy glow'): Text(-0.4730408120550815, -0.004367506914677632, '8'),
#  ('gallus',
#   'chancellor neighsay'): Text(-0.6461487722659569, 0.030938811008711892, '1'),
#  ('yona', 'ocellus'): Text(-0.5022963684651865, 0.14185365683807374, '14'),
#  ('yona', 'smolder'): Text(-0.42120951513732596, 0.1629911663075071, '23'),
#  ('yona',
#   'silverstream'): Text(-0.5411257158896445, 0.17874551638385577, '12'),
#  ('yona', 'cozy glow'): Text(-0.4308486792824352, 0.06278531637176431, '8'),
#  ('yona',
#   'chancellor neighsay'): Text(-0.6039566394933106, 0.09809163429515383, '1'),
#  ('smolder',
#   'silverstream'): Text(-0.4689266277095959, 0.1426595626492342, '25'),
#  ('smolder', 'ocellus'): Text(-0.43009728028513794, 0.10576770310345217, '50'),
#  ('smolder', 'cozy glow'): Text(-0.3586495911023866, 0.02669936263714273, '5'),
#  ('smolder', 'sludge'): Text(-0.2104473777207564, 0.2986509380762091, '7'),
#  ('silverstream',
#   'ocellus'): Text(-0.5500134810374565, 0.12152205317980087, '13'),
#  ('silverstream',
#   'cozy glow'): Text(-0.47856579185470516, 0.04245371271349144, '7'),
#  ('silverstream',
#   'chancellor neighsay'): Text(-0.6516737520655805, 0.07776003063688096, '2'),
#  ('ocellus',
#   'cozy glow'): Text(-0.4397364444302472, 0.0055618531677093935, '5'),
#  ('ocellus',
#   'chancellor neighsay'): Text(-0.6128444046411226, 0.040868171091098915, '1'),
#  ('firelight',
#   'stellar flare'): Text(-0.31349056963921806, 0.781425784331711, '16'),
#  ('cozy glow',
#   'chancellor neighsay'): Text(-0.5413967154583712, -0.03820016937521052, '24'),
#  ('tempest shadow',
#   'the storm king'): Text(0.6790928776584912, 0.22770195520705777, '27'),
#  ('tempest shadow',
#   'capper'): Text(0.5352271389360268, 0.2099721796865252, '7'),
#  ('the storm king',
#   'capper'): Text(0.6710027281676658, 0.27580193928907426, '4'),
#  ('capper',
#   'princess skystar'): Text(0.5588216664461463, 0.35876722383329074, '1')}

# %%
js = {'apple':3}
js.items()
# Out:
# dict_items([('apple', 3)])

# %%
for speaker in G.nodes():
    print(speaker)
    print(G.degree(speaker))
# Out:
# twilight sparkle
# 78
# spike
# 61
# applejack
# 68
# granny smith
# 28
# apple bloom
# 42
# rainbow dash
# 72
# rarity
# 61
# fluttershy
# 57
# pinkie pie
# 63
# mayor mare
# 18
# nightmare moon
# 8
# princess celestia
# 27
# princess luna
# 23
# big mcintosh
# 24
# sweetie drops
# 12
# mrs. cake
# 16
# mr. cake
# 9
# gilda
# 7
# snails
# 11
# snips
# 13
# trixie
# 19
# zecora
# 14
# cheerilee
# 17
# diamond tiara
# 15
# silver spoon
# 11
# scootaloo
# 35
# sweetie belle
# 32
# hoity toity
# 4
# soarin
# 7
# spitfire
# 13
# cutie mark crusaders
# 21
# rover
# 3
# photo finish
# 8
# braeburn
# 7
# young applejack
# 4
# young rainbow dash
# 6
# discord
# 25
# pipsqueak
# 13
# fancy pants
# 4
# filthy rich
# 10
# derpy
# 6
# flim
# 15
# flam
# 11
# daring do
# 7
# matilda
# 7
# cranky doodle donkey
# 6
# iron will
# 8
# garble
# 6
# bulk biceps
# 13
# rumble
# 6
# shining armor
# 18
# princess cadance
# 19
# queen chrysalis
# 11
# babs seed
# 9
# lightning dust
# 7
# ms. peachbottom
# 7
# dr. caballeron
# 5
# goldie delicious
# 6
# cheese sandwich
# 4
# maud pie
# 14
# lord tirek
# 13
# double diamond
# 8
# starlight glimmer
# 46
# sugar belle
# 16
# trouble shoes
# 5
# prince rutherford
# 15
# moon dancer
# 3
# sassy saddles
# 4
# sunburst
# 19
# princess ember
# 5
# zephyr breeze
# 5
# quibble pants
# 3
# thorax
# 13
# gabby
# 4
# gladmane
# 4
# young big mcintosh
# 3
# sky stinger
# 4
# vapor trail
# 4
# bow hothoof
# 6
# windy whistles
# 5
# ember
# 8
# rockhoof
# 16
# pharynx
# 3
# star swirl the bearded
# 14
# neighsay
# 8
# sandbar
# 21
# gallus
# 16
# yona
# 20
# smolder
# 18
# silverstream
# 16
# ocellus
# 16
# mudbriar
# 3
# firelight
# 3
# stellar flare
# 3
# cozy glow
# 23
# chancellor neighsay
# 13
# sludge
# 7
# tempest shadow
# 11
# the storm king
# 5
# capper
# 10
# princess skystar
# 6

# %%
la = list(labels.items())
la.sort(key = lambda x: -x[1])
la
# Out:
# [(('twilight sparkle', 'spike'), 1514),
#  (('twilight sparkle', 'pinkie pie'), 918),
#  (('twilight sparkle', 'rainbow dash'), 895),
#  (('twilight sparkle', 'applejack'), 771),
#  (('applejack', 'rarity'), 730),
#  (('rainbow dash', 'pinkie pie'), 696),
#  (('twilight sparkle', 'fluttershy'), 677),
#  (('applejack', 'rainbow dash'), 666),
#  (('twilight sparkle', 'rarity'), 649),
#  (('applejack', 'pinkie pie'), 569),
#  (('rainbow dash', 'fluttershy'), 530),
#  (('rainbow dash', 'rarity'), 506),
#  (('rarity', 'fluttershy'), 492),
#  (('apple bloom', 'scootaloo'), 487),
#  (('rarity', 'pinkie pie'), 483),
#  (('apple bloom', 'sweetie belle'), 467),
#  (('scootaloo', 'sweetie belle'), 440),
#  (('twilight sparkle', 'starlight glimmer'), 432),
#  (('applejack', 'apple bloom'), 428),
#  (('applejack', 'fluttershy'), 389),
#  (('fluttershy', 'pinkie pie'), 340),
#  (('trixie', 'starlight glimmer'), 338),
#  (('spike', 'rarity'), 326),
#  (('rarity', 'sweetie belle'), 288),
#  (('twilight sparkle', 'princess celestia'), 260),
#  (('spike', 'applejack'), 238),
#  (('rainbow dash', 'scootaloo'), 221),
#  (('spike', 'pinkie pie'), 198),
#  (('spike', 'starlight glimmer'), 194),
#  (('pinkie pie', 'maud pie'), 192),
#  (('fluttershy', 'discord'), 180),
#  (('spike', 'rainbow dash'), 179),
#  (('starlight glimmer', 'sunburst'), 178),
#  (('spike', 'discord'), 166),
#  (('twilight sparkle', 'discord'), 149),
#  (('twilight sparkle', 'princess cadance'), 143),
#  (('flim', 'flam'), 141),
#  (('applejack', 'granny smith'), 139),
#  (('rainbow dash', 'spitfire'), 136),
#  (('spike', 'fluttershy'), 134),
#  (('apple bloom', 'big mcintosh'), 127),
#  (('twilight sparkle', 'shining armor'), 120),
#  (('pinkie pie', 'prince rutherford'), 114),
#  (('granny smith', 'apple bloom'), 112),
#  (('pinkie pie', 'cranky doodle donkey'), 106),
#  (('twilight sparkle', 'apple bloom'), 102),
#  (('pinkie pie', 'starlight glimmer'), 101),
#  (('rainbow dash', 'discord'), 95),
#  (('applejack', 'big mcintosh'), 92),
#  (('twilight sparkle', 'princess luna'), 88),
#  (('rarity', 'sassy saddles'), 83),
#  (('pinkie pie', 'gilda'), 79),
#  (('spike', 'garble'), 73),
#  (('rainbow dash', 'starlight glimmer'), 72),
#  (('rainbow dash', 'quibble pants'), 72),
#  (('rarity', 'starlight glimmer'), 72),
#  (('princess celestia', 'princess luna'), 71),
#  (('twilight sparkle', 'trixie'), 69),
#  (('starlight glimmer', 'thorax'), 66),
#  (('twilight sparkle', 'sweetie belle'), 65),
#  (('shining armor', 'princess cadance'), 63),
#  (('fluttershy', 'zephyr breeze'), 62),
#  (('pinkie pie', 'mudbriar'), 61),
#  (('rainbow dash', 'lightning dust'), 60),
#  (('applejack', 'starlight glimmer'), 58),
#  (('twilight sparkle', 'zecora'), 57),
#  (('princess luna', 'starlight glimmer'), 57),
#  (('spike', 'big mcintosh'), 56),
#  (('spike', 'smolder'), 56),
#  (('apple bloom', 'diamond tiara'), 56),
#  (('rainbow dash', 'gilda'), 56),
#  (('twilight sparkle', 'moon dancer'), 54),
#  (('rarity', 'maud pie'), 54),
#  (('rainbow dash', 'daring do'), 52),
#  (('spike', 'thorax'), 51),
#  (('applejack', 'sweetie belle'), 51),
#  (('diamond tiara', 'silver spoon'), 51),
#  (('apple bloom', 'cheerilee'), 50),
#  (('pinkie pie', 'cheese sandwich'), 50),
#  (('smolder', 'ocellus'), 50),
#  (('discord', 'starlight glimmer'), 48),
#  (('gallus', 'silverstream'), 48),
#  (('spike', 'princess cadance'), 47),
#  (('applejack', 'scootaloo'), 46),
#  (('apple bloom', 'pinkie pie'), 45),
#  (('twilight sparkle', 'scootaloo'), 44),
#  (('spike', 'sludge'), 44),
#  (('granny smith', 'young applejack'), 44),
#  (('rarity', 'zecora'), 44),
#  (('pinkie pie', 'discord'), 44),
#  (('maud pie', 'starlight glimmer'), 44),
#  (('rainbow dash', 'soarin'), 43),
#  (('spike', 'princess celestia'), 42),
#  (('apple bloom', 'babs seed'), 42),
#  (('diamond tiara', 'sweetie belle'), 42),
#  (('applejack', 'discord'), 41),
#  (('fluttershy', 'starlight glimmer'), 41),
#  (('twilight sparkle', 'sunburst'), 40),
#  (('trixie', 'discord'), 39),
#  (('twilight sparkle', 'star swirl the bearded'), 37),
#  (('princess celestia', 'starlight glimmer'), 37),
#  (('big mcintosh', 'sweetie belle'), 37),
#  (('big mcintosh', 'sugar belle'), 37),
#  (('twilight sparkle', 'rockhoof'), 36),
#  (('spike', 'apple bloom'), 36),
#  (('applejack', 'braeburn'), 36),
#  (('applejack', 'flim'), 36),
#  (('snails', 'snips'), 36),
#  (('trixie', 'thorax'), 36),
#  (('apple bloom', 'rainbow dash'), 35),
#  (('pinkie pie', 'mrs. cake'), 35),
#  (('thorax', 'ember'), 35),
#  (('spike', 'princess ember'), 34),
#  (('rarity', 'rover'), 34),
#  (('spike', 'ember'), 32),
#  (('granny smith', 'rainbow dash'), 32),
#  (('rainbow dash', 'zephyr breeze'), 32),
#  (('fluttershy', 'princess celestia'), 32),
#  (('fluttershy', 'sweetie belle'), 31),
#  (('young applejack', 'filthy rich'), 30),
#  (('fluttershy', 'scootaloo'), 29),
#  (('pinkie pie', 'mr. cake'), 29),
#  (('big mcintosh', 'cheerilee'), 29),
#  (('scootaloo', 'gabby'), 29),
#  (('starlight glimmer', 'firelight'), 29),
#  (('cheerilee', 'sweetie belle'), 28),
#  (('twilight sparkle', 'nightmare moon'), 27),
#  (('spike', 'shining armor'), 27),
#  (('apple bloom', 'zecora'), 27),
#  (('fluttershy', 'zecora'), 27),
#  (('discord', 'lord tirek'), 27),
#  (('thorax', 'pharynx'), 27),
#  (('tempest shadow', 'the storm king'), 27),
#  (('spike', 'zecora'), 26),
#  (('apple bloom', 'cutie mark crusaders'), 26),
#  (('rarity', 'photo finish'), 26),
#  (('rarity', 'fancy pants'), 26),
#  (('fluttershy', 'iron will'), 26),
#  (('diamond tiara', 'scootaloo'), 26),
#  (('sunburst', 'stellar flare'), 26),
#  (('sandbar', 'gallus'), 26),
#  (('gallus', 'ocellus'), 26),
#  (('twilight sparkle', 'iron will'), 25),
#  (('smolder', 'silverstream'), 25),
#  (('rainbow dash', 'vapor trail'), 24),
#  (('scootaloo', 'cutie mark crusaders'), 24),
#  (('scootaloo', 'windy whistles'), 24),
#  (('sweetie belle', 'cutie mark crusaders'), 24),
#  (('gallus', 'smolder'), 24),
#  (('cozy glow', 'chancellor neighsay'), 24),
#  (('twilight sparkle', 'lord tirek'), 23),
#  (('spike', 'scootaloo'), 23),
#  (('apple bloom', 'fluttershy'), 23),
#  (('scootaloo', 'lightning dust'), 23),
#  (('yona', 'smolder'), 23),
#  (('twilight sparkle', 'ms. peachbottom'), 22),
#  (('twilight sparkle', 'tempest shadow'), 22),
#  (('princess celestia', 'discord'), 22),
#  (('scootaloo', 'bow hothoof'), 22),
#  (('sky stinger', 'vapor trail'), 22),
#  (('sandbar', 'smolder'), 22),
#  (('granny smith', 'big mcintosh'), 21),
#  (('rainbow dash', 'sweetie belle'), 21),
#  (('fluttershy', 'princess luna'), 21),
#  (('double diamond', 'starlight glimmer'), 21),
#  (('sandbar', 'silverstream'), 21),
#  (('gallus', 'yona'), 21),
#  (('rarity', 'princess cadance'), 20),
#  (('sandbar', 'ocellus'), 20),
#  (('applejack', 'flam'), 19),
#  (('apple bloom', 'trouble shoes'), 19),
#  (('rarity', 'princess celestia'), 19),
#  (('rarity', 'discord'), 19),
#  (('fluttershy', 'flim'), 19),
#  (('pinkie pie', 'princess luna'), 19),
#  (('cheerilee', 'scootaloo'), 19),
#  (('scootaloo', 'rumble'), 19),
#  (('matilda', 'cranky doodle donkey'), 19),
#  (('sandbar', 'yona'), 19),
#  (('twilight sparkle', 'mayor mare'), 18),
#  (('spike', 'snips'), 18),
#  (('spike', 'sweetie belle'), 18),
#  (('apple bloom', 'rarity'), 18),
#  (('rainbow dash', 'trixie'), 18),
#  (('pinkie pie', 'zecora'), 18),
#  (('pinkie pie', 'scootaloo'), 18),
#  (('pinkie pie', 'iron will'), 18),
#  (('spitfire', 'lightning dust'), 18),
#  (('daring do', 'quibble pants'), 18),
#  (('dr. caballeron', 'quibble pants'), 18),
#  (('bow hothoof', 'windy whistles'), 18),
#  (('twilight sparkle', 'cutie mark crusaders'), 17),
#  (('twilight sparkle', 'cozy glow'), 17),
#  (('granny smith', 'pinkie pie'), 17),
#  (('apple bloom', 'silver spoon'), 17),
#  (('apple bloom', 'gabby'), 17),
#  (('rainbow dash', 'princess celestia'), 17),
#  (('rainbow dash', 'sky stinger'), 17),
#  (('sweetie belle', 'rumble'), 17),
#  (('twilight sparkle', 'flim'), 16),
#  (('twilight sparkle', 'maud pie'), 16),
#  (('twilight sparkle', 'gallus'), 16),
#  (('applejack', 'princess celestia'), 16),
#  (('applejack', 'goldie delicious'), 16),
#  (('applejack', 'gladmane'), 16),
#  (('rarity', 'scootaloo'), 16),
#  (('rarity', 'derpy'), 16),
#  (('fluttershy', 'photo finish'), 16),
#  (('maud pie', 'sunburst'), 16),
#  (('rockhoof', 'yona'), 16),
#  (('firelight', 'stellar flare'), 16),
#  (('twilight sparkle', 'flam'), 15),
#  (('twilight sparkle', 'smolder'), 15),
#  (('spike', 'sunburst'), 15),
#  (('apple bloom', 'princess luna'), 15),
#  (('rainbow dash', 'dr. caballeron'), 15),
#  (('fluttershy', 'cutie mark crusaders'), 15),
#  (('pinkie pie', 'daring do'), 15),
#  (('sweetie belle', 'pipsqueak'), 15),
#  (('sweetie belle', 'cozy glow'), 15),
#  (('flam', 'gladmane'), 15),
#  (('spike', 'fancy pants'), 14),
#  (('applejack', 'zecora'), 14),
#  (('applejack', 'princess luna'), 14),
#  (('apple bloom', 'cozy glow'), 14),
#  (('rainbow dash', 'bulk biceps'), 14),
#  (('pinkie pie', 'princess celestia'), 14),
#  (('princess luna', 'sweetie belle'), 14),
#  (('discord', 'princess cadance'), 14),
#  (('yona', 'ocellus'), 14),
#  (('twilight sparkle', 'cheerilee'), 13),
#  (('twilight sparkle', 'queen chrysalis'), 13),
#  (('twilight sparkle', 'prince rutherford'), 13),
#  (('twilight sparkle', 'silverstream'), 13),
#  (('applejack', 'mayor mare'), 13),
#  (('applejack', 'hoity toity'), 13),
#  (('applejack', 'maud pie'), 13),
#  (('granny smith', 'filthy rich'), 13),
#  (('apple bloom', 'pipsqueak'), 13),
#  (('rainbow dash', 'cheese sandwich'), 13),
#  (('rainbow dash', 'maud pie'), 13),
#  (('rainbow dash', 'ocellus'), 13),
#  (('pinkie pie', 'mayor mare'), 13),
#  (('big mcintosh', 'discord'), 13),
#  (('starlight glimmer', 'pharynx'), 13),
#  (('silverstream', 'ocellus'), 13),
#  (('twilight sparkle', 'pipsqueak'), 12),
#  (('twilight sparkle', 'vapor trail'), 12),
#  (('twilight sparkle', 'sky stinger'), 12),
#  (('applejack', 'rockhoof'), 12),
#  (('apple bloom', 'rumble'), 12),
#  (('rainbow dash', 'princess luna'), 12),
#  (('rainbow dash', 'shining armor'), 12),
#  (('rainbow dash', 'ms. peachbottom'), 12),
#  (('rainbow dash', 'garble'), 12),
#  (('rainbow dash', 'goldie delicious'), 12),
#  (('princess celestia', 'princess cadance'), 12),
#  (('princess luna', 'scootaloo'), 12),
#  (('mrs. cake', 'mr. cake'), 12),
#  (('snips', 'trixie'), 12),
#  (('trixie', 'pharynx'), 12),
#  (('trixie', 'sunburst'), 12),
#  (('soarin', 'spitfire'), 12),
#  (('daring do', 'dr. caballeron'), 12),
#  (('princess cadance', 'queen chrysalis'), 12),
#  (('starlight glimmer', 'stellar flare'), 12),
#  (('yona', 'silverstream'), 12),
#  (('twilight sparkle', 'big mcintosh'), 11),
#  (('twilight sparkle', 'ember'), 11),
#  (('twilight sparkle', 'sandbar'), 11),
#  (('twilight sparkle', 'sludge'), 11),
#  (('granny smith', 'sweetie belle'), 11),
#  (('granny smith', 'fluttershy'), 11),
#  (('rainbow dash', 'cutie mark crusaders'), 11),
#  (('rarity', 'shining armor'), 11),
#  (('fluttershy', 'gladmane'), 11),
#  (('snails', 'trixie'), 11),
#  (('scootaloo', 'spitfire'), 11),
#  (('sweetie belle', 'gabby'), 11),
#  (('discord', 'thorax'), 11),
#  (('flim', 'gladmane'), 11),
#  (('queen chrysalis', 'starlight glimmer'), 11),
#  (('starlight glimmer', 'ember'), 11),
#  (('starlight glimmer', 'cozy glow'), 11),
#  (('sandbar', 'cozy glow'), 11),
#  (('twilight sparkle', 'garble'), 10),
#  (('twilight sparkle', 'chancellor neighsay'), 10),
#  (('applejack', 'trixie'), 10),
#  (('applejack', 'photo finish'), 10),
#  (('granny smith', 'flim'), 10),
#  (('rainbow dash', 'windy whistles'), 10),
#  (('rainbow dash', 'sandbar'), 10),
#  (('rarity', 'big mcintosh'), 10),
#  (('rarity', 'princess luna'), 10),
#  (('rarity', 'zephyr breeze'), 10),
#  (('fluttershy', 'bulk biceps'), 10),
#  (('pinkie pie', 'princess cadance'), 10),
#  (('big mcintosh', 'scootaloo'), 10),
#  (('cheerilee', 'diamond tiara'), 10),
#  (('scootaloo', 'babs seed'), 10),
#  (('scootaloo', 'cozy glow'), 10),
#  (('starlight glimmer', 'star swirl the bearded'), 10),
#  (('twilight sparkle', 'mrs. cake'), 9),
#  (('twilight sparkle', 'diamond tiara'), 9),
#  (('twilight sparkle', 'thorax'), 9),
#  (('twilight sparkle', 'yona'), 9),
#  (('spike', 'trixie'), 9),
#  (('spike', 'granny smith'), 9),
#  (('applejack', 'babs seed'), 9),
#  (('applejack', 'smolder'), 9),
#  (('granny smith', 'trixie'), 9),
#  (('rainbow dash', 'princess cadance'), 9),
#  (('rarity', 'flam'), 9),
#  (('rarity', 'capper'), 9),
#  (('fluttershy', 'flam'), 9),
#  (('pinkie pie', 'spitfire'), 9),
#  (('princess luna', 'princess cadance'), 9),
#  (('twilight sparkle', 'fancy pants'), 8),
#  (('twilight sparkle', 'capper'), 8),
#  (('spike', 'mayor mare'), 8),
#  (('applejack', 'cutie mark crusaders'), 8),
#  (('applejack', 'shining armor'), 8),
#  (('applejack', 'princess cadance'), 8),
#  (('granny smith', 'flam'), 8),
#  (('apple bloom', 'mayor mare'), 8),
#  (('rainbow dash', 'smolder'), 8),
#  (('rarity', 'trixie'), 8),
#  (('rarity', 'hoity toity'), 8),
#  (('pinkie pie', 'cheerilee'), 8),
#  (('pinkie pie', 'shining armor'), 8),
#  (('princess luna', 'pipsqueak'), 8),
#  (('silver spoon', 'scootaloo'), 8),
#  (('sweetie belle', 'babs seed'), 8),
#  (('shining armor', 'ms. peachbottom'), 8),
#  (('sandbar', 'chancellor neighsay'), 8),
#  (('gallus', 'cozy glow'), 8),
#  (('yona', 'cozy glow'), 8),
#  (('twilight sparkle', 'spitfire'), 7),
#  (('twilight sparkle', 'sugar belle'), 7),
#  (('twilight sparkle', 'ocellus'), 7),
#  (('spike', 'snails'), 7),
#  (('spike', 'princess luna'), 7),
#  (('applejack', 'yona'), 7),
#  (('applejack', 'gallus'), 7),
#  (('granny smith', 'scootaloo'), 7),
#  (('granny smith', 'goldie delicious'), 7),
#  (('apple bloom', 'flim'), 7),
#  (('apple bloom', 'mrs. cake'), 7),
#  (('rainbow dash', 'double diamond'), 7),
#  (('rainbow dash', 'bow hothoof'), 7),
#  (('rainbow dash', 'yona'), 7),
#  (('rainbow dash', 'capper'), 7),
#  (('rarity', 'cutie mark crusaders'), 7),
#  (('fluttershy', 'gilda'), 7),
#  (('pinkie pie', 'big mcintosh'), 7),
#  (('pinkie pie', 'snails'), 7),
#  (('diamond tiara', 'cutie mark crusaders'), 7),
#  (('scootaloo', 'sugar belle'), 7),
#  (('hoity toity', 'photo finish'), 7),
#  (('garble', 'princess ember'), 7),
#  (('garble', 'starlight glimmer'), 7),
#  (('maud pie', 'mudbriar'), 7),
#  (('starlight glimmer', 'ocellus'), 7),
#  (('smolder', 'sludge'), 7),
#  (('silverstream', 'cozy glow'), 7),
#  (('tempest shadow', 'capper'), 7),
#  (('twilight sparkle', 'double diamond'), 6),
#  (('twilight sparkle', 'the storm king'), 6),
#  (('spike', 'cheerilee'), 6),
#  (('applejack', 'mrs. cake'), 6),
#  (('applejack', 'snails'), 6),
#  (('apple bloom', 'goldie delicious'), 6),
#  (('apple bloom', 'maud pie'), 6),
#  (('apple bloom', 'sandbar'), 6),
#  (('rainbow dash', 'mayor mare'), 6),
#  (('rainbow dash', 'braeburn'), 6),
#  (('rainbow dash', 'derpy'), 6),
#  (('rainbow dash', 'big mcintosh'), 6),
#  (('rainbow dash', 'star swirl the bearded'), 6),
#  (('rarity', 'sweetie drops'), 6),
#  (('rarity', 'star swirl the bearded'), 6),
#  (('rarity', 'rockhoof'), 6),
#  (('rarity', 'cozy glow'), 6),
#  (('fluttershy', 'maud pie'), 6),
#  (('pinkie pie', 'sweetie belle'), 6),
#  (('pinkie pie', 'sugar belle'), 6),
#  (('pinkie pie', 'lord tirek'), 6),
#  (('pinkie pie', 'capper'), 6),
#  (('mrs. cake', 'sugar belle'), 6),
#  (('snips', 'cheerilee'), 6),
#  (('trixie', 'bulk biceps'), 6),
#  (('diamond tiara', 'babs seed'), 6),
#  (('cutie mark crusaders', 'gabby'), 6),
#  (('princess cadance', 'starlight glimmer'), 6),
#  (('sunburst', 'firelight'), 6),
#  (('rockhoof', 'smolder'), 6),
#  (('twilight sparkle', 'sassy saddles'), 5),
#  (('spike', 'rockhoof'), 5),
#  (('applejack', 'sugar belle'), 5),
#  (('applejack', 'silverstream'), 5),
#  (('applejack', 'capper'), 5),
#  (('granny smith', 'cheerilee'), 5),
#  (('rainbow dash', 'zecora'), 5),
#  (('rainbow dash', 'sugar belle'), 5),
#  (('rainbow dash', 'snails'), 5),
#  (('rainbow dash', 'gallus'), 5),
#  (('rainbow dash', 'silverstream'), 5),
#  (('rarity', 'mayor mare'), 5),
#  (('rarity', 'cheerilee'), 5),
#  (('rarity', 'princess ember'), 5),
#  (('rarity', 'flim'), 5),
#  (('fluttershy', 'ms. peachbottom'), 5),
#  (('fluttershy', 'mr. cake'), 5),
#  (('fluttershy', 'snails'), 5),
#  (('fluttershy', 'silverstream'), 5),
#  (('pinkie pie', 'goldie delicious'), 5),
#  (('pinkie pie', 'tempest shadow'), 5),
#  (('mrs. cake', 'sweetie belle'), 5),
#  (('snips', 'scootaloo'), 5),
#  (('diamond tiara', 'pipsqueak'), 5),
#  (('silver spoon', 'sweetie belle'), 5),
#  (('scootaloo', 'trouble shoes'), 5),
#  (('scootaloo', 'bulk biceps'), 5),
#  (('sweetie belle', 'trouble shoes'), 5),
#  (('sweetie belle', 'bulk biceps'), 5),
#  (('flim', 'star swirl the bearded'), 5),
#  (('flam', 'star swirl the bearded'), 5),
#  (('iron will', 'yona'), 5),
#  (('queen chrysalis', 'thorax'), 5),
#  (('starlight glimmer', 'sugar belle'), 5),
#  (('starlight glimmer', 'yona'), 5),
#  (('smolder', 'cozy glow'), 5),
#  (('ocellus', 'cozy glow'), 5),
#  (('twilight sparkle', 'snips'), 4),
#  (('twilight sparkle', 'snails'), 4),
#  (('twilight sparkle', 'silver spoon'), 4),
#  (('twilight sparkle', 'zephyr breeze'), 4),
#  (('spike', 'rover'), 4),
#  (('spike', 'mrs. cake'), 4),
#  (('spike', 'lord tirek'), 4),
#  (('spike', 'nightmare moon'), 4),
#  (('spike', 'capper'), 4),
#  (('applejack', 'soarin'), 4),
#  (('applejack', 'ms. peachbottom'), 4),
#  (('applejack', 'lord tirek'), 4),
#  (('granny smith', 'diamond tiara'), 4),
#  (('granny smith', 'starlight glimmer'), 4),
#  (('apple bloom', 'sugar belle'), 4),
#  (('apple bloom', 'starlight glimmer'), 4),
#  (('rainbow dash', 'nightmare moon'), 4),
#  (('rainbow dash', 'lord tirek'), 4),
#  (('rainbow dash', 'cheerilee'), 4),
#  (('rarity', 'iron will'), 4),
#  (('rarity', 'sludge'), 4),
#  (('fluttershy', 'big mcintosh'), 4),
#  (('fluttershy', 'shining armor'), 4),
#  (('fluttershy', 'lord tirek'), 4),
#  (('pinkie pie', 'pipsqueak'), 4),
#  (('pinkie pie', 'matilda'), 4),
#  (('pinkie pie', 'sandbar'), 4),
#  (('pinkie pie', 'sludge'), 4),
#  (('pinkie pie', 'the storm king'), 4),
#  (('mayor mare', 'derpy'), 4),
#  (('princess celestia', 'queen chrysalis'), 4),
#  (('princess celestia', 'sunburst'), 4),
#  (('big mcintosh', 'zecora'), 4),
#  (('scootaloo', 'pipsqueak'), 4),
#  (('cutie mark crusaders', 'rumble'), 4),
#  (('iron will', 'princess cadance'), 4),
#  (('shining armor', 'queen chrysalis'), 4),
#  (('double diamond', 'sugar belle'), 4),
#  (('sunburst', 'star swirl the bearded'), 4),
#  (('the storm king', 'capper'), 4),
#  (('twilight sparkle', 'photo finish'), 3),
#  (('twilight sparkle', 'bulk biceps'), 3),
#  (('twilight sparkle', 'soarin'), 3),
#  (('twilight sparkle', 'cheese sandwich'), 3),
#  (('spike', 'gallus'), 3),
#  (('spike', 'sugar belle'), 3),
#  (('spike', 'yona'), 3),
#  (('spike', 'tempest shadow'), 3),
#  (('applejack', 'double diamond'), 3),
#  (('applejack', 'prince rutherford'), 3),
#  (('applejack', 'sassy saddles'), 3),
#  (('applejack', 'cheerilee'), 3),
#  (('applejack', 'filthy rich'), 3),
#  (('applejack', 'sunburst'), 3),
#  (('applejack', 'ocellus'), 3),
#  (('applejack', 'sandbar'), 3),
#  (('applejack', 'sludge'), 3),
#  (('apple bloom', 'flam'), 3),
#  (('apple bloom', 'bow hothoof'), 3),
#  (('apple bloom', 'discord'), 3),
#  (('rainbow dash', 'diamond tiara'), 3),
#  (('rainbow dash', 'snips'), 3),
#  (('rainbow dash', 'mr. cake'), 3),
#  (('rainbow dash', 'flim'), 3),
#  (('rainbow dash', 'mrs. cake'), 3),
#  (('rainbow dash', 'filthy rich'), 3),
#  (('rainbow dash', 'sassy saddles'), 3),
#  (('rainbow dash', 'tempest shadow'), 3),
#  (('rarity', 'garble'), 3),
#  (('rarity', 'soarin'), 3),
#  (('rarity', 'filthy rich'), 3),
#  (('rarity', 'smolder'), 3),
#  (('rarity', 'chancellor neighsay'), 3),
#  (('rarity', 'tempest shadow'), 3),
#  (('fluttershy', 'braeburn'), 3),
#  (('pinkie pie', 'ms. peachbottom'), 3),
#  (('pinkie pie', 'bulk biceps'), 3),
#  (('pinkie pie', 'star swirl the bearded'), 3),
#  (('pinkie pie', 'rockhoof'), 3),
#  (('mayor mare', 'big mcintosh'), 3),
#  (('princess celestia', 'mrs. cake'), 3),
#  (('princess celestia', 'mr. cake'), 3),
#  (('princess celestia', 'lord tirek'), 3),
#  (('princess celestia', 'tempest shadow'), 3),
#  (('big mcintosh', 'flim'), 3),
#  (('big mcintosh', 'starlight glimmer'), 3),
#  (('sweetie drops', 'scootaloo'), 3),
#  (('snails', 'sweetie belle'), 3),
#  (('trixie', 'maud pie'), 3),
#  (('zecora', 'pipsqueak'), 3),
#  (('silver spoon', 'babs seed'), 3),
#  (('sweetie belle', 'discord'), 3),
#  (('discord', 'maud pie'), 3),
#  (('derpy', 'matilda'), 3),
#  (('shining armor', 'lord tirek'), 3),
#  (('shining armor', 'starlight glimmer'), 3),
#  (('princess cadance', 'sunburst'), 3),
#  (('starlight glimmer', 'silverstream'), 3),
#  (('thorax', 'silverstream'), 3),
#  (('ember', 'smolder'), 3),
#  (('rockhoof', 'star swirl the bearded'), 3),
#  (('rockhoof', 'silverstream'), 3),
#  (('twilight sparkle', 'hoity toity'), 2),
#  (('twilight sparkle', 'mr. cake'), 2),
#  (('twilight sparkle', 'granny smith'), 2),
#  (('twilight sparkle', 'princess ember'), 2),
#  (('twilight sparkle', 'lightning dust'), 2),
#  (('spike', 'cutie mark crusaders'), 2),
#  (('spike', 'mr. cake'), 2),
#  (('spike', 'derpy'), 2),
#  (('spike', 'silverstream'), 2),
#  (('spike', 'ocellus'), 2),
#  (('spike', 'cozy glow'), 2),
#  (('applejack', 'mr. cake'), 2),
#  (('applejack', 'diamond tiara'), 2),
#  (('applejack', 'young applejack'), 2),
#  (('applejack', 'spitfire'), 2),
#  (('applejack', 'queen chrysalis'), 2),
#  (('applejack', 'lightning dust'), 2),
#  (('applejack', 'trouble shoes'), 2),
#  (('applejack', 'star swirl the bearded'), 2),
#  (('granny smith', 'silver spoon'), 2),
#  (('granny smith', 'rarity'), 2),
#  (('granny smith', 'maud pie'), 2),
#  (('granny smith', 'bulk biceps'), 2),
#  (('apple bloom', 'sweetie drops'), 2),
#  (('apple bloom', 'bulk biceps'), 2),
#  (('rainbow dash', 'silver spoon'), 2),
#  (('rainbow dash', 'flam'), 2),
#  (('rarity', 'bulk biceps'), 2),
#  (('rarity', 'sugar belle'), 2),
#  (('rarity', 'sandbar'), 2),
#  (('rarity', 'gallus'), 2),
#  (('fluttershy', 'mayor mare'), 2),
#  (('fluttershy', 'daring do'), 2),
#  (('fluttershy', 'cheese sandwich'), 2),
#  (('fluttershy', 'mrs. cake'), 2),
#  (('fluttershy', 'double diamond'), 2),
#  (('fluttershy', 'sugar belle'), 2),
#  (('fluttershy', 'prince rutherford'), 2),
#  (('fluttershy', 'star swirl the bearded'), 2),
#  (('fluttershy', 'ocellus'), 2),
#  (('pinkie pie', 'derpy'), 2),
#  (('pinkie pie', 'trixie'), 2),
#  (('pinkie pie', 'ocellus'), 2),
#  (('mayor mare', 'cranky doodle donkey'), 2),
#  (('mayor mare', 'matilda'), 2),
#  (('nightmare moon', 'princess luna'), 2),
#  (('nightmare moon', 'princess celestia'), 2),
#  (('princess celestia', 'shining armor'), 2),
#  (('princess celestia', 'prince rutherford'), 2),
#  (('princess celestia', 'star swirl the bearded'), 2),
#  (('princess luna', 'lord tirek'), 2),
#  (('princess luna', 'tempest shadow'), 2),
#  (('big mcintosh', 'mrs. cake'), 2),
#  (('big mcintosh', 'goldie delicious'), 2),
#  (('mrs. cake', 'starlight glimmer'), 2),
#  (('mrs. cake', 'cozy glow'), 2),
#  (('snails', 'scootaloo'), 2),
#  (('snips', 'sweetie belle'), 2),
#  (('trixie', 'queen chrysalis'), 2),
#  (('trixie', 'princess cadance'), 2),
#  (('zecora', 'queen chrysalis'), 2),
#  (('cheerilee', 'cutie mark crusaders'), 2),
#  (('scootaloo', 'sandbar'), 2),
#  (('spitfire', 'sky stinger'), 2),
#  (('spitfire', 'vapor trail'), 2),
#  (('spitfire', 'bow hothoof'), 2),
#  (('spitfire', 'windy whistles'), 2),
#  (('cutie mark crusaders', 'trouble shoes'), 2),
#  (('cutie mark crusaders', 'discord'), 2),
#  (('cutie mark crusaders', 'cozy glow'), 2),
#  (('discord', 'sandbar'), 2),
#  (('iron will', 'shining armor'), 2),
#  (('bulk biceps', 'lightning dust'), 2),
#  (('shining armor', 'sunburst'), 2),
#  (('princess cadance', 'thorax'), 2),
#  (('lord tirek', 'cozy glow'), 2),
#  (('lord tirek', 'sandbar'), 2),
#  (('starlight glimmer', 'princess ember'), 2),
#  (('starlight glimmer', 'rockhoof'), 2),
#  (('starlight glimmer', 'gallus'), 2),
#  (('starlight glimmer', 'sandbar'), 2),
#  (('prince rutherford', 'thorax'), 2),
#  (('prince rutherford', 'smolder'), 2),
#  (('rockhoof', 'ocellus'), 2),
#  (('rockhoof', 'gallus'), 2),
#  (('star swirl the bearded', 'chancellor neighsay'), 2),
#  (('silverstream', 'chancellor neighsay'), 2),
#  (('twilight sparkle', 'rover'), 1),
#  (('twilight sparkle', 'daring do'), 1),
#  (('twilight sparkle', 'matilda'), 1),
#  (('spike', 'gilda'), 1),
#  (('spike', 'photo finish'), 1),
#  (('spike', 'daring do'), 1),
#  (('spike', 'rumble'), 1),
#  (('spike', 'matilda'), 1),
#  (('spike', 'moon dancer'), 1),
#  (('spike', 'zephyr breeze'), 1),
#  (('spike', 'sweetie drops'), 1),
#  (('spike', 'cranky doodle donkey'), 1),
#  (('spike', 'sandbar'), 1),
#  (('spike', 'chancellor neighsay'), 1),
#  (('applejack', 'nightmare moon'), 1),
#  (('applejack', 'gilda'), 1),
#  (('applejack', 'snips'), 1),
#  (('applejack', 'pipsqueak'), 1),
#  (('applejack', 'bulk biceps'), 1),
#  (('applejack', 'cozy glow'), 1),
#  (('applejack', 'the storm king'), 1),
#  (('applejack', 'tempest shadow'), 1),
#  (('granny smith', 'gilda'), 1),
#  (('granny smith', 'pipsqueak'), 1),
#  (('granny smith', 'mayor mare'), 1),
#  (('granny smith', 'babs seed'), 1),
#  (('apple bloom', 'snips'), 1),
#  (('apple bloom', 'braeburn'), 1),
#  (('apple bloom', 'windy whistles'), 1),
#  (('apple bloom', 'rockhoof'), 1),
#  (('apple bloom', 'chancellor neighsay'), 1),
#  (('apple bloom', 'smolder'), 1),
#  (('rainbow dash', 'sweetie drops'), 1),
#  (('rainbow dash', 'rumble'), 1),
#  (('rainbow dash', 'matilda'), 1),
#  (('rainbow dash', 'sunburst'), 1),
#  (('rainbow dash', 'rockhoof'), 1),
#  (('rainbow dash', 'cozy glow'), 1),
#  (('rarity', 'gilda'), 1),
#  (('rarity', 'mr. cake'), 1),
#  (('rarity', 'lightning dust'), 1),
#  (('rarity', 'ms. peachbottom'), 1),
#  (('rarity', 'double diamond'), 1),
#  (('rarity', 'prince rutherford'), 1),
#  (('rarity', 'spitfire'), 1),
#  (('rarity', 'sunburst'), 1),
#  (('rarity', 'queen chrysalis'), 1),
#  (('rarity', 'lord tirek'), 1),
#  (('fluttershy', 'snips'), 1),
#  (('fluttershy', 'dr. caballeron'), 1),
#  (('fluttershy', 'spitfire'), 1),
#  (('fluttershy', 'soarin'), 1),
#  (('fluttershy', 'queen chrysalis'), 1),
#  (('fluttershy', 'sunburst'), 1),
#  (('fluttershy', 'sandbar'), 1),
#  (('fluttershy', 'smolder'), 1),
#  (('fluttershy', 'yona'), 1),
#  (('fluttershy', 'sludge'), 1),
#  (('fluttershy', 'cozy glow'), 1),
#  (('fluttershy', 'capper'), 1),
#  (('fluttershy', 'tempest shadow'), 1),
#  (('fluttershy', 'princess cadance'), 1),
#  (('pinkie pie', 'sweetie drops'), 1),
#  (('pinkie pie', 'photo finish'), 1),
#  (('pinkie pie', 'braeburn'), 1),
#  (('pinkie pie', 'flim'), 1),
#  (('pinkie pie', 'diamond tiara'), 1),
#  (('pinkie pie', 'double diamond'), 1),
#  (('pinkie pie', 'moon dancer'), 1),
#  (('pinkie pie', 'sunburst'), 1),
#  (('pinkie pie', 'dr. caballeron'), 1),
#  (('pinkie pie', 'smolder'), 1),
#  (('pinkie pie', 'cutie mark crusaders'), 1),
#  (('pinkie pie', 'yona'), 1),
#  (('pinkie pie', 'chancellor neighsay'), 1),
#  (('mayor mare', 'sweetie drops'), 1),
#  (('mayor mare', 'zecora'), 1),
#  (('mayor mare', 'flim'), 1),
#  (('mayor mare', 'flam'), 1),
#  (('mayor mare', 'mrs. cake'), 1),
#  (('nightmare moon', 'pipsqueak'), 1),
#  (('nightmare moon', 'starlight glimmer'), 1),
#  (('princess celestia', 'sweetie drops'), 1),
#  (('princess celestia', 'thorax'), 1),
#  (('princess celestia', 'sandbar'), 1),
#  (('princess celestia', 'ember'), 1),
#  (('princess celestia', 'cozy glow'), 1),
#  (('princess luna', 'shining armor'), 1),
#  (('princess luna', 'discord'), 1),
#  (('princess luna', 'big mcintosh'), 1),
#  (('princess luna', 'sunburst'), 1),
#  (('princess luna', 'star swirl the bearded'), 1),
#  (('princess luna', 'cozy glow'), 1),
#  (('big mcintosh', 'babs seed'), 1),
#  (('big mcintosh', 'filthy rich'), 1),
#  (('big mcintosh', 'maud pie'), 1),
#  (('sweetie drops', 'photo finish'), 1),
#  (('sweetie drops', 'princess cadance'), 1),
#  (('sweetie drops', 'filthy rich'), 1),
#  (('sweetie drops', 'cozy glow'), 1),
#  (('mrs. cake', 'prince rutherford'), 1),
#  (('snails', 'cheerilee'), 1),
#  (('snips', 'silver spoon'), 1),
#  (('snips', 'diamond tiara'), 1),
#  (('trixie', 'cranky doodle donkey'), 1),
#  (('zecora', 'discord'), 1),
#  (('zecora', 'starlight glimmer'), 1),
#  (('cheerilee', 'silver spoon'), 1),
#  (('cheerilee', 'filthy rich'), 1),
#  (('diamond tiara', 'filthy rich'), 1),
#  (('silver spoon', 'pipsqueak'), 1),
#  (('scootaloo', 'braeburn'), 1),
#  (('scootaloo', 'starlight glimmer'), 1),
#  (('sweetie belle', 'braeburn'), 1),
#  (('sweetie belle', 'bow hothoof'), 1),
#  (('sweetie belle', 'sugar belle'), 1),
#  (('sweetie belle', 'starlight glimmer'), 1),
#  (('sweetie belle', 'yona'), 1),
#  (('soarin', 'bulk biceps'), 1),
#  (('cutie mark crusaders', 'babs seed'), 1),
#  (('cutie mark crusaders', 'pipsqueak'), 1),
#  (('cutie mark crusaders', 'sugar belle'), 1),
#  (('cutie mark crusaders', 'starlight glimmer'), 1),
#  (('discord', 'shining armor'), 1),
#  (('discord', 'sunburst'), 1),
#  (('discord', 'sugar belle'), 1),
#  (('discord', 'yona'), 1),
#  (('fancy pants', 'princess cadance'), 1),
#  (('flim', 'chancellor neighsay'), 1),
#  (('flim', 'prince rutherford'), 1),
#  (('cranky doodle donkey', 'starlight glimmer'), 1),
#  (('iron will', 'starlight glimmer'), 1),
#  (('shining armor', 'thorax'), 1),
#  (('starlight glimmer', 'mudbriar'), 1),
#  (('prince rutherford', 'gallus'), 1),
#  (('prince rutherford', 'yona'), 1),
#  (('prince rutherford', 'ember'), 1),
#  (('prince rutherford', 'ocellus'), 1),
#  (('sunburst', 'rockhoof'), 1),
#  (('rockhoof', 'sandbar'), 1),
#  (('gallus', 'chancellor neighsay'), 1),
#  (('yona', 'chancellor neighsay'), 1),
#  (('ocellus', 'chancellor neighsay'), 1)]

# %%
js = {}
for speaker1 in top_101:
    js[speaker1] = {}
    for speaker2 in top_101:
        if speaker1 == speaker2: continue
        try:
            js[speaker1][speaker2] = labels[(speaker1, speaker2)]
        except KeyError as err:
            try:
                js[speaker1][speaker2] = labels[(speaker2, speaker1)]
            except KeyError as err:
                continue

# %%
labels[('pinkie pie','twilight sparkle')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/nv/cw3f8ly11rz_fqddf1glkrz00000gn/T/ipykernel_73185/2278609730.py in <module>
# ----> 1 labels[('pinkie pie','twilight sparkle')]
#
# KeyError: ('pinkie pie', 'twilight sparkle')

# %%
js
# Out:
# {'twilight sparkle': {'rainbow dash': 895,
#   'pinkie pie': 918,
#   'applejack': 771,
#   'rarity': 649,
#   'spike': 1514,
#   'fluttershy': 677,
#   'apple bloom': 102,
#   'starlight glimmer': 432,
#   'sweetie belle': 65,
#   'scootaloo': 44,
#   'discord': 149,
#   'trixie': 69,
#   'princess celestia': 260,
#   'granny smith': 2,
#   'big mcintosh': 11,
#   'princess cadance': 143,
#   'maud pie': 16,
#   'princess luna': 88,
#   'sunburst': 40,
#   'shining armor': 120,
#   'thorax': 9,
#   'diamond tiara': 9,
#   'flim': 16,
#   'smolder': 15,
#   'spitfire': 7,
#   'flam': 15,
#   'zecora': 57,
#   'cheerilee': 13,
#   'gallus': 16,
#   'cutie mark crusaders': 17,
#   'sandbar': 11,
#   'ocellus': 7,
#   'cozy glow': 17,
#   'silverstream': 13,
#   'yona': 9,
#   'prince rutherford': 13,
#   'garble': 10,
#   'zephyr breeze': 4,
#   'rockhoof': 36,
#   'daring do': 1,
#   'queen chrysalis': 13,
#   'lightning dust': 2,
#   'star swirl the bearded': 37,
#   'mayor mare': 18,
#   'sugar belle': 7,
#   'ember': 11,
#   'iron will': 25,
#   'mrs. cake': 9,
#   'tempest shadow': 22,
#   'sassy saddles': 5,
#   'snips': 4,
#   'lord tirek': 23,
#   'silver spoon': 4,
#   'snails': 4,
#   'sludge': 11,
#   'cheese sandwich': 3,
#   'soarin': 3,
#   'pipsqueak': 12,
#   'photo finish': 3,
#   'bulk biceps': 3,
#   'fancy pants': 8,
#   'moon dancer': 54,
#   'capper': 8,
#   'chancellor neighsay': 10,
#   'ms. peachbottom': 22,
#   'mr. cake': 2,
#   'princess ember': 2,
#   'vapor trail': 12,
#   'sky stinger': 12,
#   'hoity toity': 2,
#   'rover': 1,
#   'the storm king': 6,
#   'double diamond': 6,
#   'nightmare moon': 27,
#   'matilda': 1,
#   'princess skystar': 9,
#   'neighsay': 33,
#   'young rainbow dash': 17},
#  'rainbow dash': {'twilight sparkle': 895,
#   'pinkie pie': 696,
#   'applejack': 666,
#   'rarity': 506,
#   'spike': 179,
#   'fluttershy': 530,
#   'apple bloom': 35,
#   'starlight glimmer': 72,
#   'sweetie belle': 21,
#   'scootaloo': 221,
#   'discord': 95,
#   'trixie': 18,
#   'princess celestia': 17,
#   'granny smith': 32,
#   'big mcintosh': 6,
#   'princess cadance': 9,
#   'maud pie': 13,
#   'princess luna': 12,
#   'sunburst': 1,
#   'shining armor': 12,
#   'diamond tiara': 3,
#   'flim': 3,
#   'smolder': 8,
#   'spitfire': 136,
#   'flam': 2,
#   'zecora': 5,
#   'cheerilee': 4,
#   'gallus': 5,
#   'cutie mark crusaders': 11,
#   'sandbar': 10,
#   'ocellus': 13,
#   'cozy glow': 1,
#   'silverstream': 5,
#   'yona': 7,
#   'garble': 12,
#   'gilda': 56,
#   'zephyr breeze': 32,
#   'rockhoof': 1,
#   'quibble pants': 72,
#   'daring do': 52,
#   'lightning dust': 60,
#   'star swirl the bearded': 6,
#   'mayor mare': 6,
#   'sugar belle': 5,
#   'mrs. cake': 3,
#   'tempest shadow': 3,
#   'sassy saddles': 3,
#   'snips': 3,
#   'lord tirek': 4,
#   'rumble': 1,
#   'silver spoon': 2,
#   'snails': 5,
#   'cheese sandwich': 13,
#   'soarin': 43,
#   'filthy rich': 3,
#   'bulk biceps': 14,
#   'goldie delicious': 12,
#   'capper': 7,
#   'bow hothoof': 7,
#   'ms. peachbottom': 12,
#   'mr. cake': 3,
#   'vapor trail': 24,
#   'sky stinger': 17,
#   'windy whistles': 10,
#   'braeburn': 6,
#   'sweetie drops': 1,
#   'derpy': 6,
#   'dr. caballeron': 15,
#   'double diamond': 7,
#   'nightmare moon': 4,
#   'matilda': 1,
#   'young rainbow dash': 4},
#  'pinkie pie': {'twilight sparkle': 918,
#   'rainbow dash': 696,
#   'applejack': 569,
#   'rarity': 483,
#   'spike': 198,
#   'fluttershy': 340,
#   'apple bloom': 45,
#   'starlight glimmer': 101,
#   'sweetie belle': 6,
#   'scootaloo': 18,
#   'discord': 44,
#   'trixie': 2,
#   'princess celestia': 14,
#   'granny smith': 17,
#   'big mcintosh': 7,
#   'princess cadance': 10,
#   'maud pie': 192,
#   'princess luna': 19,
#   'sunburst': 1,
#   'shining armor': 8,
#   'diamond tiara': 1,
#   'flim': 1,
#   'smolder': 1,
#   'spitfire': 9,
#   'zecora': 18,
#   'cheerilee': 8,
#   'cutie mark crusaders': 1,
#   'sandbar': 4,
#   'ocellus': 2,
#   'yona': 1,
#   'prince rutherford': 114,
#   'gilda': 79,
#   'cranky doodle donkey': 106,
#   'rockhoof': 3,
#   'daring do': 15,
#   'star swirl the bearded': 3,
#   'mayor mare': 13,
#   'sugar belle': 6,
#   'iron will': 18,
#   'mrs. cake': 35,
#   'tempest shadow': 5,
#   'lord tirek': 6,
#   'snails': 7,
#   'sludge': 4,
#   'cheese sandwich': 50,
#   'pipsqueak': 4,
#   'photo finish': 1,
#   'bulk biceps': 3,
#   'goldie delicious': 5,
#   'moon dancer': 1,
#   'mudbriar': 61,
#   'capper': 6,
#   'chancellor neighsay': 1,
#   'ms. peachbottom': 3,
#   'mr. cake': 29,
#   'braeburn': 1,
#   'sweetie drops': 1,
#   'the storm king': 4,
#   'derpy': 2,
#   'dr. caballeron': 1,
#   'double diamond': 1,
#   'matilda': 4,
#   'princess skystar': 8},
#  'applejack': {'twilight sparkle': 771,
#   'rainbow dash': 666,
#   'pinkie pie': 569,
#   'rarity': 730,
#   'spike': 238,
#   'fluttershy': 389,
#   'apple bloom': 428,
#   'starlight glimmer': 58,
#   'sweetie belle': 51,
#   'scootaloo': 46,
#   'discord': 41,
#   'trixie': 10,
#   'princess celestia': 16,
#   'granny smith': 139,
#   'big mcintosh': 92,
#   'princess cadance': 8,
#   'maud pie': 13,
#   'princess luna': 14,
#   'sunburst': 3,
#   'shining armor': 8,
#   'diamond tiara': 2,
#   'flim': 36,
#   'smolder': 9,
#   'spitfire': 2,
#   'flam': 19,
#   'zecora': 14,
#   'cheerilee': 3,
#   'gallus': 7,
#   'cutie mark crusaders': 8,
#   'sandbar': 3,
#   'ocellus': 3,
#   'cozy glow': 1,
#   'silverstream': 5,
#   'yona': 7,
#   'prince rutherford': 3,
#   'gilda': 1,
#   'rockhoof': 12,
#   'young applejack': 2,
#   'queen chrysalis': 2,
#   'lightning dust': 2,
#   'star swirl the bearded': 2,
#   'mayor mare': 13,
#   'sugar belle': 5,
#   'mrs. cake': 6,
#   'tempest shadow': 1,
#   'sassy saddles': 3,
#   'snips': 1,
#   'lord tirek': 4,
#   'snails': 6,
#   'sludge': 3,
#   'babs seed': 9,
#   'soarin': 4,
#   'pipsqueak': 1,
#   'filthy rich': 3,
#   'photo finish': 10,
#   'bulk biceps': 1,
#   'goldie delicious': 16,
#   'gladmane': 16,
#   'capper': 5,
#   'ms. peachbottom': 4,
#   'mr. cake': 2,
#   'braeburn': 36,
#   'hoity toity': 13,
#   'the storm king': 1,
#   'double diamond': 3,
#   'trouble shoes': 2,
#   'nightmare moon': 1,
#   'princess skystar': 3},
#  'rarity': {'twilight sparkle': 649,
#   'rainbow dash': 506,
#   'pinkie pie': 483,
#   'applejack': 730,
#   'spike': 326,
#   'fluttershy': 492,
#   'apple bloom': 18,
#   'starlight glimmer': 72,
#   'sweetie belle': 288,
#   'scootaloo': 16,
#   'discord': 19,
#   'trixie': 8,
#   'princess celestia': 19,
#   'granny smith': 2,
#   'big mcintosh': 10,
#   'princess cadance': 20,
#   'maud pie': 54,
#   'princess luna': 10,
#   'sunburst': 1,
#   'shining armor': 11,
#   'flim': 5,
#   'smolder': 3,
#   'spitfire': 1,
#   'flam': 9,
#   'zecora': 44,
#   'cheerilee': 5,
#   'gallus': 2,
#   'cutie mark crusaders': 7,
#   'sandbar': 2,
#   'cozy glow': 6,
#   'prince rutherford': 1,
#   'garble': 3,
#   'gilda': 1,
#   'zephyr breeze': 10,
#   'rockhoof': 6,
#   'queen chrysalis': 1,
#   'lightning dust': 1,
#   'star swirl the bearded': 6,
#   'mayor mare': 5,
#   'sugar belle': 2,
#   'iron will': 4,
#   'tempest shadow': 3,
#   'sassy saddles': 83,
#   'lord tirek': 1,
#   'sludge': 4,
#   'soarin': 3,
#   'filthy rich': 3,
#   'photo finish': 26,
#   'bulk biceps': 2,
#   'fancy pants': 26,
#   'capper': 9,
#   'chancellor neighsay': 3,
#   'ms. peachbottom': 1,
#   'mr. cake': 1,
#   'princess ember': 5,
#   'hoity toity': 8,
#   'rover': 34,
#   'sweetie drops': 6,
#   'derpy': 16,
#   'double diamond': 1,
#   'princess skystar': 2},
#  'spike': {'twilight sparkle': 1514,
#   'rainbow dash': 179,
#   'pinkie pie': 198,
#   'applejack': 238,
#   'rarity': 326,
#   'fluttershy': 134,
#   'apple bloom': 36,
#   'starlight glimmer': 194,
#   'sweetie belle': 18,
#   'scootaloo': 23,
#   'discord': 166,
#   'trixie': 9,
#   'princess celestia': 42,
#   'granny smith': 9,
#   'big mcintosh': 56,
#   'princess cadance': 47,
#   'princess luna': 7,
#   'sunburst': 15,
#   'shining armor': 27,
#   'thorax': 51,
#   'smolder': 56,
#   'zecora': 26,
#   'cheerilee': 6,
#   'gallus': 3,
#   'cutie mark crusaders': 2,
#   'sandbar': 1,
#   'ocellus': 2,
#   'cozy glow': 2,
#   'silverstream': 2,
#   'yona': 3,
#   'garble': 73,
#   'gilda': 1,
#   'zephyr breeze': 1,
#   'cranky doodle donkey': 1,
#   'rockhoof': 5,
#   'daring do': 1,
#   'mayor mare': 8,
#   'sugar belle': 3,
#   'ember': 32,
#   'mrs. cake': 4,
#   'tempest shadow': 3,
#   'snips': 18,
#   'lord tirek': 4,
#   'rumble': 1,
#   'snails': 7,
#   'sludge': 44,
#   'photo finish': 1,
#   'fancy pants': 14,
#   'moon dancer': 1,
#   'capper': 4,
#   'chancellor neighsay': 1,
#   'mr. cake': 2,
#   'princess ember': 34,
#   'rover': 4,
#   'sweetie drops': 1,
#   'derpy': 2,
#   'nightmare moon': 4,
#   'matilda': 1,
#   'princess skystar': 1,
#   'neighsay': 2,
#   'young rainbow dash': 2},
#  'fluttershy': {'twilight sparkle': 677,
#   'rainbow dash': 530,
#   'pinkie pie': 340,
#   'applejack': 389,
#   'rarity': 492,
#   'spike': 134,
#   'apple bloom': 23,
#   'starlight glimmer': 41,
#   'sweetie belle': 31,
#   'scootaloo': 29,
#   'discord': 180,
#   'princess celestia': 32,
#   'granny smith': 11,
#   'big mcintosh': 4,
#   'princess cadance': 1,
#   'maud pie': 6,
#   'princess luna': 21,
#   'sunburst': 1,
#   'shining armor': 4,
#   'flim': 19,
#   'smolder': 1,
#   'spitfire': 1,
#   'flam': 9,
#   'zecora': 27,
#   'cutie mark crusaders': 15,
#   'sandbar': 1,
#   'ocellus': 2,
#   'cozy glow': 1,
#   'silverstream': 5,
#   'yona': 1,
#   'prince rutherford': 2,
#   'gilda': 7,
#   'zephyr breeze': 62,
#   'daring do': 2,
#   'queen chrysalis': 1,
#   'star swirl the bearded': 2,
#   'mayor mare': 2,
#   'sugar belle': 2,
#   'iron will': 26,
#   'mrs. cake': 2,
#   'tempest shadow': 1,
#   'snips': 1,
#   'lord tirek': 4,
#   'snails': 5,
#   'sludge': 1,
#   'cheese sandwich': 2,
#   'soarin': 1,
#   'photo finish': 16,
#   'bulk biceps': 10,
#   'gladmane': 11,
#   'capper': 1,
#   'ms. peachbottom': 5,
#   'mr. cake': 5,
#   'braeburn': 3,
#   'dr. caballeron': 1,
#   'double diamond': 2,
#   'young rainbow dash': 1},
#  'apple bloom': {'twilight sparkle': 102,
#   'rainbow dash': 35,
#   'pinkie pie': 45,
#   'applejack': 428,
#   'rarity': 18,
#   'spike': 36,
#   'fluttershy': 23,
#   'starlight glimmer': 4,
#   'sweetie belle': 467,
#   'scootaloo': 487,
#   'discord': 3,
#   'granny smith': 112,
#   'big mcintosh': 127,
#   'maud pie': 6,
#   'princess luna': 15,
#   'diamond tiara': 56,
#   'flim': 7,
#   'smolder': 1,
#   'flam': 3,
#   'zecora': 27,
#   'cheerilee': 50,
#   'cutie mark crusaders': 26,
#   'sandbar': 6,
#   'cozy glow': 14,
#   'rockhoof': 1,
#   'mayor mare': 8,
#   'sugar belle': 4,
#   'mrs. cake': 7,
#   'snips': 1,
#   'rumble': 12,
#   'silver spoon': 17,
#   'babs seed': 42,
#   'pipsqueak': 13,
#   'gabby': 17,
#   'bulk biceps': 2,
#   'goldie delicious': 6,
#   'chancellor neighsay': 1,
#   'bow hothoof': 3,
#   'windy whistles': 1,
#   'braeburn': 1,
#   'sweetie drops': 2,
#   'trouble shoes': 19},
#  'starlight glimmer': {'twilight sparkle': 432,
#   'rainbow dash': 72,
#   'pinkie pie': 101,
#   'applejack': 58,
#   'rarity': 72,
#   'spike': 194,
#   'fluttershy': 41,
#   'apple bloom': 4,
#   'sweetie belle': 1,
#   'scootaloo': 1,
#   'discord': 48,
#   'trixie': 338,
#   'princess celestia': 37,
#   'granny smith': 4,
#   'big mcintosh': 3,
#   'princess cadance': 6,
#   'maud pie': 44,
#   'princess luna': 57,
#   'sunburst': 178,
#   'shining armor': 3,
#   'thorax': 66,
#   'zecora': 1,
#   'gallus': 2,
#   'cutie mark crusaders': 1,
#   'sandbar': 2,
#   'ocellus': 7,
#   'cozy glow': 11,
#   'silverstream': 3,
#   'yona': 5,
#   'garble': 7,
#   'cranky doodle donkey': 1,
#   'rockhoof': 2,
#   'queen chrysalis': 11,
#   'star swirl the bearded': 10,
#   'sugar belle': 5,
#   'ember': 11,
#   'iron will': 1,
#   'mrs. cake': 2,
#   'mudbriar': 1,
#   'stellar flare': 12,
#   'princess ember': 2,
#   'pharynx': 13,
#   'double diamond': 21,
#   'firelight': 29,
#   'nightmare moon': 1,
#   'young rainbow dash': 7},
#  'sweetie belle': {'twilight sparkle': 65,
#   'rainbow dash': 21,
#   'pinkie pie': 6,
#   'applejack': 51,
#   'rarity': 288,
#   'spike': 18,
#   'fluttershy': 31,
#   'apple bloom': 467,
#   'starlight glimmer': 1,
#   'scootaloo': 440,
#   'discord': 3,
#   'granny smith': 11,
#   'big mcintosh': 37,
#   'princess luna': 14,
#   'diamond tiara': 42,
#   'cheerilee': 28,
#   'cutie mark crusaders': 24,
#   'cozy glow': 15,
#   'yona': 1,
#   'sugar belle': 1,
#   'mrs. cake': 5,
#   'snips': 2,
#   'rumble': 17,
#   'silver spoon': 5,
#   'snails': 3,
#   'babs seed': 8,
#   'pipsqueak': 15,
#   'gabby': 11,
#   'bulk biceps': 5,
#   'bow hothoof': 1,
#   'braeburn': 1,
#   'trouble shoes': 5},
#  'scootaloo': {'twilight sparkle': 44,
#   'rainbow dash': 221,
#   'pinkie pie': 18,
#   'applejack': 46,
#   'rarity': 16,
#   'spike': 23,
#   'fluttershy': 29,
#   'apple bloom': 487,
#   'starlight glimmer': 1,
#   'sweetie belle': 440,
#   'granny smith': 7,
#   'big mcintosh': 10,
#   'princess luna': 12,
#   'diamond tiara': 26,
#   'spitfire': 11,
#   'cheerilee': 19,
#   'cutie mark crusaders': 24,
#   'sandbar': 2,
#   'cozy glow': 10,
#   'lightning dust': 23,
#   'sugar belle': 7,
#   'snips': 5,
#   'rumble': 19,
#   'silver spoon': 8,
#   'snails': 2,
#   'babs seed': 10,
#   'pipsqueak': 4,
#   'gabby': 29,
#   'bulk biceps': 5,
#   'bow hothoof': 22,
#   'windy whistles': 24,
#   'braeburn': 1,
#   'sweetie drops': 3,
#   'trouble shoes': 5,
#   'young rainbow dash': 1},
#  'discord': {'twilight sparkle': 149,
#   'rainbow dash': 95,
#   'pinkie pie': 44,
#   'applejack': 41,
#   'rarity': 19,
#   'spike': 166,
#   'fluttershy': 180,
#   'apple bloom': 3,
#   'starlight glimmer': 48,
#   'sweetie belle': 3,
#   'trixie': 39,
#   'princess celestia': 22,
#   'big mcintosh': 13,
#   'princess cadance': 14,
#   'maud pie': 3,
#   'princess luna': 1,
#   'sunburst': 1,
#   'shining armor': 1,
#   'thorax': 11,
#   'zecora': 1,
#   'cutie mark crusaders': 2,
#   'sandbar': 2,
#   'yona': 1,
#   'sugar belle': 1,
#   'lord tirek': 27},
#  'trixie': {'twilight sparkle': 69,
#   'rainbow dash': 18,
#   'pinkie pie': 2,
#   'applejack': 10,
#   'rarity': 8,
#   'spike': 9,
#   'starlight glimmer': 338,
#   'discord': 39,
#   'granny smith': 9,
#   'princess cadance': 2,
#   'maud pie': 3,
#   'sunburst': 12,
#   'thorax': 36,
#   'cranky doodle donkey': 1,
#   'queen chrysalis': 2,
#   'snips': 12,
#   'snails': 11,
#   'bulk biceps': 6,
#   'pharynx': 12},
#  'princess celestia': {'twilight sparkle': 260,
#   'rainbow dash': 17,
#   'pinkie pie': 14,
#   'applejack': 16,
#   'rarity': 19,
#   'spike': 42,
#   'fluttershy': 32,
#   'starlight glimmer': 37,
#   'discord': 22,
#   'princess cadance': 12,
#   'princess luna': 71,
#   'sunburst': 4,
#   'shining armor': 2,
#   'thorax': 1,
#   'sandbar': 1,
#   'cozy glow': 1,
#   'prince rutherford': 2,
#   'queen chrysalis': 4,
#   'star swirl the bearded': 2,
#   'ember': 1,
#   'mrs. cake': 3,
#   'tempest shadow': 3,
#   'lord tirek': 3,
#   'mr. cake': 3,
#   'sweetie drops': 1,
#   'nightmare moon': 2,
#   'neighsay': 1},
#  'granny smith': {'twilight sparkle': 2,
#   'rainbow dash': 32,
#   'pinkie pie': 17,
#   'applejack': 139,
#   'rarity': 2,
#   'spike': 9,
#   'fluttershy': 11,
#   'apple bloom': 112,
#   'starlight glimmer': 4,
#   'sweetie belle': 11,
#   'scootaloo': 7,
#   'trixie': 9,
#   'big mcintosh': 21,
#   'maud pie': 2,
#   'diamond tiara': 4,
#   'flim': 10,
#   'flam': 8,
#   'cheerilee': 5,
#   'gilda': 1,
#   'young applejack': 44,
#   'mayor mare': 1,
#   'silver spoon': 2,
#   'babs seed': 1,
#   'pipsqueak': 1,
#   'filthy rich': 13,
#   'bulk biceps': 2,
#   'goldie delicious': 7,
#   'young big mcintosh': 6},
#  'big mcintosh': {'twilight sparkle': 11,
#   'rainbow dash': 6,
#   'pinkie pie': 7,
#   'applejack': 92,
#   'rarity': 10,
#   'spike': 56,
#   'fluttershy': 4,
#   'apple bloom': 127,
#   'starlight glimmer': 3,
#   'sweetie belle': 37,
#   'scootaloo': 10,
#   'discord': 13,
#   'granny smith': 21,
#   'maud pie': 1,
#   'princess luna': 1,
#   'flim': 3,
#   'zecora': 4,
#   'cheerilee': 29,
#   'mayor mare': 3,
#   'sugar belle': 37,
#   'mrs. cake': 2,
#   'babs seed': 1,
#   'filthy rich': 1,
#   'goldie delicious': 2},
#  'princess cadance': {'twilight sparkle': 143,
#   'rainbow dash': 9,
#   'pinkie pie': 10,
#   'applejack': 8,
#   'rarity': 20,
#   'spike': 47,
#   'fluttershy': 1,
#   'starlight glimmer': 6,
#   'discord': 14,
#   'trixie': 2,
#   'princess celestia': 12,
#   'princess luna': 9,
#   'sunburst': 3,
#   'shining armor': 63,
#   'thorax': 2,
#   'queen chrysalis': 12,
#   'iron will': 4,
#   'fancy pants': 1,
#   'sweetie drops': 1},
#  'maud pie': {'twilight sparkle': 16,
#   'rainbow dash': 13,
#   'pinkie pie': 192,
#   'applejack': 13,
#   'rarity': 54,
#   'fluttershy': 6,
#   'apple bloom': 6,
#   'starlight glimmer': 44,
#   'discord': 3,
#   'trixie': 3,
#   'granny smith': 2,
#   'big mcintosh': 1,
#   'sunburst': 16,
#   'mudbriar': 7},
#  'princess luna': {'twilight sparkle': 88,
#   'rainbow dash': 12,
#   'pinkie pie': 19,
#   'applejack': 14,
#   'rarity': 10,
#   'spike': 7,
#   'fluttershy': 21,
#   'apple bloom': 15,
#   'starlight glimmer': 57,
#   'sweetie belle': 14,
#   'scootaloo': 12,
#   'discord': 1,
#   'princess celestia': 71,
#   'big mcintosh': 1,
#   'princess cadance': 9,
#   'sunburst': 1,
#   'shining armor': 1,
#   'cozy glow': 1,
#   'star swirl the bearded': 1,
#   'tempest shadow': 2,
#   'lord tirek': 2,
#   'pipsqueak': 8,
#   'nightmare moon': 2},
#  'sunburst': {'twilight sparkle': 40,
#   'rainbow dash': 1,
#   'pinkie pie': 1,
#   'applejack': 3,
#   'rarity': 1,
#   'spike': 15,
#   'fluttershy': 1,
#   'starlight glimmer': 178,
#   'discord': 1,
#   'trixie': 12,
#   'princess celestia': 4,
#   'princess cadance': 3,
#   'maud pie': 16,
#   'princess luna': 1,
#   'shining armor': 2,
#   'rockhoof': 1,
#   'star swirl the bearded': 4,
#   'stellar flare': 26,
#   'firelight': 6},
#  'shining armor': {'twilight sparkle': 120,
#   'rainbow dash': 12,
#   'pinkie pie': 8,
#   'applejack': 8,
#   'rarity': 11,
#   'spike': 27,
#   'fluttershy': 4,
#   'starlight glimmer': 3,
#   'discord': 1,
#   'princess celestia': 2,
#   'princess cadance': 63,
#   'princess luna': 1,
#   'sunburst': 2,
#   'thorax': 1,
#   'queen chrysalis': 4,
#   'iron will': 2,
#   'lord tirek': 3,
#   'ms. peachbottom': 8},
#  'thorax': {'twilight sparkle': 9,
#   'spike': 51,
#   'starlight glimmer': 66,
#   'discord': 11,
#   'trixie': 36,
#   'princess celestia': 1,
#   'princess cadance': 2,
#   'shining armor': 1,
#   'silverstream': 3,
#   'prince rutherford': 2,
#   'queen chrysalis': 5,
#   'ember': 35,
#   'pharynx': 27},
#  'diamond tiara': {'twilight sparkle': 9,
#   'rainbow dash': 3,
#   'pinkie pie': 1,
#   'applejack': 2,
#   'apple bloom': 56,
#   'sweetie belle': 42,
#   'scootaloo': 26,
#   'granny smith': 4,
#   'cheerilee': 10,
#   'cutie mark crusaders': 7,
#   'snips': 1,
#   'silver spoon': 51,
#   'babs seed': 6,
#   'pipsqueak': 5,
#   'filthy rich': 1},
#  'flim': {'twilight sparkle': 16,
#   'rainbow dash': 3,
#   'pinkie pie': 1,
#   'applejack': 36,
#   'rarity': 5,
#   'fluttershy': 19,
#   'apple bloom': 7,
#   'granny smith': 10,
#   'big mcintosh': 3,
#   'flam': 141,
#   'prince rutherford': 1,
#   'star swirl the bearded': 5,
#   'mayor mare': 1,
#   'gladmane': 11,
#   'chancellor neighsay': 1},
#  'smolder': {'twilight sparkle': 15,
#   'rainbow dash': 8,
#   'pinkie pie': 1,
#   'applejack': 9,
#   'rarity': 3,
#   'spike': 56,
#   'fluttershy': 1,
#   'apple bloom': 1,
#   'gallus': 24,
#   'sandbar': 22,
#   'ocellus': 50,
#   'cozy glow': 5,
#   'silverstream': 25,
#   'yona': 23,
#   'prince rutherford': 2,
#   'rockhoof': 6,
#   'ember': 3,
#   'sludge': 7},
#  'spitfire': {'twilight sparkle': 7,
#   'rainbow dash': 136,
#   'pinkie pie': 9,
#   'applejack': 2,
#   'rarity': 1,
#   'fluttershy': 1,
#   'scootaloo': 11,
#   'lightning dust': 18,
#   'soarin': 12,
#   'bow hothoof': 2,
#   'vapor trail': 2,
#   'sky stinger': 2,
#   'windy whistles': 2},
#  'flam': {'twilight sparkle': 15,
#   'rainbow dash': 2,
#   'applejack': 19,
#   'rarity': 9,
#   'fluttershy': 9,
#   'apple bloom': 3,
#   'granny smith': 8,
#   'flim': 141,
#   'star swirl the bearded': 5,
#   'mayor mare': 1,
#   'gladmane': 15},
#  'zecora': {'twilight sparkle': 57,
#   'rainbow dash': 5,
#   'pinkie pie': 18,
#   'applejack': 14,
#   'rarity': 44,
#   'spike': 26,
#   'fluttershy': 27,
#   'apple bloom': 27,
#   'starlight glimmer': 1,
#   'discord': 1,
#   'big mcintosh': 4,
#   'queen chrysalis': 2,
#   'mayor mare': 1,
#   'pipsqueak': 3},
#  'cheerilee': {'twilight sparkle': 13,
#   'rainbow dash': 4,
#   'pinkie pie': 8,
#   'applejack': 3,
#   'rarity': 5,
#   'spike': 6,
#   'apple bloom': 50,
#   'sweetie belle': 28,
#   'scootaloo': 19,
#   'granny smith': 5,
#   'big mcintosh': 29,
#   'diamond tiara': 10,
#   'cutie mark crusaders': 2,
#   'snips': 6,
#   'silver spoon': 1,
#   'snails': 1,
#   'filthy rich': 1},
#  'gallus': {'twilight sparkle': 16,
#   'rainbow dash': 5,
#   'applejack': 7,
#   'rarity': 2,
#   'spike': 3,
#   'starlight glimmer': 2,
#   'smolder': 24,
#   'sandbar': 26,
#   'ocellus': 26,
#   'cozy glow': 8,
#   'silverstream': 48,
#   'yona': 21,
#   'prince rutherford': 1,
#   'rockhoof': 2,
#   'chancellor neighsay': 1,
#   'neighsay': 1},
#  'cutie mark crusaders': {'twilight sparkle': 17,
#   'rainbow dash': 11,
#   'pinkie pie': 1,
#   'applejack': 8,
#   'rarity': 7,
#   'spike': 2,
#   'fluttershy': 15,
#   'apple bloom': 26,
#   'starlight glimmer': 1,
#   'sweetie belle': 24,
#   'scootaloo': 24,
#   'discord': 2,
#   'diamond tiara': 7,
#   'cheerilee': 2,
#   'cozy glow': 2,
#   'sugar belle': 1,
#   'rumble': 4,
#   'babs seed': 1,
#   'pipsqueak': 1,
#   'gabby': 6,
#   'trouble shoes': 2},
#  'sandbar': {'twilight sparkle': 11,
#   'rainbow dash': 10,
#   'pinkie pie': 4,
#   'applejack': 3,
#   'rarity': 2,
#   'spike': 1,
#   'fluttershy': 1,
#   'apple bloom': 6,
#   'starlight glimmer': 2,
#   'scootaloo': 2,
#   'discord': 2,
#   'princess celestia': 1,
#   'smolder': 22,
#   'gallus': 26,
#   'ocellus': 20,
#   'cozy glow': 11,
#   'silverstream': 21,
#   'yona': 19,
#   'rockhoof': 1,
#   'lord tirek': 2,
#   'chancellor neighsay': 8},
#  'ocellus': {'twilight sparkle': 7,
#   'rainbow dash': 13,
#   'pinkie pie': 2,
#   'applejack': 3,
#   'spike': 2,
#   'fluttershy': 2,
#   'starlight glimmer': 7,
#   'smolder': 50,
#   'gallus': 26,
#   'sandbar': 20,
#   'cozy glow': 5,
#   'silverstream': 13,
#   'yona': 14,
#   'prince rutherford': 1,
#   'rockhoof': 2,
#   'chancellor neighsay': 1},
#  'cozy glow': {'twilight sparkle': 17,
#   'rainbow dash': 1,
#   'applejack': 1,
#   'rarity': 6,
#   'spike': 2,
#   'fluttershy': 1,
#   'apple bloom': 14,
#   'starlight glimmer': 11,
#   'sweetie belle': 15,
#   'scootaloo': 10,
#   'princess celestia': 1,
#   'princess luna': 1,
#   'smolder': 5,
#   'gallus': 8,
#   'cutie mark crusaders': 2,
#   'sandbar': 11,
#   'ocellus': 5,
#   'silverstream': 7,
#   'yona': 8,
#   'mrs. cake': 2,
#   'lord tirek': 2,
#   'chancellor neighsay': 24,
#   'sweetie drops': 1},
#  'silverstream': {'twilight sparkle': 13,
#   'rainbow dash': 5,
#   'applejack': 5,
#   'spike': 2,
#   'fluttershy': 5,
#   'starlight glimmer': 3,
#   'thorax': 3,
#   'smolder': 25,
#   'gallus': 48,
#   'sandbar': 21,
#   'ocellus': 13,
#   'cozy glow': 7,
#   'yona': 12,
#   'rockhoof': 3,
#   'chancellor neighsay': 2,
#   'neighsay': 1},
#  'yona': {'twilight sparkle': 9,
#   'rainbow dash': 7,
#   'pinkie pie': 1,
#   'applejack': 7,
#   'spike': 3,
#   'fluttershy': 1,
#   'starlight glimmer': 5,
#   'sweetie belle': 1,
#   'discord': 1,
#   'smolder': 23,
#   'gallus': 21,
#   'sandbar': 19,
#   'ocellus': 14,
#   'cozy glow': 8,
#   'silverstream': 12,
#   'prince rutherford': 1,
#   'rockhoof': 16,
#   'iron will': 5,
#   'chancellor neighsay': 1,
#   'neighsay': 2},
#  'prince rutherford': {'twilight sparkle': 13,
#   'pinkie pie': 114,
#   'applejack': 3,
#   'rarity': 1,
#   'fluttershy': 2,
#   'princess celestia': 2,
#   'thorax': 2,
#   'flim': 1,
#   'smolder': 2,
#   'gallus': 1,
#   'ocellus': 1,
#   'yona': 1,
#   'ember': 1,
#   'mrs. cake': 1,
#   'neighsay': 2},
#  'garble': {'twilight sparkle': 10,
#   'rainbow dash': 12,
#   'rarity': 3,
#   'spike': 73,
#   'starlight glimmer': 7,
#   'princess ember': 7},
#  'gilda': {'rainbow dash': 56,
#   'pinkie pie': 79,
#   'applejack': 1,
#   'rarity': 1,
#   'spike': 1,
#   'fluttershy': 7,
#   'granny smith': 1},
#  'zephyr breeze': {'twilight sparkle': 4,
#   'rainbow dash': 32,
#   'rarity': 10,
#   'spike': 1,
#   'fluttershy': 62},
#  'cranky doodle donkey': {'pinkie pie': 106,
#   'spike': 1,
#   'starlight glimmer': 1,
#   'trixie': 1,
#   'mayor mare': 2,
#   'matilda': 19},
#  'rockhoof': {'twilight sparkle': 36,
#   'rainbow dash': 1,
#   'pinkie pie': 3,
#   'applejack': 12,
#   'rarity': 6,
#   'spike': 5,
#   'apple bloom': 1,
#   'starlight glimmer': 2,
#   'sunburst': 1,
#   'smolder': 6,
#   'gallus': 2,
#   'sandbar': 1,
#   'ocellus': 2,
#   'silverstream': 3,
#   'yona': 16,
#   'star swirl the bearded': 3},
#  'quibble pants': {'rainbow dash': 72, 'daring do': 18, 'dr. caballeron': 18},
#  'young applejack': {'applejack': 2,
#   'granny smith': 44,
#   'filthy rich': 30,
#   'young big mcintosh': 34},
#  'daring do': {'twilight sparkle': 1,
#   'rainbow dash': 52,
#   'pinkie pie': 15,
#   'spike': 1,
#   'fluttershy': 2,
#   'quibble pants': 18,
#   'dr. caballeron': 12},
#  'queen chrysalis': {'twilight sparkle': 13,
#   'applejack': 2,
#   'rarity': 1,
#   'fluttershy': 1,
#   'starlight glimmer': 11,
#   'trixie': 2,
#   'princess celestia': 4,
#   'princess cadance': 12,
#   'shining armor': 4,
#   'thorax': 5,
#   'zecora': 2},
#  'lightning dust': {'twilight sparkle': 2,
#   'rainbow dash': 60,
#   'applejack': 2,
#   'rarity': 1,
#   'scootaloo': 23,
#   'spitfire': 18,
#   'bulk biceps': 2},
#  'star swirl the bearded': {'twilight sparkle': 37,
#   'rainbow dash': 6,
#   'pinkie pie': 3,
#   'applejack': 2,
#   'rarity': 6,
#   'fluttershy': 2,
#   'starlight glimmer': 10,
#   'princess celestia': 2,
#   'princess luna': 1,
#   'sunburst': 4,
#   'flim': 5,
#   'flam': 5,
#   'rockhoof': 3,
#   'chancellor neighsay': 2},
#  'mayor mare': {'twilight sparkle': 18,
#   'rainbow dash': 6,
#   'pinkie pie': 13,
#   'applejack': 13,
#   'rarity': 5,
#   'spike': 8,
#   'fluttershy': 2,
#   'apple bloom': 8,
#   'granny smith': 1,
#   'big mcintosh': 3,
#   'flim': 1,
#   'flam': 1,
#   'zecora': 1,
#   'cranky doodle donkey': 2,
#   'mrs. cake': 1,
#   'sweetie drops': 1,
#   'derpy': 4,
#   'matilda': 2},
#  'sugar belle': {'twilight sparkle': 7,
#   'rainbow dash': 5,
#   'pinkie pie': 6,
#   'applejack': 5,
#   'rarity': 2,
#   'spike': 3,
#   'fluttershy': 2,
#   'apple bloom': 4,
#   'starlight glimmer': 5,
#   'sweetie belle': 1,
#   'scootaloo': 7,
#   'discord': 1,
#   'big mcintosh': 37,
#   'cutie mark crusaders': 1,
#   'mrs. cake': 6,
#   'double diamond': 4},
#  'ember': {'twilight sparkle': 11,
#   'spike': 32,
#   'starlight glimmer': 11,
#   'princess celestia': 1,
#   'thorax': 35,
#   'smolder': 3,
#   'prince rutherford': 1,
#   'neighsay': 3},
#  'iron will': {'twilight sparkle': 25,
#   'pinkie pie': 18,
#   'rarity': 4,
#   'fluttershy': 26,
#   'starlight glimmer': 1,
#   'princess cadance': 4,
#   'shining armor': 2,
#   'yona': 5},
#  'mrs. cake': {'twilight sparkle': 9,
#   'rainbow dash': 3,
#   'pinkie pie': 35,
#   'applejack': 6,
#   'spike': 4,
#   'fluttershy': 2,
#   'apple bloom': 7,
#   'starlight glimmer': 2,
#   'sweetie belle': 5,
#   'princess celestia': 3,
#   'big mcintosh': 2,
#   'cozy glow': 2,
#   'prince rutherford': 1,
#   'mayor mare': 1,
#   'sugar belle': 6,
#   'mr. cake': 12},
#  'tempest shadow': {'twilight sparkle': 22,
#   'rainbow dash': 3,
#   'pinkie pie': 5,
#   'applejack': 1,
#   'rarity': 3,
#   'spike': 3,
#   'fluttershy': 1,
#   'princess celestia': 3,
#   'princess luna': 2,
#   'capper': 7,
#   'the storm king': 27},
#  'sassy saddles': {'twilight sparkle': 5,
#   'rainbow dash': 3,
#   'applejack': 3,
#   'rarity': 83},
#  'snips': {'twilight sparkle': 4,
#   'rainbow dash': 3,
#   'applejack': 1,
#   'spike': 18,
#   'fluttershy': 1,
#   'apple bloom': 1,
#   'sweetie belle': 2,
#   'scootaloo': 5,
#   'trixie': 12,
#   'diamond tiara': 1,
#   'cheerilee': 6,
#   'silver spoon': 1,
#   'snails': 36},
#  'lord tirek': {'twilight sparkle': 23,
#   'rainbow dash': 4,
#   'pinkie pie': 6,
#   'applejack': 4,
#   'rarity': 1,
#   'spike': 4,
#   'fluttershy': 4,
#   'discord': 27,
#   'princess celestia': 3,
#   'princess luna': 2,
#   'shining armor': 3,
#   'sandbar': 2,
#   'cozy glow': 2},
#  'rumble': {'rainbow dash': 1,
#   'spike': 1,
#   'apple bloom': 12,
#   'sweetie belle': 17,
#   'scootaloo': 19,
#   'cutie mark crusaders': 4},
#  'silver spoon': {'twilight sparkle': 4,
#   'rainbow dash': 2,
#   'apple bloom': 17,
#   'sweetie belle': 5,
#   'scootaloo': 8,
#   'granny smith': 2,
#   'diamond tiara': 51,
#   'cheerilee': 1,
#   'snips': 1,
#   'babs seed': 3,
#   'pipsqueak': 1},
#  'snails': {'twilight sparkle': 4,
#   'rainbow dash': 5,
#   'pinkie pie': 7,
#   'applejack': 6,
#   'spike': 7,
#   'fluttershy': 5,
#   'sweetie belle': 3,
#   'scootaloo': 2,
#   'trixie': 11,
#   'cheerilee': 1,
#   'snips': 36},
#  'sludge': {'twilight sparkle': 11,
#   'pinkie pie': 4,
#   'applejack': 3,
#   'rarity': 4,
#   'spike': 44,
#   'fluttershy': 1,
#   'smolder': 7},
#  'cheese sandwich': {'twilight sparkle': 3,
#   'rainbow dash': 13,
#   'pinkie pie': 50,
#   'fluttershy': 2},
#  'babs seed': {'applejack': 9,
#   'apple bloom': 42,
#   'sweetie belle': 8,
#   'scootaloo': 10,
#   'granny smith': 1,
#   'big mcintosh': 1,
#   'diamond tiara': 6,
#   'cutie mark crusaders': 1,
#   'silver spoon': 3},
#  'soarin': {'twilight sparkle': 3,
#   'rainbow dash': 43,
#   'applejack': 4,
#   'rarity': 3,
#   'fluttershy': 1,
#   'spitfire': 12,
#   'bulk biceps': 1},
#  'pipsqueak': {'twilight sparkle': 12,
#   'pinkie pie': 4,
#   'applejack': 1,
#   'apple bloom': 13,
#   'sweetie belle': 15,
#   'scootaloo': 4,
#   'granny smith': 1,
#   'princess luna': 8,
#   'diamond tiara': 5,
#   'zecora': 3,
#   'cutie mark crusaders': 1,
#   'silver spoon': 1,
#   'nightmare moon': 1},
#  'gabby': {'apple bloom': 17,
#   'sweetie belle': 11,
#   'scootaloo': 29,
#   'cutie mark crusaders': 6},
#  'filthy rich': {'rainbow dash': 3,
#   'applejack': 3,
#   'rarity': 3,
#   'granny smith': 13,
#   'big mcintosh': 1,
#   'diamond tiara': 1,
#   'cheerilee': 1,
#   'young applejack': 30,
#   'sweetie drops': 1,
#   'young big mcintosh': 9},
#  'photo finish': {'twilight sparkle': 3,
#   'pinkie pie': 1,
#   'applejack': 10,
#   'rarity': 26,
#   'spike': 1,
#   'fluttershy': 16,
#   'hoity toity': 7,
#   'sweetie drops': 1},
#  'bulk biceps': {'twilight sparkle': 3,
#   'rainbow dash': 14,
#   'pinkie pie': 3,
#   'applejack': 1,
#   'rarity': 2,
#   'fluttershy': 10,
#   'apple bloom': 2,
#   'sweetie belle': 5,
#   'scootaloo': 5,
#   'trixie': 6,
#   'granny smith': 2,
#   'lightning dust': 2,
#   'soarin': 1},
#  'fancy pants': {'twilight sparkle': 8,
#   'rarity': 26,
#   'spike': 14,
#   'princess cadance': 1},
#  'goldie delicious': {'rainbow dash': 12,
#   'pinkie pie': 5,
#   'applejack': 16,
#   'apple bloom': 6,
#   'granny smith': 7,
#   'big mcintosh': 2},
#  'moon dancer': {'twilight sparkle': 54, 'pinkie pie': 1, 'spike': 1},
#  'mudbriar': {'pinkie pie': 61, 'starlight glimmer': 1, 'maud pie': 7},
#  'gladmane': {'applejack': 16, 'fluttershy': 11, 'flim': 11, 'flam': 15},
#  'capper': {'twilight sparkle': 8,
#   'rainbow dash': 7,
#   'pinkie pie': 6,
#   'applejack': 5,
#   'rarity': 9,
#   'spike': 4,
#   'fluttershy': 1,
#   'tempest shadow': 7,
#   'the storm king': 4,
#   'princess skystar': 1},
#  'chancellor neighsay': {'twilight sparkle': 10,
#   'pinkie pie': 1,
#   'rarity': 3,
#   'spike': 1,
#   'apple bloom': 1,
#   'flim': 1,
#   'gallus': 1,
#   'sandbar': 8,
#   'ocellus': 1,
#   'cozy glow': 24,
#   'silverstream': 2,
#   'yona': 1,
#   'star swirl the bearded': 2},
#  'bow hothoof': {'rainbow dash': 7,
#   'apple bloom': 3,
#   'sweetie belle': 1,
#   'scootaloo': 22,
#   'spitfire': 2,
#   'windy whistles': 18},
#  'stellar flare': {'starlight glimmer': 12, 'sunburst': 26, 'firelight': 16},
#  'ms. peachbottom': {'twilight sparkle': 22,
#   'rainbow dash': 12,
#   'pinkie pie': 3,
#   'applejack': 4,
#   'rarity': 1,
#   'fluttershy': 5,
#   'shining armor': 8},
#  'mr. cake': {'twilight sparkle': 2,
#   'rainbow dash': 3,
#   'pinkie pie': 29,
#   'applejack': 2,
#   'rarity': 1,
#   'spike': 2,
#   'fluttershy': 5,
#   'princess celestia': 3,
#   'mrs. cake': 12},
#  'princess ember': {'twilight sparkle': 2,
#   'rarity': 5,
#   'spike': 34,
#   'starlight glimmer': 2,
#   'garble': 7},
#  'vapor trail': {'twilight sparkle': 12,
#   'rainbow dash': 24,
#   'spitfire': 2,
#   'sky stinger': 22},
#  'sky stinger': {'twilight sparkle': 12,
#   'rainbow dash': 17,
#   'spitfire': 2,
#   'vapor trail': 22},
#  'windy whistles': {'rainbow dash': 10,
#   'apple bloom': 1,
#   'scootaloo': 24,
#   'spitfire': 2,
#   'bow hothoof': 18},
#  'braeburn': {'rainbow dash': 6,
#   'pinkie pie': 1,
#   'applejack': 36,
#   'fluttershy': 3,
#   'apple bloom': 1,
#   'sweetie belle': 1,
#   'scootaloo': 1},
#  'hoity toity': {'twilight sparkle': 2,
#   'applejack': 13,
#   'rarity': 8,
#   'photo finish': 7},
#  'pharynx': {'starlight glimmer': 13, 'trixie': 12, 'thorax': 27},
#  'rover': {'twilight sparkle': 1, 'rarity': 34, 'spike': 4},
#  'sweetie drops': {'rainbow dash': 1,
#   'pinkie pie': 1,
#   'rarity': 6,
#   'spike': 1,
#   'apple bloom': 2,
#   'scootaloo': 3,
#   'princess celestia': 1,
#   'princess cadance': 1,
#   'cozy glow': 1,
#   'mayor mare': 1,
#   'filthy rich': 1,
#   'photo finish': 1},
#  'the storm king': {'twilight sparkle': 6,
#   'pinkie pie': 4,
#   'applejack': 1,
#   'tempest shadow': 27,
#   'capper': 4},
#  'derpy': {'rainbow dash': 6,
#   'pinkie pie': 2,
#   'rarity': 16,
#   'spike': 2,
#   'mayor mare': 4,
#   'matilda': 3},
#  'dr. caballeron': {'rainbow dash': 15,
#   'pinkie pie': 1,
#   'fluttershy': 1,
#   'quibble pants': 18,
#   'daring do': 12},
#  'double diamond': {'twilight sparkle': 6,
#   'rainbow dash': 7,
#   'pinkie pie': 1,
#   'applejack': 3,
#   'rarity': 1,
#   'fluttershy': 2,
#   'starlight glimmer': 21,
#   'sugar belle': 4},
#  'trouble shoes': {'applejack': 2,
#   'apple bloom': 19,
#   'sweetie belle': 5,
#   'scootaloo': 5,
#   'cutie mark crusaders': 2},
#  'firelight': {'starlight glimmer': 29, 'sunburst': 6, 'stellar flare': 16},
#  'nightmare moon': {'twilight sparkle': 27,
#   'rainbow dash': 4,
#   'applejack': 1,
#   'spike': 4,
#   'starlight glimmer': 1,
#   'princess celestia': 2,
#   'princess luna': 2,
#   'pipsqueak': 1},
#  'matilda': {'twilight sparkle': 1,
#   'rainbow dash': 1,
#   'pinkie pie': 4,
#   'spike': 1,
#   'cranky doodle donkey': 19,
#   'mayor mare': 2,
#   'derpy': 3},
#  'young big mcintosh': {'granny smith': 6,
#   'young applejack': 34,
#   'filthy rich': 9},
#  'princess skystar': {'twilight sparkle': 9,
#   'pinkie pie': 8,
#   'applejack': 3,
#   'rarity': 2,
#   'spike': 1,
#   'capper': 1},
#  'neighsay': {'twilight sparkle': 33,
#   'spike': 2,
#   'princess celestia': 1,
#   'gallus': 1,
#   'silverstream': 1,
#   'yona': 2,
#   'prince rutherford': 2,
#   'ember': 3},
#  'young rainbow dash': {'twilight sparkle': 17,
#   'rainbow dash': 4,
#   'spike': 2,
#   'fluttershy': 1,
#   'starlight glimmer': 7,
#   'scootaloo': 1}}

# %%
#top3 most connected
js_connection = {}
for speaker in js:
    js_connection[speaker]=len(js[speaker].items())
sorted_l = list(js_connection.items())
sorted_l.sort(key=lambda x: -x[1])
top3_edges = [t[0] for t in sorted_l][0:3]
top3_edges
# Out:
# ['twilight sparkle', 'rainbow dash', 'applejack']

# %%
#top3 sum of weights
js_weights = {}
for speaker in js:
    js_weights[speaker]=sum(map(lambda x: x[1], js[speaker].items()))

sorted_w = list(js_weights.items())
sorted_w.sort(key=lambda x: -x[1])
top3_weights = [t[0] for t in sorted_w][0:3]
top3_weights
# Out:
# ['twilight sparkle', 'rainbow dash', 'applejack']

# %%
#top3 centrality betweenness
bc = nx.betweenness_centrality(G)
bc
# Out:
# {'twilight sparkle': 0.15638394378786105,
#  'spike': 0.07899104162741868,
#  'applejack': 0.1080215148217112,
#  'granny smith': 0.02629643686581441,
#  'apple bloom': 0.03295195910766955,
#  'rainbow dash': 0.14008522353032082,
#  'rarity': 0.07044272075385766,
#  'fluttershy': 0.053452035340405345,
#  'pinkie pie': 0.08397087539088101,
#  'mayor mare': 0.0032928980564101984,
#  'nightmare moon': 0.00014486355395446304,
#  'princess celestia': 0.0070482361711743675,
#  'princess luna': 0.0023287267850394876,
#  'big mcintosh': 0.004162540505775727,
#  'sweetie drops': 0.0010143647776019885,
#  'mrs. cake': 0.0008107960922655181,
#  'mr. cake': 1.2626262626262626e-05,
#  'gilda': 0.0,
#  'snails': 0.0001272004779654584,
#  'snips': 0.00045753697561461745,
#  'trixie': 0.008487517227596404,
#  'zecora': 0.0006123991755085298,
#  'cheerilee': 0.0010859290216882922,
#  'diamond tiara': 0.0011637084275382087,
#  'silver spoon': 0.00042267359953815294,
#  'scootaloo': 0.02317449990101321,
#  'sweetie belle': 0.015726054069596804,
#  'hoity toity': 0.0,
#  'soarin': 2.244668911335578e-05,
#  'spitfire': 0.0037932174720738845,
#  'cutie mark crusaders': 0.007038591899667424,
#  'rover': 0.0,
#  'photo finish': 0.00040566886300538615,
#  'braeburn': 0.0,
#  'young applejack': 0.0008754236454771211,
#  'young rainbow dash': 0.0,
#  'discord': 0.00276673133357828,
#  'pipsqueak': 0.0007773453423764586,
#  'fancy pants': 0.0,
#  'filthy rich': 0.005019522573221325,
#  'derpy': 3.367003367003367e-05,
#  'flim': 0.0022091128311716546,
#  'flam': 0.0010425645523684734,
#  'daring do': 0.001619632973934503,
#  'matilda': 0.0003391471474546549,
#  'cranky doodle donkey': 0.00023793302778810018,
#  'iron will': 5.677691952201756e-05,
#  'garble': 0.00012187976035525943,
#  'bulk biceps': 0.0006659543914002742,
#  'rumble': 0.0,
#  'shining armor': 0.001527746427395468,
#  'princess cadance': 0.002732452630943026,
#  'queen chrysalis': 0.0003011321833568692,
#  'babs seed': 0.00012875620451378026,
#  'lightning dust': 2.244668911335578e-05,
#  'ms. peachbottom': 0.0,
#  'dr. caballeron': 0.00046257246747442816,
#  'goldie delicious': 0.0,
#  'cheese sandwich': 0.0,
#  'maud pie': 0.002056268942463926,
#  'lord tirek': 7.608553063098518e-05,
#  'double diamond': 0.0,
#  'starlight glimmer': 0.06809651126634363,
#  'sugar belle': 0.00032247802702348155,
#  'trouble shoes': 0.0,
#  'prince rutherford': 0.00200550875105739,
#  'moon dancer': 0.0,
#  'sassy saddles': 0.0,
#  'sunburst': 0.012338202976794778,
#  'princess ember': 0.0,
#  'zephyr breeze': 0.0,
#  'quibble pants': 0.0,
#  'thorax': 0.0028073001121095473,
#  'gabby': 0.0,
#  'gladmane': 0.0,
#  'young big mcintosh': 0.0,
#  'sky stinger': 0.0,
#  'vapor trail': 0.0,
#  'bow hothoof': 9.820426487093154e-05,
#  'windy whistles': 2.244668911335578e-05,
#  'ember': 0.0003351383272654813,
#  'rockhoof': 0.0005821499592882148,
#  'pharynx': 0.0,
#  'star swirl the bearded': 0.0008036822545125389,
#  'neighsay': 0.0001990870422242971,
#  'sandbar': 0.001220139613808501,
#  'gallus': 0.0010459345872775585,
#  'yona': 0.002496629349966047,
#  'smolder': 0.0016703811767662098,
#  'silverstream': 0.0014459273627788142,
#  'ocellus': 0.000500861817675465,
#  'mudbriar': 0.0,
#  'firelight': 0.0,
#  'stellar flare': 0.0,
#  'cozy glow': 0.002386051287413203,
#  'chancellor neighsay': 0.0005649274698435031,
#  'sludge': 0.0,
#  'tempest shadow': 0.00038306286702008625,
#  'the storm king': 0.0,
#  'capper': 0.0004214467054039246,
#  'princess skystar': 0.0}

# %%
sorted_bc = list(bc.items())
sorted_bc.sort(key=lambda x: -x[1])
top3_bc = [t[0] for t in sorted_bc][0:3]
top3_bc
#sorted_bc
# Out:
# ['twilight sparkle', 'rainbow dash', 'applejack']

# %%
stat = {}
stat["most_connected_by_num"] = top3_edges
stat["most_connected_by_weight"] = top3_weights
stat["most_central_by_betweenness"] = top3_bc
stat
# Out:
# {'most_connected_by_num': ['twilight sparkle', 'rainbow dash', 'applejack'],
#  'most_connected_by_weight': ['twilight sparkle', 'rainbow dash', 'applejack'],
#  'most_central_by_betweenness': ['twilight sparkle',
#   'rainbow dash',
#   'applejack']}
